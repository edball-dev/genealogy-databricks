# %%
# %sql
-- ============================================================
-- NOTEBOOK B: gold_research_person_signals (v3)
-- Run AFTER Notebook A (weights + actions) and Notebook C (story status)
--
-- v3 changes vs v2.1:
--   REMOVED signals:
--     SIGNAL_POSSIBLE_WWI      — replaced by SIGNAL_UNCONFIRMED_MILITARY
--     SIGNAL_POSSIBLE_WWII     — replaced by SIGNAL_UNCONFIRMED_MILITARY
--     SIGNAL_POSSIBLE_OCCUPATION — superseded by SIGNAL_MISSING_OCCUPATION
--     SIGNAL_TRANSCRIPT_AVAILABLE — superseded by SIGNAL_TRANSCRIPT_RICH
--   NEW completeness signals:
--     SIGNAL_UNCONFIRMED_MILITARY — born 1880-1928, no _MILT or MilitaryRecord doc;
--                                   gender-neutral (women served too)
--     SIGNAL_MISSING_OCCUPATION   — male, working-age lifespan overlap, num_occupations=0
--     SIGNAL_MISSING_BURIAL       — death_year >= 1837, no burial/cremation event
--     SIGNAL_NO_RESIDENCE         — lifespan >= 20 years, zero RESI events
--   NEW evidence signals:
--     SIGNAL_NO_DOCUMENTS_AT_ALL  — zero matched files in silver_document_person
--     SIGNAL_UNRESOLVED_CONFLICT  — CONFLICT in gold_fact_comparison, no override
--     SIGNAL_TRANSCRIPT_ONLY_FACTS — TRANSCRIPT_ONLY rows in gold_fact_comparison
--   WIDENED:
--     SIGNAL_UNCOVERED_SOURCES    — proximity <= 2 restriction removed;
--                                   now fires for any person with > 1 uncovered source
--   NEW narrative signals:
--     SIGNAL_CONFIRMED_MILITARY   — has _MILT event or MilitaryRecord doc
--     SIGNAL_LARGE_FAMILY         — >= 6 children recorded
--     SIGNAL_NEWSPAPER_MENTION    — NewspaperClipping doc filed
--     SIGNAL_WILL_OR_PROBATE      — Will or Probate doc filed
--   NEW context signal:
--     SIGNAL_TRANSCRIPT_RICH      — >= 2 non-BMDIndex transcribed docs
--
-- New CTEs added:
--   doc_signals  — counts/flags from silver_document_person + ocr_transcriptions
--                  for: no_documents, military_record, newspaper, will_probate,
--                       transcript_rich (>= 2 non-BMD transcribed docs)
--   resi_counts  — count of RESI events per person for SIGNAL_NO_RESIDENCE
--   fact_comparison_signals — UNRESOLVED_CONFLICT and TRANSCRIPT_ONLY_FACTS
-- ============================================================

CREATE OR REPLACE VIEW genealogy.gold_research_person_signals AS

WITH timeline AS (
  SELECT
    t.person_gedcom_id,
    MAX(p.sex)                                    AS sex,
    MIN(event_year_parsed)                        AS first_event_year,
    MAX(event_year_parsed)                        AS last_event_year,
    MAX(age_years)                                AS max_event_age,
    MAX(year(p.death_date))                       AS death_year,
    MAX(year(p.birth_date))                       AS birth_year,
    COALESCE(
      MAX(year(p.death_date)),
      LEAST(MAX(year(p.birth_date)) + 80, year(current_date)),
      LEAST(MIN(event_year_parsed) + 80, year(current_date))
    )                                             AS expected_end_year,
    (
      COALESCE(
        MAX(year(p.death_date)),
        LEAST(MAX(year(p.birth_date)) + 80, year(current_date)),
        LEAST(MIN(event_year_parsed) + 80, year(current_date))
      ) - MIN(event_year_parsed) + 1
    )                                             AS effective_span_years,
    COUNT(*)                                      AS event_count
  FROM genealogy.gold_person_event_timeline t
  JOIN genealogy.gold_person_life p ON p.person_gedcom_id = t.person_gedcom_id
  WHERE event_year_parsed IS NOT NULL
  GROUP BY t.person_gedcom_id
),

evidence AS (
  SELECT
    person_gedcom_id,
    total_facts,
    total_sources,
    avg_sources_per_fact,
    child_event_count,
    marriage_event_count,
    family_event_count,
    sourced_family_event_count
  FROM genealogy.gold_person_evidence_summary
),

proximity AS (
  SELECT
    p.person_id,
    MIN(ancestral_proximity)    AS proximity,
    MIN(d.generation_depth)     AS depth,
    d.person_id                 AS nearest_ancestor_id
  FROM genealogy.gold_ancestral_proximity p
  JOIN genealogy.gold_generation_depth d ON d.person_id = p.path_to_ancestor[0]
  GROUP BY p.person_id, d.person_id
),

-- Expected census years each person should appear in.
-- Covers England & Wales / Scotland censuses 1841-1921 + 1939 Register.
census_coverage AS (
  SELECT
    t.person_gedcom_id,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1840
          AND t.expected_end_year >= 1841 THEN 1 ELSE 0 END  AS expected_1841,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1850
          AND t.expected_end_year >= 1851 THEN 1 ELSE 0 END  AS expected_1851,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1860
          AND t.expected_end_year >= 1861 THEN 1 ELSE 0 END  AS expected_1861,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1870
          AND t.expected_end_year >= 1871 THEN 1 ELSE 0 END  AS expected_1871,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1880
          AND t.expected_end_year >= 1881 THEN 1 ELSE 0 END  AS expected_1881,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1890
          AND t.expected_end_year >= 1891 THEN 1 ELSE 0 END  AS expected_1891,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1900
          AND t.expected_end_year >= 1901 THEN 1 ELSE 0 END  AS expected_1901,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1910
          AND t.expected_end_year >= 1911 THEN 1 ELSE 0 END  AS expected_1911,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1920
          AND t.expected_end_year >= 1921 THEN 1 ELSE 0 END  AS expected_1921,
    CASE WHEN t.birth_year IS NOT NULL AND t.birth_year <= 1938
          AND t.expected_end_year >= 1939 THEN 1 ELSE 0 END  AS expected_1939
  FROM timeline t
),

-- Uncovered source counts — supports SIGNAL_UNCOVERED_SOURCES (v3: proximity restriction removed)
uncovered_counts AS (
  SELECT
    person_gedcom_id,
    COUNT(*) AS uncovered_count
  FROM genealogy.gold_source_coverage
  WHERE coverage_status = 'UNCOVERED'
  GROUP BY person_gedcom_id
),

-- Residence event counts — supports SIGNAL_NO_RESIDENCE
-- Uses gold_person_event_timeline; RESI is the census event type in this tree
resi_counts AS (
  SELECT
    person_gedcom_id,
    COUNT(*) AS resi_count
  FROM genealogy.gold_person_event_timeline
  WHERE event_type = 'RESI'
  GROUP BY person_gedcom_id
),

-- Military event flag — supports SIGNAL_UNCONFIRMED_MILITARY and SIGNAL_CONFIRMED_MILITARY
-- A person has confirmed military if they have a _MILT event in the timeline
military_events AS (
  SELECT DISTINCT person_gedcom_id
  FROM genealogy.gold_person_event_timeline
  WHERE event_type = '_MILT'
),

-- Burial/cremation event flag — supports SIGNAL_MISSING_BURIAL
burial_events AS (
  SELECT DISTINCT person_gedcom_id
  FROM genealogy.gold_person_event_timeline
  WHERE event_type IN ('BURI', 'CREM')
),

-- OCR/document signals — aggregates flags from silver_document_person + ocr_transcriptions
-- Covers: docs not transcribed, fact conflicts, and v3 new signals:
--   no_documents: zero matched files for this person
--   has_military_record: MilitaryRecord doc type filed (alternative to _MILT event)
--   has_newspaper: NewspaperClipping doc filed
--   has_will_probate: Will or Probate doc filed
--   transcript_rich_count: count of non-BMDIndex transcribed docs
ocr_signals AS (
  SELECT
    p.person_gedcom_id,
    -- SIGNAL_NO_DOCUMENTS_AT_ALL: zero files matched to this person
    CASE WHEN COUNT(sdp.file_id) = 0 THEN TRUE ELSE FALSE END
      AS no_documents,
    -- SIGNAL_DOCS_NOT_TRANSCRIBED: document filed but not OCR'd
    MAX(CASE WHEN sc.coverage_status = 'DOCUMENT_NO_TRANSCRIPT' THEN TRUE ELSE FALSE END)
      AS has_docs_not_transcribed,
    -- SIGNAL_FACT_CONFLICT: transcript contradicts tree fact
    MAX(CASE WHEN fc.status = 'CONFLICT' THEN TRUE ELSE FALSE END)
      AS has_fact_conflict,
    -- SIGNAL_CONFIRMED_MILITARY (doc route): MilitaryRecord doc filed for this person
    MAX(CASE WHEN ot.doc_type_detected = 'MilitaryRecord' THEN TRUE ELSE FALSE END)
      AS has_military_record,
    -- SIGNAL_NEWSPAPER_MENTION: newspaper clipping filed
    MAX(CASE WHEN ot.doc_type_detected = 'NewspaperClipping' THEN TRUE ELSE FALSE END)
      AS has_newspaper,
    -- SIGNAL_WILL_OR_PROBATE: will or probate doc filed
    MAX(CASE WHEN ot.doc_type_detected IN ('Will', 'Probate') THEN TRUE ELSE FALSE END)
      AS has_will_probate,
    -- SIGNAL_TRANSCRIPT_RICH: >= 2 non-BMDIndex transcribed docs
    -- Counts distinct files with a transcription that are not index-only records
    COUNT(DISTINCT CASE WHEN ot.doc_type_detected != 'BMDIndex'
                          AND ot.file_id IS NOT NULL THEN ot.file_id END)
      AS non_bmd_transcript_count
  FROM genealogy.gold_person_life p
  LEFT JOIN genealogy.silver_document_person sdp ON sdp.person_gedcom_id = p.person_gedcom_id
  LEFT JOIN genealogy.gold_source_coverage sc    ON sc.person_gedcom_id  = p.person_gedcom_id
  LEFT JOIN genealogy.gold_fact_comparison fc    ON fc.person_gedcom_id  = p.person_gedcom_id
  LEFT JOIN genealogy.ocr_transcriptions ot      ON ot.file_id = sdp.file_id
  GROUP BY p.person_gedcom_id
),

-- Fact comparison signals — UNRESOLVED_CONFLICT and TRANSCRIPT_ONLY_FACTS
-- UNRESOLVED_CONFLICT: conflict exists with no entry in silver_document_person_override
-- TRANSCRIPT_ONLY_FACTS: document has a fact not yet reflected in the tree
fact_comparison_signals AS (
  SELECT
    fc.person_gedcom_id,
    -- Conflict with no manual override recorded for this file
    MAX(CASE
      WHEN fc.status = 'CONFLICT'
        AND NOT EXISTS (
          SELECT 1 FROM genealogy.silver_document_person_override ov
          WHERE ov.file_id = fc.file_id
            AND ov.person_gedcom_id = fc.person_gedcom_id
        )
      THEN TRUE ELSE FALSE END) AS has_unresolved_conflict,
    -- Transcript-only fact: document fact not in tree
    MAX(CASE WHEN fc.status = 'TRANSCRIPT_ONLY' THEN TRUE ELSE FALSE END)
      AS has_transcript_only_facts
  FROM genealogy.gold_fact_comparison fc
  GROUP BY fc.person_gedcom_id
),

-- Story written flag
story_status AS (
  SELECT person_gedcom_id, story_written
  FROM genealogy.silver_person_story_status
)

SELECT
  p.person_gedcom_id,

  -- ── Structural / lineage context ─────────────────────────────────────────
  CASE WHEN p.person_gedcom_id = pr.nearest_ancestor_id THEN TRUE ELSE FALSE END
    AS is_direct_ancestor,
  pr.depth,
  pr.proximity,
  p.event_count,
  p.effective_span_years,

  CASE WHEN pr.proximity = 0 THEN TRUE ELSE FALSE END   AS SIGNAL_DIRECT_ANCESTOR,
  CASE WHEN pr.proximity = 1 THEN TRUE ELSE FALSE END   AS SIGNAL_CLOSE_COLLATERAL,

  -- ── INTEGRITY — Completeness ──────────────────────────────────────────────

  CASE WHEN p.birth_year IS NULL
    THEN TRUE ELSE FALSE END
    AS SIGNAL_NO_BIRTH_RECORDED,

  -- GUARD: suppress if birth_year > 1930 (likely living) or lifespan < 16 years
  CASE WHEN p.death_year IS NULL
    AND p.expected_end_year < year(current_date)
    AND (p.birth_year IS NULL OR p.birth_year <= 1930)
    THEN TRUE ELSE FALSE END
    AS SIGNAL_NO_DEATH_RECORDED,

  -- GUARD: suppress if effective lifespan < 16 years (died young, never married)
  CASE WHEN fs.num_marriages = 0
    AND (
      p.death_year IS NULL
      OR (p.death_year - COALESCE(p.birth_year, p.death_year - 40)) >= 16
    )
    THEN TRUE ELSE FALSE END
    AS SIGNAL_NO_MARRIAGES,

  -- GUARD v2.1: restricted to proximity <= 1
  CASE WHEN fs.num_child_births = 0
    AND COALESCE(pr.proximity, 99) <= 1
    AND NOT (
      p.death_year IS NOT NULL
      AND p.effective_span_years BETWEEN 16 AND 40
    )
    THEN TRUE ELSE FALSE END
    AS SIGNAL_NO_CHILDREN,

  CASE WHEN fs.num_parents < 2
    THEN TRUE ELSE FALSE END
    AS SIGNAL_MISSING_PARENT,

  CASE WHEN (
      (cc.expected_1841 > 0 AND fs.has_1841_census = 0) OR
      (cc.expected_1851 > 0 AND fs.has_1851_census = 0) OR
      (cc.expected_1861 > 0 AND fs.has_1861_census = 0) OR
      (cc.expected_1871 > 0 AND fs.has_1871_census = 0) OR
      (cc.expected_1881 > 0 AND fs.has_1881_census = 0) OR
      (cc.expected_1891 > 0 AND fs.has_1891_census = 0) OR
      (cc.expected_1901 > 0 AND fs.has_1901_census = 0) OR
      (cc.expected_1911 > 0 AND fs.has_1911_census = 0) OR
      (cc.expected_1921 > 0 AND fs.has_1921_census = 0) OR
      (cc.expected_1939 > 0 AND fs.has_1939_register = 0)
    )
    THEN TRUE ELSE FALSE END
    AS SIGNAL_MISSING_CENSUS_COVERAGE,

  -- v3: proximity restriction REMOVED — fires for any person with > 1 uncovered source
  CASE WHEN COALESCE(uc.uncovered_count, 0) > 1
    THEN TRUE ELSE FALSE END
    AS SIGNAL_UNCOVERED_SOURCES,

  COALESCE(o.has_docs_not_transcribed, FALSE) AS SIGNAL_DOCS_NOT_TRANSCRIBED,

  CASE WHEN
    p.death_year IS NULL
    AND p.last_event_year < p.birth_year + 40
    THEN TRUE ELSE FALSE END
    AS SIGNAL_LATE_LIFE_GAP,

  CASE WHEN
    p.max_event_age <= 25
    AND e.family_event_count > 0
    THEN TRUE ELSE FALSE END
    AS SIGNAL_EARLY_LIFE_ONLY,

  CASE WHEN
    fs.max_days_between_child_births > 730
    OR (fs.num_marriages > 0 AND fs.num_child_births = 0)
    THEN TRUE ELSE FALSE END
    AS SIGNAL_CHILD_GAPS,

  -- NEW v3: no military service confirmed or denied for WWI/WWII-eligible person
  -- Gender-neutral — women served as nurses, land army, munitions workers etc.
  -- No proximity restriction — structural multiplier handles prioritisation.
  -- Mutually exclusive with SIGNAL_CONFIRMED_MILITARY by design.
  CASE WHEN
    p.birth_year BETWEEN 1880 AND 1928
    AND me.person_gedcom_id IS NULL          -- no _MILT event
    AND NOT COALESCE(o.has_military_record, FALSE)  -- no MilitaryRecord doc
    THEN TRUE ELSE FALSE END
    AS SIGNAL_UNCONFIRMED_MILITARY,

  -- NEW v3: adult male with no occupation recorded
  -- Working age overlap: birth_year to birth_year+65 overlaps with
  -- expected_end_year (i.e. person lived into working age)
  -- Male only — female occupations were frequently unrecorded in this period
  CASE WHEN
    p.sex = 'M'
    AND fs.num_occupations = 0
    AND p.birth_year IS NOT NULL
    AND p.expected_end_year >= p.birth_year + 18  -- lived to working age
    THEN TRUE ELSE FALSE END
    AS SIGNAL_MISSING_OCCUPATION,

  -- NEW v3: post-1837 death with no burial or cremation event recorded
  -- Pre-1837 excluded as burial registers are less reliably transcribed
  CASE WHEN
    p.death_year IS NOT NULL
    AND p.death_year >= 1837
    AND be.person_gedcom_id IS NULL
    THEN TRUE ELSE FALSE END
    AS SIGNAL_MISSING_BURIAL,

  -- NEW v3: lifespan >= 20 years but zero residence/census events
  -- Uses event_type = 'RESI' (the census event type used in this tree)
  CASE WHEN
    p.effective_span_years >= 20
    AND COALESCE(rc.resi_count, 0) = 0
    THEN TRUE ELSE FALSE END
    AS SIGNAL_NO_RESIDENCE,

  -- ── INTEGRITY — Evidence fragility ───────────────────────────────────────

  -- NEW v3: no files at all matched to this person in silver_document_person
  COALESCE(o.no_documents, FALSE) AS SIGNAL_NO_DOCUMENTS_AT_ALL,

  -- NEW v3: conflict in gold_fact_comparison with no corresponding override
  COALESCE(fcs.has_unresolved_conflict, FALSE) AS SIGNAL_UNRESOLVED_CONFLICT,

  -- NEW v3: transcript fact not yet reflected in tree
  COALESCE(fcs.has_transcript_only_facts, FALSE) AS SIGNAL_TRANSCRIPT_ONLY_FACTS,

  CASE WHEN COALESCE(e.avg_sources_per_fact, 0) < 1.0
    THEN TRUE ELSE FALSE END
    AS SIGNAL_LOW_EVIDENCE_DENSITY,

  CASE WHEN e.avg_sources_per_fact IS NULL
    OR e.avg_sources_per_fact < 0.3
    THEN TRUE ELSE FALSE END
    AS SIGNAL_VERY_LOW_EVIDENCE_DENSITY,

  CASE WHEN e.total_sources = 1 AND e.total_facts >= 3
    THEN TRUE ELSE FALSE END
    AS SIGNAL_SINGLE_SOURCE_DEPENDENCE,

  CASE WHEN e.family_event_count > e.sourced_family_event_count
    THEN TRUE ELSE FALSE END
    AS SIGNAL_UNSOURCED_FAMILY_EVENTS,

  CASE WHEN fs.has_given_name = 0 OR fs.has_surname = 0
    THEN TRUE ELSE FALSE END
    AS SIGNAL_INCOMPLETE_NAME,

  CASE WHEN
    (
      (p.birth_year  >= 1837 AND fs.birth_date_precision  <> 'DAY')
      OR
      (p.death_year  >= 1837 AND fs.death_date_precision  <> 'DAY')
      OR
      (fs.marriage_date_precision IS NOT NULL
        AND fs.earliest_marriage_year >= 1837
        AND fs.marriage_date_precision <> 'DAY')
    )
    THEN TRUE ELSE FALSE END
    AS SIGNAL_IMPRECISE_DATES,

  CASE WHEN
    p.birth_year IS NOT NULL AND p.birth_year >= 1600
    AND (
      (p.birth_year IS NOT NULL AND (
        fs.birth_place IS NULL
        OR LENGTH(fs.birth_place) - LENGTH(REPLACE(fs.birth_place, ',', '')) < 1
      ))
      OR
      (p.death_year IS NOT NULL AND (
        fs.death_place IS NULL
        OR LENGTH(fs.death_place) - LENGTH(REPLACE(fs.death_place, ',', '')) < 1
      ))
    )
    THEN TRUE ELSE FALSE END
    AS SIGNAL_IMPRECISE_PLACES,

  COALESCE(o.has_fact_conflict, FALSE) AS SIGNAL_FACT_CONFLICT,

  -- ── NARRATIVE — Texture ───────────────────────────────────────────────────

  -- v3: SIGNAL_MILITARY retained (historical confirmed service, pre-_MILT era)
  CASE WHEN fs.num_military > 0
    THEN TRUE ELSE FALSE END
    AS SIGNAL_MILITARY,

  CASE WHEN fs.num_marriages > 1
    THEN TRUE ELSE FALSE END
    AS SIGNAL_MULTIPLE_SPOUSES,

  CASE WHEN
    p.death_year IS NOT NULL
    AND p.effective_span_years BETWEEN 16 AND 40
    THEN TRUE ELSE FALSE END
    AS SIGNAL_YOUNG_DEATH,

  CASE WHEN fs.num_migration > 0 OR fs.num_countries > 1
    THEN TRUE ELSE FALSE END
    AS SIGNAL_MIGRANT,

  -- NEW v3: confirmed military — _MILT event OR MilitaryRecord doc filed
  -- Mutually exclusive with SIGNAL_UNCONFIRMED_MILITARY by design
  CASE WHEN
    me.person_gedcom_id IS NOT NULL
    OR COALESCE(o.has_military_record, FALSE)
    THEN TRUE ELSE FALSE END
    AS SIGNAL_CONFIRMED_MILITARY,

  -- NEW v3: large family — social history and child mortality narrative angle
  CASE WHEN fs.num_child_births >= 6
    THEN TRUE ELSE FALSE END
    AS SIGNAL_LARGE_FAMILY,

  -- NEW v3: newspaper clipping filed for this person — rare and high narrative value
  COALESCE(o.has_newspaper, FALSE) AS SIGNAL_NEWSPAPER_MENTION,

  -- NEW v3: will or probate document filed — wealth, family dynamics, final wishes
  COALESCE(o.has_will_probate, FALSE) AS SIGNAL_WILL_OR_PROBATE,

  -- Story suppression signal
  COALESCE(ss.story_written, FALSE) AS SIGNAL_STORY_WRITTEN,

  -- ── NARRATIVE — Context ───────────────────────────────────────────────────

  -- NEW v3: >= 2 non-BMDIndex transcribed docs — enough primary material to write from
  -- BMDIndex entries are register indexes only, not narrative documents
  CASE WHEN COALESCE(o.non_bmd_transcript_count, 0) >= 2
    THEN TRUE ELSE FALSE END
    AS SIGNAL_TRANSCRIPT_RICH,

  -- Multiple distinct occupations recorded
  CASE WHEN fs.num_occupations > 1
    THEN TRUE ELSE FALSE END
    AS SIGNAL_VARIED_OCCUPATIONS,

  -- REDEFINED v2: family events present but census coverage missing
  CASE WHEN
    (fs.num_marriages > 0 OR fs.num_child_births > 0)
    AND (
      (cc.expected_1841 > 0 AND fs.has_1841_census = 0) OR
      (cc.expected_1851 > 0 AND fs.has_1851_census = 0) OR
      (cc.expected_1861 > 0 AND fs.has_1861_census = 0) OR
      (cc.expected_1871 > 0 AND fs.has_1871_census = 0) OR
      (cc.expected_1881 > 0 AND fs.has_1881_census = 0) OR
      (cc.expected_1891 > 0 AND fs.has_1891_census = 0) OR
      (cc.expected_1901 > 0 AND fs.has_1901_census = 0) OR
      (cc.expected_1911 > 0 AND fs.has_1911_census = 0) OR
      (cc.expected_1921 > 0 AND fs.has_1921_census = 0) OR
      (cc.expected_1939 > 0 AND fs.has_1939_register = 0)
    )
    THEN TRUE ELSE FALSE END
    AS SIGNAL_POSSIBLE_RESIDENCE,

  CASE WHEN
    e.family_event_count >= 3
    AND e.avg_sources_per_fact < 1.5
    THEN TRUE ELSE FALSE END
    AS SIGNAL_HIGH_FAMILY_PAYOFF,

  CASE WHEN
    p.sex = 'F'
    AND fs.has_1939_register = 1
    AND fs.num_marriages = 0
    THEN TRUE ELSE FALSE END
    AS SIGNAL_POSSIBLE_MARRIAGE,

  CASE WHEN
    p.sex = 'F'
    AND fs.has_1911_census = 1
    AND p.birth_year <= 1895
    THEN TRUE ELSE FALSE END
    AS SIGNAL_POSSIBLE_CHILDREN

FROM timeline p
JOIN  evidence e                  ON p.person_gedcom_id = e.person_gedcom_id
JOIN  genealogy.gold_person_fact_summary fs ON fs.person_gedcom_id = p.person_gedcom_id
LEFT JOIN proximity pr            ON p.person_gedcom_id = pr.person_id
LEFT JOIN census_coverage cc      ON p.person_gedcom_id = cc.person_gedcom_id
LEFT JOIN uncovered_counts uc     ON p.person_gedcom_id = uc.person_gedcom_id
LEFT JOIN resi_counts rc          ON p.person_gedcom_id = rc.person_gedcom_id
LEFT JOIN military_events me      ON p.person_gedcom_id = me.person_gedcom_id
LEFT JOIN burial_events be        ON p.person_gedcom_id = be.person_gedcom_id
LEFT JOIN ocr_signals o           ON p.person_gedcom_id = o.person_gedcom_id
LEFT JOIN fact_comparison_signals fcs ON p.person_gedcom_id = fcs.person_gedcom_id
LEFT JOIN story_status ss         ON p.person_gedcom_id = ss.person_gedcom_id;

# %%
# %sql
-- ============================================================
-- CELL 2: gold_research_person_signals_pivoted (v3)
--
-- v3 changes:
--   REMOVED: SIGNAL_POSSIBLE_WWI, SIGNAL_POSSIBLE_WWII,
--            SIGNAL_POSSIBLE_OCCUPATION, SIGNAL_TRANSCRIPT_AVAILABLE
--   ADDED:   SIGNAL_UNCONFIRMED_MILITARY, SIGNAL_MISSING_OCCUPATION,
--            SIGNAL_MISSING_BURIAL, SIGNAL_NO_RESIDENCE,
--            SIGNAL_NO_DOCUMENTS_AT_ALL, SIGNAL_UNRESOLVED_CONFLICT,
--            SIGNAL_TRANSCRIPT_ONLY_FACTS, SIGNAL_CONFIRMED_MILITARY,
--            SIGNAL_LARGE_FAMILY, SIGNAL_NEWSPAPER_MENTION,
--            SIGNAL_WILL_OR_PROBATE, SIGNAL_TRANSCRIPT_RICH
-- ============================================================

CREATE OR REPLACE VIEW genealogy.gold_research_person_signals_pivoted AS
SELECT person_gedcom_id, signal_code
FROM genealogy.gold_research_person_signals
LATERAL VIEW explode(map(
  -- INTEGRITY — Completeness
  'SIGNAL_NO_BIRTH_RECORDED',          SIGNAL_NO_BIRTH_RECORDED,
  'SIGNAL_NO_DEATH_RECORDED',          SIGNAL_NO_DEATH_RECORDED,
  'SIGNAL_NO_MARRIAGES',               SIGNAL_NO_MARRIAGES,
  'SIGNAL_NO_CHILDREN',                SIGNAL_NO_CHILDREN,
  'SIGNAL_MISSING_PARENT',             SIGNAL_MISSING_PARENT,
  'SIGNAL_MISSING_CENSUS_COVERAGE',    SIGNAL_MISSING_CENSUS_COVERAGE,
  'SIGNAL_UNCOVERED_SOURCES',          SIGNAL_UNCOVERED_SOURCES,
  'SIGNAL_DOCS_NOT_TRANSCRIBED',       SIGNAL_DOCS_NOT_TRANSCRIBED,
  'SIGNAL_LATE_LIFE_GAP',              SIGNAL_LATE_LIFE_GAP,
  'SIGNAL_EARLY_LIFE_ONLY',            SIGNAL_EARLY_LIFE_ONLY,
  'SIGNAL_CHILD_GAPS',                 SIGNAL_CHILD_GAPS,
  'SIGNAL_UNCONFIRMED_MILITARY',       SIGNAL_UNCONFIRMED_MILITARY,
  'SIGNAL_MISSING_OCCUPATION',         SIGNAL_MISSING_OCCUPATION,
  'SIGNAL_MISSING_BURIAL',             SIGNAL_MISSING_BURIAL,
  'SIGNAL_NO_RESIDENCE',               SIGNAL_NO_RESIDENCE,
  -- INTEGRITY — Evidence
  'SIGNAL_NO_DOCUMENTS_AT_ALL',        SIGNAL_NO_DOCUMENTS_AT_ALL,
  'SIGNAL_UNRESOLVED_CONFLICT',        SIGNAL_UNRESOLVED_CONFLICT,
  'SIGNAL_TRANSCRIPT_ONLY_FACTS',      SIGNAL_TRANSCRIPT_ONLY_FACTS,
  'SIGNAL_LOW_EVIDENCE_DENSITY',       SIGNAL_LOW_EVIDENCE_DENSITY,
  'SIGNAL_VERY_LOW_EVIDENCE_DENSITY',  SIGNAL_VERY_LOW_EVIDENCE_DENSITY,
  'SIGNAL_SINGLE_SOURCE_DEPENDENCE',   SIGNAL_SINGLE_SOURCE_DEPENDENCE,
  'SIGNAL_UNSOURCED_FAMILY_EVENTS',    SIGNAL_UNSOURCED_FAMILY_EVENTS,
  'SIGNAL_IMPRECISE_DATES',            SIGNAL_IMPRECISE_DATES,
  'SIGNAL_INCOMPLETE_NAME',            SIGNAL_INCOMPLETE_NAME,
  'SIGNAL_IMPRECISE_PLACES',           SIGNAL_IMPRECISE_PLACES,
  'SIGNAL_FACT_CONFLICT',              SIGNAL_FACT_CONFLICT,
  -- NARRATIVE — Texture
  'SIGNAL_MILITARY',                   SIGNAL_MILITARY,
  'SIGNAL_YOUNG_DEATH',                SIGNAL_YOUNG_DEATH,
  'SIGNAL_MIGRANT',                    SIGNAL_MIGRANT,
  'SIGNAL_CONFIRMED_MILITARY',         SIGNAL_CONFIRMED_MILITARY,
  'SIGNAL_LARGE_FAMILY',               SIGNAL_LARGE_FAMILY,
  'SIGNAL_NEWSPAPER_MENTION',          SIGNAL_NEWSPAPER_MENTION,
  'SIGNAL_WILL_OR_PROBATE',            SIGNAL_WILL_OR_PROBATE,
  'SIGNAL_STORY_WRITTEN',              SIGNAL_STORY_WRITTEN,
  -- NARRATIVE — Family
  'SIGNAL_MULTIPLE_SPOUSES',           SIGNAL_MULTIPLE_SPOUSES,
  -- NARRATIVE — Context
  'SIGNAL_TRANSCRIPT_RICH',            SIGNAL_TRANSCRIPT_RICH,
  'SIGNAL_VARIED_OCCUPATIONS',         SIGNAL_VARIED_OCCUPATIONS,
  'SIGNAL_POSSIBLE_RESIDENCE',         SIGNAL_POSSIBLE_RESIDENCE,
  'SIGNAL_HIGH_FAMILY_PAYOFF',         SIGNAL_HIGH_FAMILY_PAYOFF,
  'SIGNAL_POSSIBLE_MARRIAGE',          SIGNAL_POSSIBLE_MARRIAGE,
  'SIGNAL_POSSIBLE_CHILDREN',          SIGNAL_POSSIBLE_CHILDREN
)) exploded AS signal_code, is_present
WHERE is_present = TRUE;

# %%
# %sql
-- ============================================================
-- CELL 3: Verification — signal fire rates
-- Run after Cell 1 and 2. Review before running calibration notebook.
--
-- New signals — watch for unexpected rates:
--   SIGNAL_UNCONFIRMED_MILITARY  expect moderate % (all 1880-1928 born, not confirmed)
--   SIGNAL_MISSING_OCCUPATION    expect moderate-high % (many males without occ recorded)
--   SIGNAL_MISSING_BURIAL        expect moderate % (many deaths without burial event)
--   SIGNAL_NO_RESIDENCE          may be high initially — many people have no RESI events
--   SIGNAL_NO_DOCUMENTS_AT_ALL   expect high % (OCR coverage still partial)
--   SIGNAL_UNRESOLVED_CONFLICT   expect low % (Cuthbertson only so far)
--   SIGNAL_TRANSCRIPT_ONLY_FACTS expect low % (same)
--   SIGNAL_CONFIRMED_MILITARY    expect low % (rare)
--   SIGNAL_LARGE_FAMILY          expect low % (< 10%)
--   SIGNAL_NEWSPAPER_MENTION     expect very low % (< 2%)
--   SIGNAL_WILL_OR_PROBATE       expect very low % (< 5%)
--   SIGNAL_TRANSCRIPT_RICH       expect low % initially (OCR coverage partial)
--   SIGNAL_UNCOVERED_SOURCES     was ~15-25% at proximity<=2; expect higher now
-- ============================================================

SELECT
  signal_code,
  COUNT(*)                                          AS fire_count,
  ROUND(COUNT(*) * 100.0 / MAX(total.cnt), 1)       AS fire_pct
FROM genealogy.gold_research_person_signals_pivoted
CROSS JOIN (SELECT COUNT(DISTINCT person_gedcom_id) AS cnt
            FROM genealogy.gold_research_person_signals) total
GROUP BY signal_code
ORDER BY fire_pct DESC;

# %%
# %sql
-- ============================================================
-- CELL 4: Signals firing but contributing nothing to scores
-- Should return 0 rows after running Notebook A v3
-- ============================================================

SELECT DISTINCT p.signal_code
FROM genealogy.gold_research_person_signals_pivoted p
LEFT JOIN genealogy.ref_signal_weights w ON w.signal_code = p.signal_code
WHERE w.signal_code IS NULL
ORDER BY p.signal_code;

# %%
# %sql
-- ============================================================
-- CELL 5: Spot check — new v3 signals on Cuthbertson branch
-- Cuthbertson is the only branch with OCR/reconciliation data.
-- SIGNAL_CONFIRMED_MILITARY, SIGNAL_UNRESOLVED_CONFLICT, SIGNAL_TRANSCRIPT_ONLY_FACTS,
-- SIGNAL_TRANSCRIPT_RICH etc. should only fire here for now.
-- ============================================================

SELECT
  s.person_gedcom_id,
  p.given_name,
  p.surname,
  p.birth_year,
  p.sex,
  s.SIGNAL_UNCONFIRMED_MILITARY,
  s.SIGNAL_CONFIRMED_MILITARY,
  s.SIGNAL_MISSING_OCCUPATION,
  s.SIGNAL_MISSING_BURIAL,
  s.SIGNAL_NO_RESIDENCE,
  s.SIGNAL_NO_DOCUMENTS_AT_ALL,
  s.SIGNAL_UNRESOLVED_CONFLICT,
  s.SIGNAL_TRANSCRIPT_ONLY_FACTS,
  s.SIGNAL_TRANSCRIPT_RICH,
  s.SIGNAL_LARGE_FAMILY,
  s.SIGNAL_NEWSPAPER_MENTION,
  s.SIGNAL_WILL_OR_PROBATE
FROM genealogy.gold_research_person_signals s
JOIN genealogy.gold_person_life p ON p.person_gedcom_id = s.person_gedcom_id
JOIN genealogy.gold_person_branch b ON b.person_gedcom_id = s.person_gedcom_id
WHERE b.branch = 'Cuthbertson'
ORDER BY p.surname, p.given_name
LIMIT 100;
