-- %% [markdown]
-- # Notebook 01: Document Matching & Source Coverage Audit
--
-- Run cells in order.
--
-- - Cells 1–4: Create tables (idempotent)
-- - Cell 4b: Create silver_document_person_override and add manual overrides
-- - Cell 4c: Create silver_document_match_exception
-- - Cell 5: Main matching algorithm
-- - Cell 5b: Spouse inference for marriage certificates
-- - Cell 5c: Resolve remaining ties via sibling-document consensus
-- - Cell 5d: Sync gold_transcript_facts.person_gedcom_id after a match correction
-- - Cell 5e: Household member inference for Census/BurialRegister documents
-- - Cell 6: Diagnostic query for unmatched files — review and resolve before moving on
-- - Cell 7: Source/doc_type mapping view (BirthIndex/MarriageIndex/DeathIndex replacing BMDIndex)
-- - Cell 8: Populate gold_source_coverage
-- - Cell 9: Coverage summary
-- - Cell 10: People with most uncovered citations
-- - Cell 11: Verify a specific person

-- %% [markdown]
-- ## Cell 1 — Create silver_person_alias
--
-- Seeded with four alias types:
-- - MARRIED_NAME: wife takes husband's surname
-- - FATHER_SURNAME: child surname differs from biological father's surname
-- - DOCUMENT_NAME: explicit Sr/Jr suffix disambiguation for same-name relatives —
--   only resolves files whose filename carries a (Sr)/(Jr) marker (see Cell 5).
-- - SURNAME_VARIANT: document spells the surname differently from the tree (e.g.
--   pre-civil-registration spelling drift).
--
-- Add a new DOCUMENT_NAME/SURNAME_VARIANT row here when a fresh case can be
-- resolved this way instead of via silver_document_person_override.

-- %%
-- %sql
CREATE OR REPLACE TABLE genealogy.silver_person_alias AS
SELECT
DISTINCT
  sf.wife_gedcom_id AS person_gedcom_id,
  wp.given_name AS alias_given_name,
  hp.surname AS alias_surname,
  'MARRIED_NAME' AS alias_type,
  CAST(NULL AS STRING) AS alias_suffix,
  CONCAT('Married name via ', coalesce(hp.given_name, '[unknown]'), ' ', hp.surname) AS notes
FROM
  genealogy.silver_family sf
    JOIN genealogy.gold_person_life wp
      ON sf.wife_gedcom_id = wp.person_gedcom_id
    JOIN genealogy.gold_person_life hp
      ON sf.husband_gedcom_id = hp.person_gedcom_id
WHERE
  hp.surname IS NOT NULL
  AND sf.relationship_type is null -- i.e. not 'partner'
  AND hp.surname != wp.surname -- exclude cases where surnames already match
  UNION ALL
  -- Populate father surname aliases for children with different surnames
  SELECT DISTINCT
  sfc.child_gedcom_id                                        AS person_gedcom_id,
  cp.given_name                                              AS alias_given_name,
  fp.surname                                                 AS alias_surname,
  'FATHER_SURNAME'                                           AS alias_type,
  CAST(NULL AS STRING) AS alias_suffix,
  CONCAT('Father surname via ', fp.given_name, ' ', fp.surname) AS notes
FROM genealogy.silver_family_child sfc
JOIN genealogy.silver_family sf    ON sfc.family_gedcom_id  = sf.family_gedcom_id
JOIN genealogy.gold_person_life cp ON sfc.child_gedcom_id   = cp.person_gedcom_id
JOIN genealogy.gold_person_life fp ON sf.husband_gedcom_id  = fp.person_gedcom_id
WHERE cp.surname != fp.surname
  AND fp.surname IS NOT NULL
  AND cp.surname IS NOT NULL
  AND sfc.father_relationship_type = 'biological'
  UNION ALL
  -- Manual aliases (curated per-case, no automated source):
  -- DOCUMENT_NAME     — explicit suffix disambiguation for same-name relatives, keyed on
  --                     a marker the filename itself carries: Sr/Jr/Jnr/Snr, or a relative-
  --                     to-the-archivist annotation like (Uncle) (BUG-006, 2026-09-16 --
  --                     widened alongside the Jr/Sr suffix regex in Cells 5/5c/6 so it
  --                     participates in suffix-match ranking priority #1 instead of just
  --                     being stripped as noise). Matching is keyed on that marker via
  --                     alias_suffix (see Cell 5), so this can't help files with no marker
  --                     at all.
  -- SURNAME_VARIANT   — document spells the surname differently from the tree (e.g.
  --                     pre-civil-registration spelling drift). alias_suffix optional;
  --                     set it when the specific generation is also known, to avoid
  --                     colliding with an unrelated same-name/different-spelling person.
  -- MARRIED_NAME      — manual counterpart to the auto-derived MARRIED_NAME rows above,
  --                     used when the document forename is a nickname/diminutive of the
  --                     tree's given_name (so the auto row's exact-name join still can't
  --                     match it) or the married surname itself isn't in silver_family yet.
  -- Files not covered by either still need silver_document_person_override.
  SELECT
    v.person_gedcom_id, v.alias_given_name, v.alias_surname, v.alias_type, v.alias_suffix, v.notes
  FROM (VALUES
    ('@I_967018275@',  'Charles Edward', 'Ball',        'DOCUMENT_NAME',   'Jr',  'Charles Edward Ball Jr (b.1917) — disambiguates from his father of the same name'),
    ('@I998518491@',   'George',         'Cuthbertson', 'DOCUMENT_NAME',   'Sr',  'George Cuthbertson Sr (b.1771)'),
    ('@I1002165280@',  'John',           'Glendinning', 'DOCUMENT_NAME',   'Sr',  'John Glendinning Sr (b.1772)'),
    ('@I_967018265@',  'Archibald',      'McLean',      'DOCUMENT_NAME',   'Jr',  'Archibald William "Baldy" McLean Jr (b.1894)'),
    ('@I908750301@',   'Thomas',         'Thorpe',      'DOCUMENT_NAME',   'Jr',  'Thomas Thorpe Jr (b.1839)'),
    ('@I332509215242@','Samuel',         'Mattock',     'SURNAME_VARIANT', 'Sr',  'Samuel Maddock Sr (b.1795) — 1816 marriage doc spells surname Mattock; two unrelated Samuel Mattocks already in the tree (b.1858, b.1893) were winning the match by default since neither passed the year-plausibility check'),
    ('@I332509465415@','Elizabeth',      'Balls',       'SURNAME_VARIANT', NULL,  'Elizabeth Gibbs / Elizabeth Baulls née Gibbs (b. abt 1738, d. Mar 1814) — 1814 burial doc spells married surname Balls (dropped the ‘u’); the existing auto-derived MARRIED_NAME alias only covers the canonical tree spelling Baulls, which the document does not use verbatim, so it never entered the candidate pool. Three unrelated Elizabeth Balls already in the tree (b.1826, b.1858, b.1865) were winning the match by default since none passed the year-plausibility check for an 1814 document.'),
    ('@I25788621623@', 'Henry',          'Easter',      'SURNAME_VARIANT', NULL,  'Henry Eastoe (b. abt 1776, d. 1848, Litcham, Norfolk) — 1828 marriage doc (widower remarrying) spells surname Easter, a period parish-clerk variant. Four unrelated Henry/Henry-middle-name Easters already in the tree (b.1832, b.1861, b.1865, b.1872) were winning the match by default via sibling-consensus (Cell 5c) since none passed the year-plausibility check for an 1828 document.'),
    ('@I_967018302@', 'Dina',           'Ball',        'MARRIED_NAME',    NULL,  'Davidina Cuthbertson (b.1927, d.2020) m. Ronald Ball — documents use nickname "Dina", not tree given_name "Davidina"; the auto-derived MARRIED_NAME alias for this marriage (silver_family @F1789) already covers surname Ball but only under the formal given name, so it never matched these files.'),
    ('@I_967018302@', 'Dina',           'MacLean',     'MARRIED_NAME',    NULL,  'Davidina Cuthbertson (b.1927, d.2020) — documents (1977 name-change record onward, incl. her 1995 marriage to Douglas Edwin Vickery, matching the tree''s recorded @F1783 marriage) are filed under married surname MacLean, a marriage not currently captured in silver_family; also uses nickname "Dina" rather than tree given_name "Davidina".'),
    ('@I_967018258@', 'James',          'Snaddon',     'SURNAME_VARIANT', NULL,  'James Sneddon (b.1796, d.1859, Fife, Scotland) — 1816 marriage doc spells surname Snaddon, a period Scottish spelling variant of Sneddon; exact year and wife-surname match to the tree''s recorded @F1797 marriage to Rachel Burt (b.1796) in Dunfermline, Fife.'),
    ('@I332509215242@','Samuel',        'Maddox',      'SURNAME_VARIANT', 'Sr',  'Samuel Maddock Sr (b.1795, d.1839) — same person as the existing Mattock SURNAME_VARIANT row above, here spelled Maddox. Flagged, not confirmed: the 1845-01-26 tithe record postdates his death by 6yrs, outside DQ-001''s plausibility window (no exemption for Tithe records) and no son of his is named Samuel, so this is expected to land in silver_document_match_exception for manual review rather than auto-match — added so it surfaces there instead of sitting unexplained as SURNAME_NOT_IN_TREE.'),
    ('@I_967018051@', 'Edward',        'Cope',        'DOCUMENT_NAME',   'Uncle',  'Edward Cope (b.1778, d.1866) — BUG-006 fix (2026-09-16): the (Uncle) annotation on his 4 filed documents was previously stripped as generic noise (same as (son of Archibald) etc.), which let plain forename matching split them across 3 different tree Edward Copes -- the 1858 Will (he would be aged 80, plausible) went to a living b.1835/d.1918 Edward, and the 1866 Nottinghamshire Guardian death notice went to a b.1738/d.1789 Edward (77yrs post-death, only passed DQ-001 via the NewspaperClipping upper-bound exemption). The 1866 headstone and death-duty register index already matched this Edward correctly on year alone. Adding Uncle as a suffix marker (alongside Sr/Jr in the Cell 5/5c/6 regex) pins all 4 to him via suffix-match ranking priority #1.')
  ) AS v(person_gedcom_id, alias_given_name, alias_surname, alias_type, alias_suffix, notes);

COMMENT ON TABLE genealogy.silver_person_alias IS 'Derived and manual name aliases for matching — married surnames, father surnames, suffixes used in document titles etc';

-- %% [markdown]
-- ## Cell 2 — Create silver_document_person

-- %%
-- %sql
CREATE TABLE IF NOT EXISTS genealogy.silver_document_person (
  file_id             STRING   NOT NULL,
  file_name           STRING,
  person_gedcom_id    STRING   NOT NULL,
  display_name        STRING,
  match_method        STRING,
  match_confidence    STRING,
  candidate_count     INT,
  notes               STRING,
  matched_at          TIMESTAMP
)
USING DELTA
COMMENT 'Links OCR transcript files to person_gedcom_id.';

-- %% [markdown]
-- ## Cell 3 — Create gold_transcript_facts

-- %%
-- %sql
CREATE TABLE IF NOT EXISTS genealogy.gold_transcript_facts (
  file_id             STRING   NOT NULL,
  person_gedcom_id    STRING,
  fact_type           STRING,
  fact_value          STRING,
  fact_year           INT,
  confidence          STRING,
  source_doc_type     STRING,
  extracted_at        TIMESTAMP
)
USING DELTA
COMMENT 'Structured facts extracted from OCR transcripts by Gemini.';

-- %% [markdown]
-- ## Cell 4 — Create gold_fact_comparison and gold_source_coverage

-- %%
-- %sql
CREATE TABLE IF NOT EXISTS genealogy.gold_fact_comparison (
  person_gedcom_id    STRING,
  display_name        STRING,
  fact_type           STRING,
  tree_value          STRING,
  transcript_value    STRING,
  file_id             STRING,
  file_name           STRING,
  source_doc_type     STRING,
  status              STRING,
  conflict_severity   STRING,
  notes               STRING,
  refreshed_at        TIMESTAMP
)
USING DELTA
COMMENT 'Comparison of facts from OCR transcripts vs gold_person_life tree data.';

CREATE TABLE IF NOT EXISTS genealogy.gold_source_coverage (
  event_id            STRING,
  person_gedcom_id    STRING,
  source_title        STRING,
  source_category     STRING,
  citation_date       STRING,
  citation_text       STRING,
  citation_url        STRING,
  has_document        BOOLEAN,
  has_transcript      BOOLEAN,
  matched_file_ids    STRING,
  ancestry_record_id  STRING,
  coverage_status     STRING,
  refreshed_at        TIMESTAMP
)
USING DELTA
COMMENT 'Source coverage audit: which tree citations have downloaded documents/transcripts.';

-- %% [markdown]
-- ## Cell 4b — Create silver_document_person_override
--
-- This is a deliberately-empty escape hatch, not an unfinished feature. As of 2026-09-13 every case that once needed a manual override (23 rows, mostly Sr/Jr same-name ambiguity) got resolved algorithmically instead — suffix-aware matching, a surname-variant alias, transcript-derived age/date scoring, and sibling-document consensus (see Cells 1 and 5). The table is kept, empty, in case a future document genuinely can't be resolved from tree/transcript data alone (e.g. it needs an external record to disambiguate). Add a row here only when that happens — do not re-add the historical Sr/Jr rows removed today; they resolve on their own now.
--
-- Overrides, if any exist, are seeded into silver_document_person before the algorithm runs, and those file_ids are then skipped automatically.

-- %%
-- %sql
CREATE TABLE IF NOT EXISTS genealogy.silver_document_person_override (
  file_id           STRING NOT NULL,
  file_name         STRING,
  person_gedcom_id  STRING NOT NULL,
  notes             STRING
)
USING DELTA
COMMENT 'Manual overrides for document-to-person matching. Takes precedence over algorithmic matching.';

-- expect 0 — every previously-overridden case now resolves algorithmically (see
-- Cell 4b's markdown). Add new rows here only for a case genuinely unresolvable
-- from tree/transcript data alone.
SELECT COUNT(*) AS override_rows FROM genealogy.silver_document_person_override;

-- %% [markdown]
-- ## Cell 4c — Create silver_document_match_exception
--
-- Holds files Cell 5 (zero year-plausible candidates) or Cell 5c (sibling
-- consensus disagrees with this specific file's own year) declined to
-- force-match onto a chronologically implausible candidate — the fix for the
-- root cause behind the Elizabeth Balls / Henry Easter wrong-person matches
-- (Asana 1218506594311016). A file logged here got no row in
-- silver_document_person at all (Cell 5's case) or kept its pre-consensus LOW
-- row untouched (Cell 5c's case) — review the same way as any other unmatched
-- file: resolve via a silver_person_alias addition (Cell 1, the common case —
-- see the Henry Eastoe/Elizabeth Gibbs SURNAME_VARIANT rows) or a
-- silver_document_person_override row (Cell 4b, last resort) if no
-- tree/transcript signal can resolve it. DQ-010 surfaces this table's row
-- count for trend visibility.

-- %%
-- %sql
CREATE TABLE IF NOT EXISTS genealogy.silver_document_match_exception (
  file_id                 STRING     NOT NULL,
  file_name                STRING,
  doc_type_detected        STRING,
  year                      STRING,
  surname                   STRING,
  forename                  STRING,
  candidate_count           INT,
  reason                    STRING,
  candidates_considered     STRING,
  logged_at                 TIMESTAMP
)
USING DELTA
COMMENT 'Files Cell 5/5c declined to force-match onto a chronologically implausible candidate -- for manual review. See Asana 1218506594311016.';

TRUNCATE TABLE genealogy.silver_document_match_exception;

-- %% [markdown]
-- ## Cell 5 — Main matching algorithm
--
-- TRUNCATEs silver_document_person and repopulates from scratch each run.
-- Seeds manual overrides first, then runs algorithmic matching for remaining files.
--
-- Ranking priority:
-- 1. Suffix match (a filename-confirmed Sr/Jr DOCUMENT_NAME alias beats everything else)
-- 2. Ancestors before non-ancestors
-- 3. Doc type affinity (birth doc near birth year, death doc near death year, marriage doc near marriage event)
-- 4. Ancestral proximity (0 = direct ancestor)
-- 5. Year plausibility
-- 6. person_gedcom_id ASC (deterministic tiebreaker)

-- %%
-- %sql
TRUNCATE TABLE genealogy.silver_document_person;

-- Seed manual overrides first
INSERT INTO genealogy.silver_document_person
  (file_id, file_name, person_gedcom_id, display_name,
   match_method, match_confidence, candidate_count, notes, matched_at)
SELECT
  o.file_id,
  o.file_name,
  o.person_gedcom_id,
  p.given_name || ' ' || p.surname AS display_name,
  'MANUAL'                         AS match_method,
  'HIGH'                           AS match_confidence,
  1                                AS candidate_count,
  o.notes,
  CURRENT_TIMESTAMP()
FROM genealogy.silver_document_person_override o
JOIN genealogy.gold_person_life p ON o.person_gedcom_id = p.person_gedcom_id;

-- Algorithmic matching
WITH

cleaned_transcripts_base AS (
  SELECT
    file_id,
    file_name,
    year,
    surname,
    -- Suffix extracted before stripping, for suffix-aware alias matching below.
    REGEXP_EXTRACT(forename, '\\(?(Jr|Sr|Jnr|Snr|Uncle)\\.?\\)?\\s*$') AS forename_suffix,
    -- BUG-005 fix (2026-09-16): strip Jr/Sr first (forename_suffix above is
    -- unaffected), then strip any other trailing parenthetical annotation --
    -- filers add notes like (Uncle) or (son of Archibald) to disambiguate
    -- same-name relatives, which aren't part of the actual given name and were
    -- blocking forename matching entirely (COPE_Edward (Uncle)_*, MCLEAN_James
    -- (son of Archibald)_*).
    TRIM(REGEXP_REPLACE(
      TRIM(REGEXP_REPLACE(forename, '\\s*\\(?(Jr|Sr|Jnr|Snr|Uncle)\\.?\\)?\\s*$', '')),
      '\\s*\\([^)]*\\)\\s*$', ''
    )) AS forename_clean,
    doc_type_detected,
    transcribed_text
  FROM genealogy.ocr_transcriptions
),

-- BUG-001 fix B (extended): extract a document-stated age so doc_type_affinity below
-- isn't stuck at the worst tier (ELSE 2) for these doc types. No structured age
-- column exists on ocr_transcriptions or (non-circularly) on gold_transcript_facts,
-- so it's pulled from transcribed_text with doc-type-specific regexes; NULL on
-- extraction failure just falls through to ELSE 2, so a missed extraction never
-- produces a wrong score.
-- Census, BurialRegister: both OCR'd as a "|"-delimited table (parish register rows
--   are the same tabular shape as a census return) -- age is the first purely-numeric
--   pipe-delimited cell after the person's own name is spelled out in full. A
--   household/family member listed via a ditto mark ("do") instead of the literal
--   surname can't be matched by this regex -- see BUG-003 note on Cell 5c below for
--   why that's a real, accepted limitation, not a bug in this regex.
-- MonumentalInscription: text commonly reads "...DIED <date> <year>, AGED <n>
--   YEARS" for each burial recorded on the stone; anchoring on the file's own year
--   picks the right age when a stone lists multiple burials.
-- NewspaperClipping: obituary/inquest reports commonly state "aged <n>" directly.
--   Only the explicit "aged N" phrasing is used (not e.g. "(N)") since a bare
--   parenthesised number is too easily something else (a page/plot/amount).
-- MilitaryRecord: attestation forms ask "What is the date of your birth?" and
--   answer with a full date — the stated age here is computed as this file's
--   year minus the extracted birth year, so it plugs into the same age-based
--   scoring formula as the other doc types below.
cleaned_transcripts AS (
  SELECT
    file_id, file_name, year, surname, forename_clean, forename_suffix, doc_type_detected,
    CASE
      WHEN doc_type_detected IN ('Census', 'BurialRegister') THEN
        TRY_CAST(
          REGEXP_EXTRACT(
            transcribed_text,
            CONCAT('(?i)', forename_clean, '\\s+', surname, '[^\\n]*?\\|\\s*(\\d{1,3})\\s*\\|'),
            1
          ) AS INT)
      WHEN doc_type_detected = 'MonumentalInscription' AND year IS NOT NULL THEN
        TRY_CAST(
          REGEXP_EXTRACT(
            transcribed_text,
            CONCAT('(?s)', year, '.{0,60}?AGED\\s+(\\d{1,3})'),
            1
          ) AS INT)
      WHEN doc_type_detected = 'NewspaperClipping' THEN
        TRY_CAST(REGEXP_EXTRACT(transcribed_text, '(?i)aged\\s+(\\d{1,3})', 1) AS INT)
      WHEN doc_type_detected = 'MilitaryRecord' THEN
        TRY_CAST(SUBSTR(year, 1, 4) AS INT)
          - TRY_CAST(
              REGEXP_EXTRACT(
                transcribed_text,
                '(?i)date of (?:your )?birth\\?[^\\d]{0,20}\\d{1,2}(?:st|nd|rd|th)?\\.?\\s+\\w+\\s+(\\d{4})',
                1
              ) AS INT)
      ELSE NULL
    END AS doc_stated_age
  FROM cleaned_transcripts_base
),

marriage_years AS (
  SELECT person_gedcom_id, event_year_parsed AS marriage_year
  FROM genealogy.gold_person_event_timeline
  WHERE event_type = 'MARR' AND event_year_parsed IS NOT NULL
),

candidate_counts AS (
  SELECT t.file_id, COUNT(DISTINCT p.person_gedcom_id) AS candidate_count
  FROM cleaned_transcripts t
  JOIN genealogy.gold_person_life p
    ON UPPER(TRIM(t.surname)) = UPPER(TRIM(p.surname))
   AND (
     UPPER(TRIM(t.forename_clean)) = UPPER(TRIM(p.given_name))
     -- BUG-001 fix C: match any token in given_name, not just the first, so
     -- someone known by a middle name (e.g. "Eileen Mary" as "Mary") isn't
     -- silently excluded from the candidate pool.
     OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(p.given_name)), ' '), UPPER(TRIM(t.forename_clean)))
   )
  GROUP BY t.file_id
  UNION
  SELECT t.file_id, COUNT(DISTINCT a.person_gedcom_id) AS candidate_count
  FROM cleaned_transcripts t
  JOIN genealogy.silver_person_alias a
    ON UPPER(TRIM(t.surname)) = UPPER(TRIM(a.alias_surname))
   AND (
     UPPER(TRIM(t.forename_clean)) = UPPER(TRIM(a.alias_given_name))
     OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(a.alias_given_name)), ' '), UPPER(TRIM(t.forename_clean)))
   )
  GROUP BY t.file_id
),

candidate_counts_agg AS (
  SELECT file_id, SUM(candidate_count) AS candidate_count
  FROM candidate_counts
  GROUP BY file_id
),

primary_matches AS (
  SELECT
    t.file_id, t.file_name, t.doc_type_detected, t.year, t.doc_stated_age,
    p.person_gedcom_id,
    TRIM(p.given_name) || ' ' || TRIM(p.surname) AS display_name,
    p.birth_date, p.death_date,
    FALSE AS matched_via_alias,
    -- Suffix awareness (Sr/Jr): direct name matches carry no suffix guarantee —
    -- only a DOCUMENT_NAME alias whose suffix matches the filename counts as
    -- suffix_constrained (see alias_matches below).
    FALSE AS suffix_constrained
  FROM cleaned_transcripts t
  JOIN genealogy.gold_person_life p
    ON UPPER(TRIM(t.surname)) = UPPER(TRIM(p.surname))
   AND (
     UPPER(TRIM(t.forename_clean)) = UPPER(TRIM(p.given_name))
     OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(p.given_name)), ' '), UPPER(TRIM(t.forename_clean)))
   )
),

alias_matches AS (
  SELECT
    t.file_id, t.file_name, t.doc_type_detected, t.year, t.doc_stated_age,
    a.person_gedcom_id,
    pl.given_name || ' ' || pl.surname || ' (matched via ' || a.alias_type || ': ' || a.alias_surname || ')' AS display_name,
    pl.birth_date, pl.death_date,
    TRUE AS matched_via_alias,
    -- suffix_constrained=TRUE only when the alias carries an explicit suffix
    -- requirement (DOCUMENT_NAME rows with alias_suffix set) that the filename's
    -- own suffix satisfied — ranked above every other candidate below, since it's
    -- the strongest, most specific signal available (the document's own filename
    -- naming a particular generation).
    (a.alias_suffix IS NOT NULL) AS suffix_constrained
  FROM cleaned_transcripts t
  JOIN genealogy.silver_person_alias a
    ON UPPER(TRIM(t.surname)) = UPPER(TRIM(a.alias_surname))
   AND (
     UPPER(TRIM(t.forename_clean)) = UPPER(TRIM(a.alias_given_name))
     OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(a.alias_given_name)), ' '), UPPER(TRIM(t.forename_clean)))
   )
   -- When the alias has a suffix constraint, require it to match the doc's own
   -- suffix (case-insensitive, handles Jr/Jnr/Sr/Snr). NULL alias_suffix = no
   -- constraint = always passes (MARRIED_NAME/FATHER_SURNAME aliases, unaffected).
   AND (
     a.alias_suffix IS NULL
     OR UPPER(TRIM(a.alias_suffix)) = UPPER(TRIM(t.forename_suffix))
   )
  JOIN genealogy.gold_person_life pl ON a.person_gedcom_id = pl.person_gedcom_id
),

all_matches AS (
  SELECT * FROM primary_matches
  UNION ALL
  SELECT * FROM alias_matches
),

scored_matches_raw AS (
  SELECT
    m.file_id, m.file_name, m.person_gedcom_id, m.display_name, m.matched_via_alias, m.suffix_constrained,
    cc.candidate_count,
    COALESCE(ap.ancestral_proximity, 9999) AS ancestral_proximity,
    ap.person_id IS NOT NULL               AS is_ancestor,
    -- BUG-001 fix A: when death_date is NULL, cap the upper bound at birth_date+110y
    -- instead of leaving it unbounded — an unresolved "brick wall" ancestor with no
    -- death_date would otherwise vacuously match any future document year.
    -- Year fix: ocr_transcriptions.year is sometimes a full "YYYY-MM-DD" string
    -- rather than a bare year (confirmed: 93/1002 rows) — TRY_CAST(... AS INT)
    -- silently returns NULL on those, which was quietly disabling year_plausible
    -- AND doc_type_affinity for every candidate on that file (nobody could ever
    -- score a match, so the tie-fallback admitted everyone). Taking just the
    -- leading 4 digits fixes both formats.
    (m.birth_date IS NULL OR TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) >= YEAR(m.birth_date) - 2)
      AND (
        -- BUG-002 fix (2026-09-15): NewspaperClipping documents can legitimately
        -- postdate death by years or decades -- obituaries, memorial notices,
        -- estate-sale auctions -- so no upper bound applies to this doc type;
        -- only the birth-side lower bound above still applies. Confirmed via
        -- Thomas Thorpe's 1894 estate-sale clipping, 6 years after his 1888
        -- death (Asana 1218488426839724 / 1218506783096280).
        -- NOTE: Probate/Will were considered for the same exemption (per the
        -- Asana task's proposed wording) but reverted after live validation
        -- found it breaks currently-correct matches -- e.g. CORNER_John_1760_
        -- Will.jpg: without an upper bound, a John Corner who died in 1742 (18
        -- years before this 1760 document) became "plausible" alongside the
        -- correct b.1759 candidate, turning 4 previously-clean Corner/Cope
        -- Will matches into new LOW-confidence ties. Unlike NewspaperClipping,
        -- no live Probate/Will case actually needed this exemption -- only
        -- Thorpe's NewspaperClipping did -- so the scope stays to what was
        -- observed and verified, not the broader original wording.
        m.doc_type_detected = 'NewspaperClipping'
        OR (m.death_date IS NOT NULL AND TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) <= YEAR(m.death_date) + 2)
        OR (m.death_date IS NULL AND m.birth_date IS NOT NULL
              AND TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) <= YEAR(m.birth_date) + 110)
        OR (m.death_date IS NULL AND m.birth_date IS NULL)
      )
                                           AS year_plausible,
    CASE
      WHEN m.doc_type_detected IN ('BirthCertificate','BaptismRegister')
        AND m.birth_date IS NOT NULL
        AND ABS(TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) - YEAR(m.birth_date)) <= 2  THEN 0
      WHEN m.doc_type_detected IN ('BirthCertificate','BaptismRegister')
        AND m.birth_date IS NOT NULL
        AND ABS(TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) - YEAR(m.birth_date)) <= 5  THEN 1
      -- Will added alongside DeathCertificate/Probate: in this corpus a Will is
      -- filed under the year it was administered/relevant to the estate, which
      -- in practice sits close to the testator's death (same ±2/±5 tolerance).
      WHEN m.doc_type_detected IN ('DeathCertificate','Probate','Will')
        AND m.death_date IS NOT NULL
        AND ABS(TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) - YEAR(m.death_date)) <= 2  THEN 0
      WHEN m.doc_type_detected IN ('DeathCertificate','Probate','Will')
        AND m.death_date IS NOT NULL
        AND ABS(TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) - YEAR(m.death_date)) <= 5  THEN 1
      WHEN m.doc_type_detected = 'MarriageCertificate'
        AND EXISTS (
          SELECT 1 FROM marriage_years my
          WHERE my.person_gedcom_id = m.person_gedcom_id
            AND ABS(TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) - my.marriage_year) <= 2
        )                                                            THEN 0
      -- BUG-001 fix B (extended): age-based scoring using doc_stated_age extracted
      -- above, now covering Census/BurialRegister/MonumentalInscription/
      -- NewspaperClipping/MilitaryRecord. Implied birth year = doc year - stated
      -- age, compared against the candidate's actual birth_date.
      WHEN m.doc_type_detected IN ('Census','BurialRegister','MonumentalInscription','NewspaperClipping','MilitaryRecord')
        AND m.doc_stated_age IS NOT NULL
        AND m.birth_date IS NOT NULL
        AND ABS((TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) - m.doc_stated_age) - YEAR(m.birth_date)) <= 2 THEN 0
      WHEN m.doc_type_detected IN ('Census','BurialRegister','MonumentalInscription','NewspaperClipping','MilitaryRecord')
        AND m.doc_stated_age IS NOT NULL
        AND m.birth_date IS NOT NULL
        AND ABS((TRY_CAST(SUBSTR(m.year, 1, 4) AS INT) - m.doc_stated_age) - YEAR(m.birth_date)) <= 5 THEN 1
      ELSE 2
    END AS doc_type_affinity
  FROM all_matches m
  JOIN candidate_counts_agg cc ON m.file_id = cc.file_id
  LEFT JOIN genealogy.gold_ancestral_proximity ap ON m.person_gedcom_id = ap.person_id
  WHERE NOT EXISTS (
    SELECT 1 FROM genealogy.silver_document_person sdp WHERE sdp.file_id = m.file_id
  )
),

-- Multi-page fix: a multi-page document (page_index > 1 in ocr_transcriptions)
-- produces one cleaned_transcripts row per page, so a candidate matching the same
-- name on every page ends up as multiple identical-looking rows here. Left alone,
-- COUNT(*) below would count those duplicate pages as if they were competing
-- candidates, wrongly flagging a clean single-candidate file as a tie. Collapse
-- back to one row per (file_id, person_gedcom_id, matched_via_alias,
-- suffix_constrained), taking the best evidence seen on any page: TRUE wins for
-- year_plausible, the lowest (best) doc_type_affinity wins.
scored_matches AS (
  SELECT
    file_id, file_name, person_gedcom_id, display_name, matched_via_alias, suffix_constrained,
    candidate_count, ancestral_proximity, is_ancestor,
    MAX(year_plausible) AS year_plausible,
    MIN(doc_type_affinity) AS doc_type_affinity
  FROM scored_matches_raw
  GROUP BY file_id, file_name, person_gedcom_id, display_name, matched_via_alias, suffix_constrained,
           candidate_count, ancestral_proximity, is_ancestor
),

ranked AS (
  SELECT
    *,
    ROW_NUMBER() OVER (
      PARTITION BY file_id
      ORDER BY
        -- Suffix-aware fix: a filename-confirmed Sr/Jr alias outranks everything
        -- else, including ancestor status — it's a direct statement from the
        -- document itself about which generation it concerns.
        suffix_constrained DESC,
        is_ancestor DESC,
        doc_type_affinity ASC,
        ancestral_proximity ASC,
        year_plausible DESC,
        person_gedcom_id ASC
    ) AS rank,
    -- BUG-001 fix D: size of the tie group sharing the best score on every criterion
    -- above (excluding the arbitrary person_gedcom_id sort). Used below to flag
    -- genuine remaining ties as LOW confidence instead of silently picking one.
    COUNT(*) OVER (
      PARTITION BY file_id, suffix_constrained, is_ancestor, doc_type_affinity, ancestral_proximity, year_plausible
    ) AS tie_group_size
  FROM scored_matches
  -- BUG-002 fix (2026-09-15): removed the old `OR NOT EXISTS (... a plausible
  -- row for this file ...)` fallback. That fallback forced a pick from the
  -- implausible-year candidates whenever ZERO candidates for a file were
  -- year-plausible, instead of leaving the file unmatched -- confirmed live as
  -- the root cause of the Elizabeth Balls and Henry Easter wrong-person matches
  -- (Asana 1218488426839724). A file with no year-plausible candidate now simply
  -- gets no row here (and so no INSERT below) -- Cell 6 (the unmatched-file
  -- diagnostic, further down this notebook) persists it to
  -- silver_document_match_exception for manual review instead. Asana 1218506594311016.
  WHERE year_plausible = TRUE
)

INSERT INTO genealogy.silver_document_person
  (file_id, file_name, person_gedcom_id, display_name,
   match_method, match_confidence, candidate_count, notes, matched_at)
SELECT
  file_id, file_name, person_gedcom_id, display_name,
  CASE
    WHEN candidate_count = 1 AND NOT matched_via_alias THEN 'EXACT'
    WHEN candidate_count = 1 AND matched_via_alias     THEN 'EXACT_ALIAS'
    WHEN matched_via_alias                             THEN 'EXACT_MULTI_ALIAS'
    ELSE                                                    'EXACT_MULTI'
  END AS match_method,
  CASE
    -- BUG-001 fix D: a genuine remaining tie is always LOW, checked before the
    -- ancestor/rank branches below so a tie among ancestors doesn't get masked as MEDIUM.
    WHEN tie_group_size > 1                            THEN 'LOW'
    WHEN candidate_count = 1 AND is_ancestor           THEN 'HIGH'
    WHEN candidate_count = 1                           THEN 'MEDIUM'
    WHEN is_ancestor AND ancestral_proximity = 0
      AND doc_type_affinity = 0                        THEN 'HIGH'
    WHEN is_ancestor AND rank = 1                      THEN 'MEDIUM'
    ELSE                                                    'LOW'
  END AS match_confidence,
  candidate_count,
  CONCAT_WS(' | ',
    CASE WHEN candidate_count > 1 THEN CONCAT(candidate_count, ' candidates') ELSE NULL END,
    CASE WHEN is_ancestor THEN CONCAT('ancestor proximity=', ancestral_proximity) ELSE 'non-ancestor' END,
    CASE WHEN doc_type_affinity < 2 THEN CONCAT('doc_type_affinity=', doc_type_affinity) ELSE NULL END,
    CASE WHEN matched_via_alias THEN 'matched via alias' ELSE NULL END,
    CASE WHEN suffix_constrained THEN 'suffix matched' ELSE NULL END,
    CASE WHEN tie_group_size > 1
      THEN CONCAT('TIE: ', tie_group_size, ' candidates equally plausible, needs manual review')
      ELSE NULL END
  ) AS notes,
  CURRENT_TIMESTAMP()
FROM ranked
WHERE rank = 1;

-- %%
-- %sql
-- Summary of match results
SELECT match_confidence, match_method, COUNT(*) AS n
FROM genealogy.silver_document_person
GROUP BY match_confidence, match_method
ORDER BY n DESC;

-- %% [markdown]
-- ## Cell 5b - Spouse inference for marriage certificates

-- %%
-- Insert spouse rows for marriage certificates already matched to the primary person.
-- Joins silver_family in both directions to find the spouse, then guards on the
-- certificate year being within ±2 of that specific family unit's marriage year —
-- preventing a second-marriage cert being linked to the wrong spouse.

INSERT INTO genealogy.silver_document_person
  (file_id, file_name, person_gedcom_id, display_name,
   match_method, match_confidence, candidate_count, notes, matched_at)

WITH

-- Marriage certificates already matched to their primary person
matched_marriages AS (
  SELECT sdp.file_id, sdp.file_name, sdp.person_gedcom_id AS primary_person_id
  FROM genealogy.silver_document_person sdp
  JOIN genealogy.ocr_transcriptions ot ON sdp.file_id = ot.file_id
  WHERE ot.doc_type_detected = 'MarriageCertificate'
),

-- Find the spouse for each primary person via silver_family (both directions)
-- and pull the marriage year for that specific family unit
spouse_candidates AS (
  SELECT
    mm.file_id,
    mm.file_name,
    mm.primary_person_id,
    CASE
      WHEN sf.husband_gedcom_id = mm.primary_person_id THEN sf.wife_gedcom_id
      ELSE sf.husband_gedcom_id
    END AS spouse_gedcom_id,
    sf.family_gedcom_id
  FROM matched_marriages mm
  JOIN genealogy.silver_family sf
    ON sf.husband_gedcom_id = mm.primary_person_id
    OR sf.wife_gedcom_id    = mm.primary_person_id
  WHERE sf.relationship_type IS NULL  -- exclude non-marriage partnerships
),

-- Guard: certificate year must be within ±2 of this family unit's marriage year.
-- Uses the spouse's own MARR event to get the year for this specific family unit,
-- avoiding cross-contamination when either party had multiple marriages.
spouse_with_year_guard AS (
  -- DISTINCT: gold_person_event_timeline has duplicate MARR rows for the same
  -- person+year in 36 known cases (same marriage recorded twice, e.g. with
  -- different place-string granularity) -- without it, each duplicate event
  -- row fans this join out into a second identical spouse-inference row for
  -- the same file_id (confirmed: SIDDAL_William_1779_Marriage.jpg -> Sarah
  -- Marsden was inserted twice before this fix).
  SELECT DISTINCT sc.file_id, sc.file_name, sc.spouse_gedcom_id
  FROM spouse_candidates sc
  JOIN genealogy.gold_person_event_timeline et
    ON  et.person_gedcom_id = sc.spouse_gedcom_id
    AND et.event_type       = 'MARR'
    AND et.event_year_parsed IS NOT NULL
  JOIN genealogy.ocr_transcriptions ot ON sc.file_id = ot.file_id
  WHERE ABS(TRY_CAST(ot.year AS INT) - et.event_year_parsed) <= 2
)

SELECT
  sg.file_id,
  sg.file_name,
  sg.spouse_gedcom_id                              AS person_gedcom_id,
  pl.given_name || ' ' || pl.surname               AS display_name,
  'SPOUSE_INFERENCE'                               AS match_method,
  'HIGH'                                           AS match_confidence,
  1                                                AS candidate_count,
  'Spouse inferred from marriage certificate match' AS notes,
  CURRENT_TIMESTAMP()
FROM spouse_with_year_guard sg
JOIN genealogy.gold_person_life pl ON sg.spouse_gedcom_id = pl.person_gedcom_id
WHERE NOT EXISTS (
  SELECT 1 FROM genealogy.silver_document_person sdp
  WHERE sdp.file_id = sg.file_id
    AND sdp.person_gedcom_id = sg.spouse_gedcom_id
);

-- %% [markdown]
-- ## Cell 5c — Resolve remaining ties via sibling-document consensus
--
-- If Cell 5's own scoring still leaves a file LOW/tied, check whether other files filed under the exact same name (surname, forename, and Sr/Jr suffix presence) already resolved confidently (HIGH/MEDIUM, non-manual) to one single person. Unanimous agreement among those siblings is taken as the answer; a split vote changes nothing and the file stays LOW for manual review.

-- %%
-- %sql
-- Cell 5c — Resolve remaining ties via sibling-document consensus
-- A file Cell 5 still couldn't resolve on its own (match_confidence = LOW) may
-- still be resolvable indirectly: other files filed under the exact same name
-- (same surname, same forename once suffix-stripped, same suffix presence/
-- absence -- so a "(Sr)" cluster is never mixed with an unsuffixed one) were
-- independently and confidently matched (HIGH/MEDIUM, and not from a manual
-- override or a SPOUSE_INFERENCE row -- see below -- to avoid circularity) to
-- one single person. If every one of those
-- confident siblings agrees, that consensus is a safer answer than the arbitrary
-- tiebreak Cell 5 would otherwise fall back on. A split vote among siblings
-- changes nothing -- the file stays LOW for manual review.
--
-- BUG-003 fix (2026-09-15): sibling agreement alone isn't enough -- this file
-- still has to be chronologically possible for the consensus person. Previously
-- there was no such check at all, so a file could be handed a consensus person
-- who wasn't even born yet: Henry Easter's 1828 marriage doc (he's recorded as
-- a widower remarrying, i.e. an adult) was resolved to a person born 1832,
-- purely because two OTHER "Henry Easter" files -- an 1841 census and an 1848
-- burial belonging to a *different*, same-named relative (his father, as it
-- turned out) -- had confidently matched that person. Same widened Probate/
-- Will/NewspaperClipping upper-bound exemption as Cell 5 -- a sibling-
-- consensus estate-sale/obituary clipping can legitimately postdate death
-- (Thomas Thorpe's 1894 clipping, 6yrs after his 1888 death, must still pass).
-- A file whose year fails this check for the consensus person keeps its
-- pre-consensus LOW row untouched and is logged to
-- silver_document_match_exception instead. Asana 1218506594311016.

CREATE OR REPLACE TEMP VIEW v_5c_consensus_scored AS
WITH cleaned_transcripts AS (
  SELECT
    file_id,
    UPPER(TRIM(surname)) AS surname_key,
    -- Same trailing-annotation strip as Cell 5's forename_clean (BUG-005,
    -- 2026-09-16), so a sibling group keys on the same cleaned forename.
    UPPER(TRIM(REGEXP_REPLACE(
      TRIM(REGEXP_REPLACE(forename, '\\s*\\(?(Jr|Sr|Jnr|Snr|Uncle)\\.?\\)?\\s*$', '')),
      '\\s*\\([^)]*\\)\\s*$', ''
    ))) AS forename_key,
    COALESCE(UPPER(TRIM(REGEXP_EXTRACT(forename, '\\(?(Jr|Sr|Jnr|Snr|Uncle)\\.?\\)?\\s*$'))), '') AS suffix_key
  FROM genealogy.ocr_transcriptions
),

tied_files AS (
  SELECT sdp2.file_id, ct.surname_key, ct.forename_key, ct.suffix_key
  FROM genealogy.silver_document_person sdp2
  JOIN cleaned_transcripts ct ON sdp2.file_id = ct.file_id
  WHERE sdp2.match_confidence = 'LOW' AND sdp2.match_method != 'MANUAL'
),

sibling_matches AS (
  SELECT DISTINCT
    tf.file_id, sdp3.person_gedcom_id, ct2.file_id AS sibling_file_id
  FROM tied_files tf
  JOIN cleaned_transcripts ct2
    ON  ct2.surname_key = tf.surname_key
    AND ct2.forename_key = tf.forename_key
    AND ct2.suffix_key = tf.suffix_key
    AND ct2.file_id != tf.file_id
  JOIN genealogy.silver_document_person sdp3
    ON sdp3.file_id = ct2.file_id
   AND sdp3.match_confidence IN ('HIGH', 'MEDIUM')
   -- A marriage certificate file gets a second silver_document_person row
   -- for the inferred spouse (Cell 5b) -- a different person on the SAME
   -- file_id. Left in, that row would count as a second, disagreeing
   -- "sibling" vote for the very name being resolved, since the join below
   -- is keyed on file_id sharing the same name, not on which row of a
   -- multi-row file matches it. Excluding SPOUSE_INFERENCE keeps the vote
   -- restricted to rows that are actually about the named person.
   AND sdp3.match_method NOT IN ('MANUAL', 'SPOUSE_INFERENCE')
),

consensus AS (
  SELECT file_id,
    COUNT(DISTINCT sibling_file_id) AS sibling_count,
    MIN(person_gedcom_id)           AS consensus_person
  FROM sibling_matches
  GROUP BY file_id
  HAVING COUNT(DISTINCT person_gedcom_id) = 1
),

-- BUG-004 fix (2026-09-15, caught in production): ocr_transcriptions has one
-- row per PAGE, not per file (see Cell 5's "Multi-page fix" note) -- joining
-- straight to it here produced multiple output rows per file_id for any
-- multi-page document, which then made the MERGE below fail with
-- DELTA_MULTIPLE_SOURCE_ROW_MATCHING_TARGET_ROW_IN_MERGE (confirmed live:
-- up to 10 ocr_transcriptions rows for a single file_id). year/doc_type/
-- surname/forename are the same across every page of one document, so a
-- single representative row per file_id is enough here.
file_meta AS (
  SELECT file_id,
    MIN(file_name) AS file_name, MIN(doc_type_detected) AS doc_type_detected,
    MIN(year) AS year, MIN(surname) AS surname, MIN(forename) AS forename
  FROM genealogy.ocr_transcriptions
  GROUP BY file_id
)

SELECT
  c.file_id, c.consensus_person, c.sibling_count,
  pl.given_name || ' ' || pl.surname AS display_name,
  ot.file_name, ot.doc_type_detected, ot.year, ot.surname, ot.forename,
  (pl.birth_date IS NULL OR TRY_CAST(SUBSTR(ot.year, 1, 4) AS INT) >= YEAR(pl.birth_date) - 2)
    AND (
      ot.doc_type_detected = 'NewspaperClipping'  -- see Cell 5's BUG-002 fix note: Probate/Will exemption reverted, NewspaperClipping-only
      OR (pl.death_date IS NOT NULL AND TRY_CAST(SUBSTR(ot.year, 1, 4) AS INT) <= YEAR(pl.death_date) + 2)
      OR (pl.death_date IS NULL AND pl.birth_date IS NOT NULL
            AND TRY_CAST(SUBSTR(ot.year, 1, 4) AS INT) <= YEAR(pl.birth_date) + 110)
      OR (pl.death_date IS NULL AND pl.birth_date IS NULL)
    )                                                   AS year_plausible
FROM consensus c
JOIN genealogy.gold_person_life pl ON c.consensus_person = pl.person_gedcom_id
JOIN file_meta ot ON ot.file_id = c.file_id;

MERGE INTO genealogy.silver_document_person sdp
USING (
  SELECT file_id, consensus_person, sibling_count, display_name
  FROM v_5c_consensus_scored
  WHERE year_plausible
) src
ON sdp.file_id = src.file_id
WHEN MATCHED THEN UPDATE SET
  sdp.person_gedcom_id = src.consensus_person,
  sdp.display_name     = src.display_name,
  sdp.match_method      = 'SIBLING_CONSENSUS',
  sdp.match_confidence  = 'MEDIUM',
  sdp.notes             = CONCAT('Resolved via ', src.sibling_count, ' other confidently-matched document(s) filed under the same name'),
  sdp.matched_at        = CURRENT_TIMESTAMP();

-- BUG-003 fix: sibling consensus existed but failed the year check above --
-- leave the file at its pre-consensus LOW row (untouched) and log the rejected
-- consensus attempt for manual review instead of silently applying it.
INSERT INTO genealogy.silver_document_match_exception
  (file_id, file_name, doc_type_detected, year, surname, forename,
   candidate_count, reason, candidates_considered, logged_at)
SELECT
  file_id, file_name, doc_type_detected, year, surname, forename,
  NULL,
  'SIBLING_CONSENSUS_YEAR_IMPLAUSIBLE',
  CONCAT(consensus_person, ' (', display_name, ') via ', sibling_count,
         ' sibling document(s) -- rejected: implausible for this file''s own year'),
  CURRENT_TIMESTAMP()
FROM v_5c_consensus_scored
WHERE NOT year_plausible;

-- Verify: overall confidence/method breakdown after consensus resolution
SELECT match_confidence, match_method, COUNT(*) AS n
FROM genealogy.silver_document_person
GROUP BY match_confidence, match_method
ORDER BY n DESC;

-- %% [markdown]
-- ## Cell 5d — Sync gold_transcript_facts.person_gedcom_id after a match correction
--
-- gold_transcript_facts.person_gedcom_id is copied from silver_document_person by notebook_02_fact_extraction.py at extraction time. That notebook only processes files with no existing gold_transcript_facts row (a NOT EXISTS guard), so it never revisits a file once extracted — a later correction to silver_document_person (a new override, or an algorithm re-run) leaves the old person_gedcom_id behind. No re-extraction (and no Gemini call) is needed to fix this: the extracted fact_type/fact_value pairs are unchanged, only the foreign key needs to catch up.
--
-- Skips file_ids with more than one silver_document_person row (marriage certificates with an inferred spouse row, from Cell 5b) since gold_transcript_facts doesn't record which of the two people a given fact belongs to — safer to leave those for manual review than guess.

-- %%
-- %sql
-- Cell 5d — Sync gold_transcript_facts.person_gedcom_id after a match correction
MERGE INTO genealogy.gold_transcript_facts gtf
USING (
  SELECT file_id, MIN(person_gedcom_id) AS person_gedcom_id
  FROM genealogy.silver_document_person
  GROUP BY file_id
  HAVING COUNT(*) = 1
) sdp
ON gtf.file_id = sdp.file_id
WHEN MATCHED AND gtf.person_gedcom_id <> sdp.person_gedcom_id THEN
  UPDATE SET gtf.person_gedcom_id = sdp.person_gedcom_id;

-- Verify: 0 expected — any remaining mismatch means a single-mapping file didn't sync
SELECT COUNT(*) AS remaining_stale_single_mapping_facts
FROM genealogy.gold_transcript_facts gtf
JOIN (
  SELECT file_id, MIN(person_gedcom_id) AS person_gedcom_id
  FROM genealogy.silver_document_person
  GROUP BY file_id
  HAVING COUNT(*) = 1
) sdp ON gtf.file_id = sdp.file_id
WHERE gtf.person_gedcom_id <> sdp.person_gedcom_id;

-- %% [markdown]
-- ## Cell 5e — Household member inference from `silver_transcript_person_mention` (v2)
--
-- **Redesign, Session 69 -> 70.** The original Cell 5e (paused, never merged) tried
-- to infer household members — spouse, children — beyond a document's single
-- matched primary person by parsing `ocr_transcriptions.personal_names`/
-- `transcribed_text` directly. That kept surfacing new edge cases (name-token
-- order varying by document type, the historical ditto-mark convention,
-- spurious digit matches from unrelated table columns) because it had to
-- reverse-engineer table structure from flat OCR text after the fact. Ed's
-- manual spot-check of the v1 output against source images found real false
-- positives (same-name generational collisions, a daughter matched instead of
-- the correct spouse via a colliding married-name alias) alongside real misses.
--
-- The fix agreed in the design session that followed: restructure the
-- transcript into per-person records *at extraction time* — `silver_transcript_person_mention`
-- (one row per person mentioned in a document, `role_in_record` a controlled
-- vocabulary, ditto marks and word-order already resolved, name normalised to
-- Forename-first) — then match from that structured table instead of flat
-- text. This cell is the redesign; it replaces v1's SQL entirely.
--
-- **Scope decision for this pass (handover flagged as open, resolved here):**
-- only match mentions whose `role_in_record` maps directly to a structural
-- family relation already derivable via `silver_family`/`silver_family_child`
-- — Wife/Husband -> SPOUSE, Son/Daughter/Child -> CHILD, Father/Mother -> PARENT.
-- `Head` is skipped (it is the document's own already-matched primary in
-- every test case). Will/Probate roles (Testator, Executor, Legatee, Witness)
-- are deliberately **not** attempted this pass — the document's `detail` text
-- sometimes states the real family relation ("son of testator") but that is
-- free text, and parsing it back out reintroduces exactly the flat-text
-- fragility this redesign exists to remove; several legatees/witnesses in the
-- test corpus (e.g. Harry and Edith Harriss, "for help and kindness") are not
-- tree relatives at all. Revisit as a separate, deliberate piece of work if
-- that coverage is wanted — see Asana 1218641074662915.
--
-- **Disambiguation design.** A household role's name is checked only against
-- the correspondingly-typed candidate pool (a `Wife` mention only against the
-- primary's SPOUSE candidates, never CHILD/PARENT) — this alone resolves the
-- generational-collision failure mode v1 hit (father vs son sharing a name
-- sit in different pools). A candidate must additionally have been alive at
-- the document's year (`birth_year` <= doc year <= `death_year`) — a loose
-- sanity gate, not an age match: self-reported ages on historical census
-- forms are commonly imprecise by several years, so requiring every match to
-- land within a tight age tolerance rejected genuine matches during
-- validation (Robert Warrington's actual wife's stated census age was 10
-- years off her true birth year). Age/DOB proximity (`age_years` for
-- standard census rows, the full year parsed from `dob_raw` for the 1939
-- Register, which records exact dates rather than ages) is used only as a
-- **tie-breaker** when more than one candidate in the same pool shares a
-- mention's exact name — the same-forename same-role case a same-name
-- sibling pair would produce.
--
-- **Validated 2026-09-18 against all 11 documents in `silver_transcript_person_mention`**
-- (pre-scaling test corpus, Asana 1218641074662915) before shipping:
-- - WARRINGTON_Robert_1851_Census (20-row, 4-household page) — matches only
--   Robert's real spouse (Ann Cooper) and 2 real children, zero leakage from
--   the other 3 unrelated households on the same page. Reproduces the
--   Session 69 result for this file without regressing it.
-- - The two "Ann Warrington" mentions (Wife age 55 vs Daughter age 22,
--   identical name) resolve correctly without needing the age tie-breaker at
--   all — `role_in_record` alone separates them into the SPOUSE and CHILD
--   pools.
-- - PEARSON_Alfred_1939_Register / EASTER_Sunny_1939_Register — both match
--   correctly (spouse + child) despite `role_in_record` being inferred
--   rather than stated (`confidence: medium` in the source table) — the
--   matcher does not require role certainty, only a role assignment to
--   filter against.
-- - The two-Charles-Edward-Ball collision (1934 testator vs his own son,
--   1971 executor) does not arise, by construction — both mentions carry a
--   Will-only role (Testator/Executor) excluded from this pass's scope.
--
-- Confidence stays MEDIUM, not HIGH, same reasoning as v1: household
-- membership on a census/register page is not structurally guaranteed the
-- way a marriage certificate's spouse is. `match_method` is
-- `HOUSEHOLD_INFERENCE_V2` so these rows are distinguishable from any v1
-- row still in the table (none currently — v1 was never run against
-- production).

-- %%
-- %sql
-- Cell 5e — Household member inference from silver_transcript_person_mention (v2)
INSERT INTO genealogy.silver_document_person
  (file_id, file_name, person_gedcom_id, display_name,
   match_method, match_confidence, candidate_count, notes, matched_at)

WITH

-- Files already matched to a primary person, with that document's year
-- Restricted to the TRUE primary match only (Cell 5/5b/5c's own methods).
-- Bug found live this session: without this filter, once Cell 5g/5h/5f have
-- written their own inferred rows to silver_document_person, a later cell
-- re-deriving matched_docs from the same table picks those rows up as if
-- they were additional "primaries" too -- e.g. after Cell 5g matched Clara
-- as Executor (SPOUSE relation) on Charles Edward Ball's 1934 will, Cell 5h
-- treated CLARA as a second primary and computed her own SIBLING (Samuel
-- Mattock) as if he were related to Charles Edward Ball directly -- silently
-- causing Cell 5h to skip its whole-tree fallback for him, thinking Cell 5g
-- had already covered it. Excluding this session's two new match_methods
-- keeps every cell's candidate pool anchored to the one true primary.
matched_docs AS (
  SELECT sdp.file_id, sdp.person_gedcom_id AS primary_person_id, ot.year, ot.file_name
  FROM genealogy.silver_document_person sdp
  JOIN genealogy.ocr_transcriptions ot ON ot.file_id = sdp.file_id
  WHERE sdp.file_id IN (SELECT DISTINCT file_id FROM genealogy.silver_transcript_person_mention)
    AND sdp.match_method NOT IN ('HOUSEHOLD_INFERENCE_V2', 'WHOLE_TREE_NAME_MATCH')
  GROUP BY sdp.file_id, sdp.person_gedcom_id, ot.year, ot.file_name
),

-- Person-mention rows in scope for this pass: household roles only (see
-- Cell 5e markdown for why Will/Probate roles are deliberately excluded).
-- role_in_record maps to the same SPOUSE/CHILD/PARENT vocabulary
-- silver_family/silver_family_child queries use elsewhere in this notebook.
mentions AS (
  SELECT tpm.file_id, tpm.person_index, tpm.name_raw, tpm.age_years, tpm.dob_raw,
    UPPER(TRIM(REGEXP_EXTRACT(tpm.name_raw, '^(\\S+)', 1))) AS forename_first,
    UPPER(TRIM(REGEXP_EXTRACT(tpm.name_raw, '(\\S+)$', 1))) AS surname_last,
    CASE
      WHEN tpm.role_in_record IN ('Wife', 'Husband') THEN 'SPOUSE'
      WHEN tpm.role_in_record IN ('Son', 'Daughter', 'Child') THEN 'CHILD'
    END AS mapped_relation,
    -- dob_raw is a full transcribed date (e.g. "29 Dec 1903") -- the 1939
    -- Register records exact DOB instead of age, so this is the only
    -- birth-year signal available for those rows.
    TRY_CAST(REGEXP_EXTRACT(tpm.dob_raw, '(\\d{4})$', 1) AS INT) AS dob_year
  FROM genealogy.silver_transcript_person_mention tpm
  JOIN (SELECT DISTINCT file_id, doc_type_detected FROM genealogy.ocr_transcriptions) ot2
    ON ot2.file_id = tpm.file_id
  WHERE tpm.role_in_record IN ('Wife', 'Husband', 'Son', 'Daughter', 'Child')
    -- Cell 5f role-expansion brief: Cell 5b's marriage-certificate spouse
    -- inference is structurally unambiguous (the second party comes straight
    -- from silver_family, no OCR dependency) and more reliable than reading a
    -- name off the document for that one doc type -- running both risks
    -- duplicate/conflicting rows. Scoped to MarriageCertificate + Spouse only;
    -- every other doc type's spouse matching here is unaffected.
    AND NOT (tpm.role_in_record IN ('Wife', 'Husband') AND ot2.doc_type_detected = 'MarriageCertificate')
),

-- Structurally known relatives of the matched primary person: spouse,
-- children, parents. Same three-way pattern used elsewhere in this notebook.
relatives AS (
  SELECT md.file_id, md.year, md.primary_person_id,
    CASE WHEN sf.husband_gedcom_id = md.primary_person_id THEN sf.wife_gedcom_id ELSE sf.husband_gedcom_id END AS relative_id,
    'SPOUSE' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family sf
    ON sf.husband_gedcom_id = md.primary_person_id OR sf.wife_gedcom_id = md.primary_person_id
  WHERE sf.relationship_type IS NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, fc.child_gedcom_id AS relative_id, 'CHILD' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family sf
    ON sf.husband_gedcom_id = md.primary_person_id OR sf.wife_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc ON fc.family_gedcom_id = sf.family_gedcom_id
),

relatives_named AS (
  SELECT DISTINCT r.file_id, r.year, r.relation, r.relative_id,
    COALESCE(pl.given_name, '') AS given_name, COALESCE(pl.surname, '') AS surname,
    pl.birth_year, pl.death_year
  FROM relatives r
  JOIN genealogy.gold_person_life pl ON pl.person_gedcom_id = r.relative_id
  WHERE r.relative_id IS NOT NULL AND r.relative_id != r.primary_person_id
),

-- A relative's own tree name plus any alias (MARRIED_NAME etc.) both get a
-- chance to match -- needed e.g. for a wife recorded under her married
-- surname rather than the tree's maiden-name row.
candidate_names AS (
  SELECT file_id, year, relation, relative_id, birth_year, death_year,
    UPPER(TRIM(REGEXP_EXTRACT(given_name, '^(\\S+)', 1))) AS forename_first, UPPER(TRIM(surname)) AS surname
  FROM relatives_named
  WHERE surname != ''

  UNION ALL

  SELECT rn.file_id, rn.year, rn.relation, rn.relative_id, rn.birth_year, rn.death_year,
    UPPER(TRIM(REGEXP_EXTRACT(a.alias_given_name, '^(\\S+)', 1))) AS forename_first, UPPER(TRIM(a.alias_surname)) AS surname
  FROM relatives_named rn
  JOIN genealogy.silver_person_alias a ON a.person_gedcom_id = rn.relative_id
  WHERE a.alias_surname IS NOT NULL AND a.alias_surname != ''
),

-- A candidate matches a mention only within its own role-mapped pool (a
-- Wife mention never checked against CHILD candidates), and only if alive
-- at the document's year -- a loose plausibility gate, not an age match;
-- see Cell 5e markdown for why a tight age tolerance rejected genuine
-- matches during validation.
candidate_matches AS (
  SELECT DISTINCT c.file_id, c.relation, c.relative_id, c.birth_year,
    m.person_index, m.name_raw,
    CASE
      WHEN m.age_years IS NOT NULL THEN TRY_CAST(SUBSTR(c.year, 1, 4) AS INT) - m.age_years
      WHEN m.dob_year IS NOT NULL THEN m.dob_year
    END AS implied_birth_year
  FROM candidate_names c
  JOIN mentions m
    ON m.file_id = c.file_id
   AND m.mapped_relation = c.relation
   AND m.forename_first = c.forename_first
   AND m.surname_last = c.surname
  WHERE c.birth_year <= TRY_CAST(SUBSTR(c.year, 1, 4) AS INT)
    AND (c.death_year IS NULL OR c.death_year >= TRY_CAST(SUBSTR(c.year, 1, 4) AS INT))
),

-- How many distinct candidates matched each specific mention -- a genuine
-- same-forename-same-role sibling collision (not hit in the validated test
-- corpus, but structurally possible) needs the age/DOB tie-break below;
-- an unambiguous mention (the common case) doesn't.
mention_candidate_counts AS (
  SELECT file_id, person_index, COUNT(DISTINCT relative_id) AS n_candidates
  FROM candidate_matches
  GROUP BY file_id, person_index
),

ranked AS (
  SELECT cm.*, mcc.n_candidates,
    ROW_NUMBER() OVER (
      PARTITION BY cm.file_id, cm.person_index
      ORDER BY ABS(COALESCE(cm.implied_birth_year, cm.birth_year) - cm.birth_year) ASC, cm.relative_id ASC
    ) AS rk
  FROM candidate_matches cm
  JOIN mention_candidate_counts mcc ON mcc.file_id = cm.file_id AND mcc.person_index = cm.person_index
),

-- Collapse to one row per (file, relative) -- a person mentioned more than
-- once in the same document (not seen in the test corpus) would otherwise
-- fan out.
final AS (
  SELECT file_id, relative_id, relation, MIN(person_index) AS person_index
  FROM ranked
  WHERE n_candidates = 1 OR rk = 1
  GROUP BY file_id, relative_id, relation
)

SELECT
  f.file_id,
  md.file_name,
  f.relative_id AS person_gedcom_id,
  pl.given_name || ' ' || pl.surname AS display_name,
  'HOUSEHOLD_INFERENCE_V2' AS match_method,
  'MEDIUM' AS match_confidence,
  1 AS candidate_count,
  CONCAT('Household member (', f.relation, ') matched via silver_transcript_person_mention') AS notes,
  CURRENT_TIMESTAMP()
FROM final f
JOIN matched_docs md ON md.file_id = f.file_id
JOIN genealogy.gold_person_life pl ON pl.person_gedcom_id = f.relative_id
WHERE NOT EXISTS (
  SELECT 1 FROM genealogy.silver_document_person sdp
  WHERE sdp.file_id = f.file_id AND sdp.person_gedcom_id = f.relative_id
);

-- %%
-- %sql
-- Verification: household-inference (v2) rows just added, by relation
SELECT
  REGEXP_EXTRACT(notes, 'Household member \\(([A-Z]+)\\)', 1) AS relation,
  COUNT(*) AS rows_added,
  COUNT(DISTINCT file_id) AS files_affected,
  COUNT(DISTINCT person_gedcom_id) AS distinct_people
FROM genealogy.silver_document_person
WHERE match_method = 'HOUSEHOLD_INFERENCE_V2'
GROUP BY 1
ORDER BY rows_added DESC;

-- Sanity check, expect 0: a household-inference row should never be the
-- only row on a file (it always accompanies the Cell 5 primary match).
SELECT COUNT(*) AS orphaned_household_only_files
FROM (
  SELECT file_id, COUNT(*) AS n,
    SUM(CASE WHEN match_method = 'HOUSEHOLD_INFERENCE_V2' THEN 1 ELSE 0 END) AS n_household
  FROM genealogy.silver_document_person
  GROUP BY file_id
) x
WHERE n_household = n;

-- Sanity check, expect 0: the two-Charles-Edward-Ball collision (task
-- 1218641074662915's reference case) should never resolve both wills'
-- mentions to the same person_gedcom_id, since Will roles are out of scope
-- this pass -- confirms scope is actually being respected, not just that
-- the collision happens not to fire today.
SELECT COUNT(*) AS will_role_rows_incorrectly_matched
FROM genealogy.silver_document_person
WHERE match_method = 'HOUSEHOLD_INFERENCE_V2'
  AND file_id IN ('0B00VuRbH2UFNaWtKWXpxdGdXZlU', '0B00VuRbH2UFNY3IyZlFjbS1UcUk', '11cDZ6oFAHIBD8IGH1VWj8RQIC4FKzPVK');

-- %% [markdown]
-- ## Cell 5f — Role expansion: Tier 1 relations + Tier 2 non-family roles
--
-- **Follow-up to Cell 5e (v2), Session 71 -> 72.** Cell 5e's SPOUSE/CHILD matching
-- is working correctly and is untouched here (aside from one small addition
-- below). This adds the remaining roles from the role-expansion brief:
-- **Parent, Grandparent, Sibling, Grandchild, Witness, Executor, Legatee** —
-- split into two genuinely different matching problems.
--
-- **Tier 1 — blood/family relation roles (Cell 5f code cell below).** Parent,
-- Grandparent, Sibling and Grandchild all have a guaranteed structural
-- candidate pool the same way Spouse/Child already do, via `silver_family`/
-- `silver_family_child` traversal from the primary person. Fixes a real bug
-- found while extending this: Cell 5e's original PARENT branch (`CASE WHEN
-- husband_gedcom_id IS NOT NULL THEN husband_gedcom_id ELSE wife_gedcom_id
-- END`) only ever returned ONE parent per family record, so a document naming
-- the *other* parent could never match — confirmed live (AMBROSE_Sarah
-- Ann_1857_Baptism's Mother row silently had zero candidates under the old
-- logic). Fixed here by emitting both parents as separate candidate rows.
-- Same match_method (`HOUSEHOLD_INFERENCE_V2`) and role/plausibility filtering
-- as Spouse/Child.
--
-- **Tier 2 — non-guaranteed roles (Cell 5g + 5h code cells below).** Witness,
-- Executor and Legatee have no structural candidate pool from the primary
-- person's own family record — often a genuine relative, but just as often a
-- solicitor, neighbour, or unrelated witness. Two-step approach:
-- 1. **Cell 5g** — try the *whole* family candidate pool first (Spouse, Child,
--    Parent, Grandparent, Sibling, Grandchild — any relation, not just one),
--    since many executors/legatees genuinely are close relatives. Still
--    `HOUSEHOLD_INFERENCE_V2`, confidence MEDIUM — notes record which relation
--    actually resolved it (e.g. "Executor matched via CHILD relation").
-- 2. **Cell 5h** — for anyone Cell 5g didn't catch, fall back to a whole-tree
--    name + alive-at-document-year search (the same mechanism Cell 5's own
--    primary matcher uses, applied to a secondary name). New match_method
--    `WHOLE_TREE_NAME_MATCH` since this carries no structural guarantee —
--    confidence MEDIUM with exactly one plausible candidate, LOW (with a TIE
--    note, same convention as Cell 5's own tie handling) when the tree has
--    more than one same-name candidate and nothing distinguishes them.
--
-- **Testator is not a new matching problem.** By definition the Testator on a
-- will *is* the document's own already-matched primary person (Cell 5/5b/5c) —
-- `'Testator'` is deliberately absent from every role filter below, so no row
-- is ever attempted for it.
--
-- **One small addition to Cell 5e**: Wife/Husband mentions are now skipped
-- when `doc_type_detected = 'MarriageCertificate'`, since Cell 5b's existing
-- marriage-certificate spouse inference is structurally unambiguous (the
-- second party comes straight from `silver_family`, no OCR dependency) and
-- more reliable than reading a name off the document for that one case.
-- Scoped to MarriageCertificate + Spouse only — every other doc type's spouse
-- matching is unaffected, and no MarriageCertificate documents exist in
-- `silver_transcript_person_mention` yet, so this has zero effect on the
-- current corpus and only guards against future backfill.
--
-- **Validated against the role-expansion brief's test cases** before shipping
-- (all via live dry-run, matching the exact SQL below): the two-Charles-
-- Edward-Ball collision is now genuinely *resolved*, not just avoided — Clara's
-- 1971 will Executor "Charles Edward Ball" correctly resolves to his own
-- person_gedcom_id (the son, CHILD relation), distinct from his late father's
-- id on the 1934 will (SPOUSE relation, matched to Clara herself as Executor
-- there). Christine Jane Ball (Legatee, granddaughter) resolves via GRANDCHILD.
-- Ronald Ball (Legatee, son) resolves via CHILD. Samuel Mattock (1934 will
-- Witness) correctly resolves via Cell 5h's whole-tree fallback to the *right*
-- one of two same-name tree candidates, purely because the alive-at-1934
-- filter excludes the other (who died in 1922). Joan Margaret Ball (1971 will
-- Executor, relation unstated) correctly surfaces as a genuine LOW-confidence
-- tie — two different real "Joan Margaret Ball"s exist in the tree, one of
-- whom actually is Charles Edward Ball's wife; nothing in the document or tree
-- distinguishes them, so this is flagged for manual review rather than guessed
-- confidently either way. Fred Anderson (1934 will Witness) and Harry/Edith
-- Harriss (1971 will Legatees) correctly produce no match at all in either
-- step, since none of the three exist in the tree — confirms the matcher
-- doesn't force a pick just because a name was checked.

-- %%
-- %sql
-- Cell 5f — Tier 1 role expansion: Parent (fixed), Grandparent, Sibling, Grandchild
INSERT INTO genealogy.silver_document_person
  (file_id, file_name, person_gedcom_id, display_name,
   match_method, match_confidence, candidate_count, notes, matched_at)

WITH

-- Restricted to the TRUE primary match only (Cell 5/5b/5c's own methods).
-- Bug found live this session: without this filter, once Cell 5g/5h/5f have
-- written their own inferred rows to silver_document_person, a later cell
-- re-deriving matched_docs from the same table picks those rows up as if
-- they were additional "primaries" too -- e.g. after Cell 5g matched Clara
-- as Executor (SPOUSE relation) on Charles Edward Ball's 1934 will, Cell 5h
-- treated CLARA as a second primary and computed her own SIBLING (Samuel
-- Mattock) as if he were related to Charles Edward Ball directly -- silently
-- causing Cell 5h to skip its whole-tree fallback for him, thinking Cell 5g
-- had already covered it. Excluding this session's two new match_methods
-- keeps every cell's candidate pool anchored to the one true primary.
matched_docs AS (
  SELECT sdp.file_id, sdp.person_gedcom_id AS primary_person_id, ot.year, ot.file_name
  FROM genealogy.silver_document_person sdp
  JOIN genealogy.ocr_transcriptions ot ON ot.file_id = sdp.file_id
  WHERE sdp.file_id IN (SELECT DISTINCT file_id FROM genealogy.silver_transcript_person_mention)
    AND sdp.match_method NOT IN ('HOUSEHOLD_INFERENCE_V2', 'WHOLE_TREE_NAME_MATCH')
  GROUP BY sdp.file_id, sdp.person_gedcom_id, ot.year, ot.file_name
),

mentions AS (
  SELECT tpm.file_id, tpm.person_index, tpm.name_raw, tpm.age_years, tpm.dob_raw,
    UPPER(TRIM(REGEXP_EXTRACT(tpm.name_raw, '^(\\S+)', 1))) AS forename_first,
    UPPER(TRIM(REGEXP_EXTRACT(tpm.name_raw, '(\\S+)$', 1))) AS surname_last,
    CASE
      WHEN tpm.role_in_record IN ('Father', 'Mother') THEN 'PARENT'
      WHEN tpm.role_in_record IN ('Grandfather', 'Grandmother') THEN 'GRANDPARENT'
      WHEN tpm.role_in_record IN ('Brother', 'Sister') THEN 'SIBLING'
      WHEN tpm.role_in_record IN ('Grandson', 'Granddaughter', 'Grandchild', 'Grand Son', 'Grand Daughter') THEN 'GRANDCHILD'
    END AS mapped_relation,
    TRY_CAST(REGEXP_EXTRACT(tpm.dob_raw, '(\\d{4})$', 1) AS INT) AS dob_year
  FROM genealogy.silver_transcript_person_mention tpm
  WHERE tpm.role_in_record IN ('Father','Mother','Grandfather','Grandmother','Brother','Sister',
        'Grandson','Granddaughter','Grandchild','Grand Son','Grand Daughter')
),

-- PARENT emits both parents as separate rows (fixes Cell 5e's original
-- single-parent CASE, which only ever returned one -- see Cell 5f markdown).
-- GRANDPARENT is one more family_child hop each side; SIBLING is other
-- children of the primary's own parent family; GRANDCHILD is the primary's
-- children's own children.
relatives AS (
  SELECT md.file_id, md.year, md.primary_person_id, sf.husband_gedcom_id AS relative_id, 'PARENT' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf ON sf.family_gedcom_id = fc.family_gedcom_id
  WHERE sf.husband_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, sf.wife_gedcom_id AS relative_id, 'PARENT' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf ON sf.family_gedcom_id = fc.family_gedcom_id
  WHERE sf.wife_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, sf2.husband_gedcom_id AS relative_id, 'GRANDPARENT' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc1 ON fc1.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf1 ON sf1.family_gedcom_id = fc1.family_gedcom_id
  JOIN genealogy.silver_family_child fc2 ON fc2.child_gedcom_id = sf1.husband_gedcom_id OR fc2.child_gedcom_id = sf1.wife_gedcom_id
  JOIN genealogy.silver_family sf2 ON sf2.family_gedcom_id = fc2.family_gedcom_id
  WHERE sf2.husband_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, sf2.wife_gedcom_id AS relative_id, 'GRANDPARENT' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc1 ON fc1.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf1 ON sf1.family_gedcom_id = fc1.family_gedcom_id
  JOIN genealogy.silver_family_child fc2 ON fc2.child_gedcom_id = sf1.husband_gedcom_id OR fc2.child_gedcom_id = sf1.wife_gedcom_id
  JOIN genealogy.silver_family sf2 ON sf2.family_gedcom_id = fc2.family_gedcom_id
  WHERE sf2.wife_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, fc_sib.child_gedcom_id AS relative_id, 'SIBLING' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc_sib ON fc_sib.family_gedcom_id = fc.family_gedcom_id
  WHERE fc_sib.child_gedcom_id != md.primary_person_id

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, fc_gc.child_gedcom_id AS relative_id, 'GRANDCHILD' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family sf_c ON sf_c.husband_gedcom_id = md.primary_person_id OR sf_c.wife_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc_c ON fc_c.family_gedcom_id = sf_c.family_gedcom_id
  JOIN genealogy.silver_family sf_gc ON sf_gc.husband_gedcom_id = fc_c.child_gedcom_id OR sf_gc.wife_gedcom_id = fc_c.child_gedcom_id
  JOIN genealogy.silver_family_child fc_gc ON fc_gc.family_gedcom_id = sf_gc.family_gedcom_id
),

relatives_named AS (
  SELECT DISTINCT r.file_id, r.year, r.relation, r.relative_id,
    COALESCE(pl.given_name, '') AS given_name, COALESCE(pl.surname, '') AS surname,
    pl.birth_year, pl.death_year
  FROM relatives r
  JOIN genealogy.gold_person_life pl ON pl.person_gedcom_id = r.relative_id
  WHERE r.relative_id IS NOT NULL AND r.relative_id != r.primary_person_id
),

candidate_names AS (
  SELECT file_id, year, relation, relative_id, birth_year, death_year,
    UPPER(TRIM(REGEXP_EXTRACT(given_name, '^(\\S+)', 1))) AS forename_first, UPPER(TRIM(surname)) AS surname
  FROM relatives_named
  WHERE surname != ''

  UNION ALL

  SELECT rn.file_id, rn.year, rn.relation, rn.relative_id, rn.birth_year, rn.death_year,
    UPPER(TRIM(REGEXP_EXTRACT(a.alias_given_name, '^(\\S+)', 1))) AS forename_first, UPPER(TRIM(a.alias_surname)) AS surname
  FROM relatives_named rn
  JOIN genealogy.silver_person_alias a ON a.person_gedcom_id = rn.relative_id
  WHERE a.alias_surname IS NOT NULL AND a.alias_surname != ''
),

candidate_matches AS (
  SELECT DISTINCT c.file_id, c.relation, c.relative_id, c.birth_year, m.person_index, m.name_raw,
    CASE
      WHEN m.age_years IS NOT NULL THEN TRY_CAST(SUBSTR(c.year, 1, 4) AS INT) - m.age_years
      WHEN m.dob_year IS NOT NULL THEN m.dob_year
    END AS implied_birth_year
  FROM candidate_names c
  JOIN mentions m
    ON m.file_id = c.file_id AND m.mapped_relation = c.relation
   AND m.forename_first = c.forename_first AND m.surname_last = c.surname
  WHERE c.birth_year <= TRY_CAST(SUBSTR(c.year, 1, 4) AS INT)
    AND (c.death_year IS NULL OR c.death_year >= TRY_CAST(SUBSTR(c.year, 1, 4) AS INT))
),

mention_candidate_counts AS (
  SELECT file_id, person_index, COUNT(DISTINCT relative_id) AS n_candidates
  FROM candidate_matches GROUP BY file_id, person_index
),

ranked AS (
  SELECT cm.*, mcc.n_candidates,
    ROW_NUMBER() OVER (
      PARTITION BY cm.file_id, cm.person_index
      ORDER BY ABS(COALESCE(cm.implied_birth_year, cm.birth_year) - cm.birth_year) ASC, cm.relative_id ASC
    ) AS rk
  FROM candidate_matches cm
  JOIN mention_candidate_counts mcc ON mcc.file_id = cm.file_id AND mcc.person_index = cm.person_index
),

final AS (
  SELECT file_id, relative_id, relation, MIN(person_index) AS person_index
  FROM ranked
  WHERE n_candidates = 1 OR rk = 1
  GROUP BY file_id, relative_id, relation
)

SELECT
  f.file_id,
  md.file_name,
  f.relative_id AS person_gedcom_id,
  pl.given_name || ' ' || pl.surname AS display_name,
  'HOUSEHOLD_INFERENCE_V2' AS match_method,
  'MEDIUM' AS match_confidence,
  1 AS candidate_count,
  CONCAT('Household member (', f.relation, ') matched via silver_transcript_person_mention') AS notes,
  CURRENT_TIMESTAMP()
FROM final f
JOIN matched_docs md ON md.file_id = f.file_id
JOIN genealogy.gold_person_life pl ON pl.person_gedcom_id = f.relative_id
WHERE NOT EXISTS (
  SELECT 1 FROM genealogy.silver_document_person sdp
  WHERE sdp.file_id = f.file_id AND sdp.person_gedcom_id = f.relative_id
);

-- %%
-- %sql
-- Cell 5g — Tier 2 step 1: Witness/Executor/Legatee via the whole family pool
INSERT INTO genealogy.silver_document_person
  (file_id, file_name, person_gedcom_id, display_name,
   match_method, match_confidence, candidate_count, notes, matched_at)

WITH

-- Restricted to the TRUE primary match only (Cell 5/5b/5c's own methods).
-- Bug found live this session: without this filter, once Cell 5g/5h/5f have
-- written their own inferred rows to silver_document_person, a later cell
-- re-deriving matched_docs from the same table picks those rows up as if
-- they were additional "primaries" too -- e.g. after Cell 5g matched Clara
-- as Executor (SPOUSE relation) on Charles Edward Ball's 1934 will, Cell 5h
-- treated CLARA as a second primary and computed her own SIBLING (Samuel
-- Mattock) as if he were related to Charles Edward Ball directly -- silently
-- causing Cell 5h to skip its whole-tree fallback for him, thinking Cell 5g
-- had already covered it. Excluding this session's two new match_methods
-- keeps every cell's candidate pool anchored to the one true primary.
matched_docs AS (
  SELECT sdp.file_id, sdp.person_gedcom_id AS primary_person_id, ot.year, ot.file_name
  FROM genealogy.silver_document_person sdp
  JOIN genealogy.ocr_transcriptions ot ON ot.file_id = sdp.file_id
  WHERE sdp.file_id IN (SELECT DISTINCT file_id FROM genealogy.silver_transcript_person_mention)
    AND sdp.match_method NOT IN ('HOUSEHOLD_INFERENCE_V2', 'WHOLE_TREE_NAME_MATCH')
  GROUP BY sdp.file_id, sdp.person_gedcom_id, ot.year, ot.file_name
),

-- Testator deliberately absent: it IS the document's own already-matched
-- primary person (Cell 5/5b/5c) -- see Cell 5f markdown.
mentions AS (
  SELECT tpm.file_id, tpm.person_index, tpm.name_raw, tpm.role_in_record, tpm.age_years, tpm.dob_raw,
    UPPER(TRIM(REGEXP_EXTRACT(tpm.name_raw, '^(\\S+)', 1))) AS forename_first,
    UPPER(TRIM(REGEXP_EXTRACT(tpm.name_raw, '(\\S+)$', 1))) AS surname_last,
    TRY_CAST(REGEXP_EXTRACT(tpm.dob_raw, '(\\d{4})$', 1) AS INT) AS dob_year
  FROM genealogy.silver_transcript_person_mention tpm
  WHERE tpm.role_in_record IN ('Witness','Executor','Legatee')
),

-- Full family relation pool -- unlike Tier 1 mentions (which must land on a
-- specific relation type), a Witness/Executor/Legatee could turn out to be
-- ANY relation to the primary person (e.g. Clara Ball as Executor on her own
-- husband's will is his SPOUSE) -- see Cell 5f markdown.
relatives AS (
  SELECT md.file_id, md.year, md.primary_person_id,
    CASE WHEN sf.husband_gedcom_id = md.primary_person_id THEN sf.wife_gedcom_id ELSE sf.husband_gedcom_id END AS relative_id,
    'SPOUSE' AS relation
  FROM matched_docs md
  JOIN genealogy.silver_family sf ON sf.husband_gedcom_id = md.primary_person_id OR sf.wife_gedcom_id = md.primary_person_id
  WHERE sf.relationship_type IS NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, fc.child_gedcom_id, 'CHILD'
  FROM matched_docs md
  JOIN genealogy.silver_family sf ON sf.husband_gedcom_id = md.primary_person_id OR sf.wife_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc ON fc.family_gedcom_id = sf.family_gedcom_id

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, sf.husband_gedcom_id, 'PARENT'
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf ON sf.family_gedcom_id = fc.family_gedcom_id
  WHERE sf.husband_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, sf.wife_gedcom_id, 'PARENT'
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf ON sf.family_gedcom_id = fc.family_gedcom_id
  WHERE sf.wife_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, sf2.husband_gedcom_id, 'GRANDPARENT'
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc1 ON fc1.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf1 ON sf1.family_gedcom_id = fc1.family_gedcom_id
  JOIN genealogy.silver_family_child fc2 ON fc2.child_gedcom_id = sf1.husband_gedcom_id OR fc2.child_gedcom_id = sf1.wife_gedcom_id
  JOIN genealogy.silver_family sf2 ON sf2.family_gedcom_id = fc2.family_gedcom_id
  WHERE sf2.husband_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, sf2.wife_gedcom_id, 'GRANDPARENT'
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc1 ON fc1.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf1 ON sf1.family_gedcom_id = fc1.family_gedcom_id
  JOIN genealogy.silver_family_child fc2 ON fc2.child_gedcom_id = sf1.husband_gedcom_id OR fc2.child_gedcom_id = sf1.wife_gedcom_id
  JOIN genealogy.silver_family sf2 ON sf2.family_gedcom_id = fc2.family_gedcom_id
  WHERE sf2.wife_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, fc_sib.child_gedcom_id, 'SIBLING'
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc_sib ON fc_sib.family_gedcom_id = fc.family_gedcom_id
  WHERE fc_sib.child_gedcom_id != md.primary_person_id

  UNION ALL

  SELECT md.file_id, md.year, md.primary_person_id, fc_gc.child_gedcom_id, 'GRANDCHILD'
  FROM matched_docs md
  JOIN genealogy.silver_family sf_c ON sf_c.husband_gedcom_id = md.primary_person_id OR sf_c.wife_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc_c ON fc_c.family_gedcom_id = sf_c.family_gedcom_id
  JOIN genealogy.silver_family sf_gc ON sf_gc.husband_gedcom_id = fc_c.child_gedcom_id OR sf_gc.wife_gedcom_id = fc_c.child_gedcom_id
  JOIN genealogy.silver_family_child fc_gc ON fc_gc.family_gedcom_id = sf_gc.family_gedcom_id
),

relatives_named AS (
  SELECT DISTINCT r.file_id, r.year, r.relation, r.relative_id,
    COALESCE(pl.given_name, '') AS given_name, COALESCE(pl.surname, '') AS surname,
    pl.birth_year, pl.death_year
  FROM relatives r
  JOIN genealogy.gold_person_life pl ON pl.person_gedcom_id = r.relative_id
  WHERE r.relative_id IS NOT NULL AND r.relative_id != r.primary_person_id
),

candidate_names AS (
  SELECT file_id, year, relation, relative_id, birth_year, death_year,
    UPPER(TRIM(REGEXP_EXTRACT(given_name, '^(\\S+)', 1))) AS forename_first, UPPER(TRIM(surname)) AS surname
  FROM relatives_named
  WHERE surname != ''

  UNION ALL

  SELECT rn.file_id, rn.year, rn.relation, rn.relative_id, rn.birth_year, rn.death_year,
    UPPER(TRIM(REGEXP_EXTRACT(a.alias_given_name, '^(\\S+)', 1))) AS forename_first, UPPER(TRIM(a.alias_surname)) AS surname
  FROM relatives_named rn
  JOIN genealogy.silver_person_alias a ON a.person_gedcom_id = rn.relative_id
  WHERE a.alias_surname IS NOT NULL AND a.alias_surname != ''
),

candidate_matches AS (
  SELECT DISTINCT c.file_id, c.relation, c.relative_id, c.birth_year, m.person_index, m.name_raw, m.role_in_record,
    CASE
      WHEN m.age_years IS NOT NULL THEN TRY_CAST(SUBSTR(c.year, 1, 4) AS INT) - m.age_years
      WHEN m.dob_year IS NOT NULL THEN m.dob_year
    END AS implied_birth_year
  FROM candidate_names c
  JOIN mentions m
    ON m.file_id = c.file_id AND m.forename_first = c.forename_first AND m.surname_last = c.surname
  WHERE c.birth_year <= TRY_CAST(SUBSTR(c.year, 1, 4) AS INT)
    AND (c.death_year IS NULL OR c.death_year >= TRY_CAST(SUBSTR(c.year, 1, 4) AS INT))
),

mention_candidate_counts AS (
  SELECT file_id, person_index, COUNT(DISTINCT relative_id) AS n_candidates
  FROM candidate_matches GROUP BY file_id, person_index
),

ranked AS (
  SELECT cm.*, mcc.n_candidates,
    ROW_NUMBER() OVER (
      PARTITION BY cm.file_id, cm.person_index
      ORDER BY ABS(COALESCE(cm.implied_birth_year, cm.birth_year) - cm.birth_year) ASC, cm.relative_id ASC
    ) AS rk
  FROM candidate_matches cm
  JOIN mention_candidate_counts mcc ON mcc.file_id = cm.file_id AND mcc.person_index = cm.person_index
),

final AS (
  SELECT file_id, relative_id, relation, role_in_record, MIN(person_index) AS person_index
  FROM ranked
  WHERE n_candidates = 1 OR rk = 1
  GROUP BY file_id, relative_id, relation, role_in_record
)

SELECT
  f.file_id,
  md.file_name,
  f.relative_id AS person_gedcom_id,
  pl.given_name || ' ' || pl.surname AS display_name,
  'HOUSEHOLD_INFERENCE_V2' AS match_method,
  'MEDIUM' AS match_confidence,
  1 AS candidate_count,
  CONCAT(f.role_in_record, ' matched via ', f.relation, ' relation') AS notes,
  CURRENT_TIMESTAMP()
FROM final f
JOIN matched_docs md ON md.file_id = f.file_id
JOIN genealogy.gold_person_life pl ON pl.person_gedcom_id = f.relative_id
WHERE NOT EXISTS (
  SELECT 1 FROM genealogy.silver_document_person sdp
  WHERE sdp.file_id = f.file_id AND sdp.person_gedcom_id = f.relative_id
);

-- %%
-- %sql
-- Cell 5h — Tier 2 step 2: whole-tree name + year-plausibility fallback
INSERT INTO genealogy.silver_document_person
  (file_id, file_name, person_gedcom_id, display_name,
   match_method, match_confidence, candidate_count, notes, matched_at)

WITH

-- Restricted to the TRUE primary match only (Cell 5/5b/5c's own methods) --
-- see the note on Cell 5f's matched_docs for why.
matched_docs AS (
  SELECT sdp.file_id, sdp.person_gedcom_id AS primary_person_id, ot.year, ot.file_name
  FROM genealogy.silver_document_person sdp
  JOIN genealogy.ocr_transcriptions ot ON ot.file_id = sdp.file_id
  WHERE sdp.file_id IN (SELECT DISTINCT file_id FROM genealogy.silver_transcript_person_mention)
    AND sdp.match_method NOT IN ('HOUSEHOLD_INFERENCE_V2', 'WHOLE_TREE_NAME_MATCH')
  GROUP BY sdp.file_id, sdp.person_gedcom_id, ot.year, ot.file_name
),

mentions AS (
  SELECT tpm.file_id, tpm.person_index, tpm.name_raw, tpm.role_in_record, tpm.age_years, tpm.dob_raw,
    UPPER(TRIM(REGEXP_EXTRACT(tpm.name_raw, '^(\\S+)', 1))) AS forename_first,
    UPPER(TRIM(REGEXP_EXTRACT(tpm.name_raw, '(\\S+)$', 1))) AS surname_last,
    -- Everything before the surname (e.g. "Joan Margaret" from "Joan Margaret
    -- Ball") -- used below to prefer a candidate whose full given name
    -- matches, not just the first token. Found live: without this, "Joan
    -- Margaret Ball" (forename_first=JOAN) spuriously tied against an
    -- unrelated "Joan Hobson" whose married-name alias was just "Joan Ball"
    -- (no Margaret at all) -- both satisfied the old forename_first+surname
    -- check equally, producing a false LOW-confidence tie between one real
    -- match and one same-first-name-only person.
    UPPER(TRIM(REGEXP_REPLACE(tpm.name_raw, '\\s+\\S+$', ''))) AS full_forename,
    TRY_CAST(REGEXP_EXTRACT(tpm.dob_raw, '(\\d{4})$', 1) AS INT) AS dob_year
  FROM genealogy.silver_transcript_person_mention tpm
  WHERE tpm.role_in_record IN ('Witness','Executor','Legatee')
),

-- Same family relation pool as Cell 5g, collapsed to just names, used here
-- only to test "did Cell 5g's step 1 have ANY family candidate for this
-- mention" -- independent of whether Cell 5g has actually run yet, so this
-- cell is correct standalone as well as run after 5g.
relatives AS (
  SELECT md.file_id,
    CASE WHEN sf.husband_gedcom_id = md.primary_person_id THEN sf.wife_gedcom_id ELSE sf.husband_gedcom_id END AS relative_id
  FROM matched_docs md
  JOIN genealogy.silver_family sf ON sf.husband_gedcom_id = md.primary_person_id OR sf.wife_gedcom_id = md.primary_person_id
  WHERE sf.relationship_type IS NULL

  UNION ALL

  SELECT md.file_id, fc.child_gedcom_id
  FROM matched_docs md
  JOIN genealogy.silver_family sf ON sf.husband_gedcom_id = md.primary_person_id OR sf.wife_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc ON fc.family_gedcom_id = sf.family_gedcom_id

  UNION ALL

  SELECT md.file_id, sf.husband_gedcom_id
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf ON sf.family_gedcom_id = fc.family_gedcom_id
  WHERE sf.husband_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, sf.wife_gedcom_id
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf ON sf.family_gedcom_id = fc.family_gedcom_id
  WHERE sf.wife_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, sf2.husband_gedcom_id
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc1 ON fc1.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf1 ON sf1.family_gedcom_id = fc1.family_gedcom_id
  JOIN genealogy.silver_family_child fc2 ON fc2.child_gedcom_id = sf1.husband_gedcom_id OR fc2.child_gedcom_id = sf1.wife_gedcom_id
  JOIN genealogy.silver_family sf2 ON sf2.family_gedcom_id = fc2.family_gedcom_id
  WHERE sf2.husband_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, sf2.wife_gedcom_id
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc1 ON fc1.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family sf1 ON sf1.family_gedcom_id = fc1.family_gedcom_id
  JOIN genealogy.silver_family_child fc2 ON fc2.child_gedcom_id = sf1.husband_gedcom_id OR fc2.child_gedcom_id = sf1.wife_gedcom_id
  JOIN genealogy.silver_family sf2 ON sf2.family_gedcom_id = fc2.family_gedcom_id
  WHERE sf2.wife_gedcom_id IS NOT NULL

  UNION ALL

  SELECT md.file_id, fc_sib.child_gedcom_id
  FROM matched_docs md
  JOIN genealogy.silver_family_child fc ON fc.child_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc_sib ON fc_sib.family_gedcom_id = fc.family_gedcom_id
  WHERE fc_sib.child_gedcom_id != md.primary_person_id

  UNION ALL

  SELECT md.file_id, fc_gc.child_gedcom_id
  FROM matched_docs md
  JOIN genealogy.silver_family sf_c ON sf_c.husband_gedcom_id = md.primary_person_id OR sf_c.wife_gedcom_id = md.primary_person_id
  JOIN genealogy.silver_family_child fc_c ON fc_c.family_gedcom_id = sf_c.family_gedcom_id
  JOIN genealogy.silver_family sf_gc ON sf_gc.husband_gedcom_id = fc_c.child_gedcom_id OR sf_gc.wife_gedcom_id = fc_c.child_gedcom_id
  JOIN genealogy.silver_family_child fc_gc ON fc_gc.family_gedcom_id = sf_gc.family_gedcom_id
),

candidate_names AS (
  SELECT DISTINCT r.file_id,
    UPPER(TRIM(REGEXP_EXTRACT(pl.given_name, '^(\\S+)', 1))) AS forename_first, UPPER(TRIM(pl.surname)) AS surname
  FROM relatives r
  JOIN genealogy.gold_person_life pl ON pl.person_gedcom_id = r.relative_id
  WHERE r.relative_id IS NOT NULL AND pl.surname IS NOT NULL AND pl.surname != ''

  UNION

  SELECT DISTINCT r.file_id,
    UPPER(TRIM(REGEXP_EXTRACT(a.alias_given_name, '^(\\S+)', 1))) AS forename_first, UPPER(TRIM(a.alias_surname)) AS surname
  FROM relatives r
  JOIN genealogy.silver_person_alias a ON a.person_gedcom_id = r.relative_id
  WHERE r.relative_id IS NOT NULL AND a.alias_surname IS NOT NULL AND a.alias_surname != ''
),

-- Mentions the family pool has zero candidates for -- these are the ones
-- Cell 5g's step 1 could never have matched, so they fall to the whole-tree
-- search below.
tier2_unresolved AS (
  SELECT m.file_id, m.person_index, m.name_raw, m.role_in_record, m.forename_first, m.surname_last,
    m.full_forename, m.age_years, m.dob_year
  FROM mentions m
  WHERE NOT EXISTS (
    SELECT 1 FROM candidate_names c
    WHERE c.file_id = m.file_id AND c.forename_first = m.forename_first AND c.surname = m.surname_last
  )
),

-- Same mechanism Cell 5's own primary matcher uses (name match + alive-at-
-- document-year plausibility), applied to a secondary name instead of the
-- document's main subject.
whole_tree_candidates AS (
  SELECT tu.file_id, tu.person_index, tu.name_raw, tu.role_in_record,
    p.person_gedcom_id, p.given_name, p.surname, p.birth_year, p.death_year,
    CASE WHEN UPPER(TRIM(p.given_name)) = tu.full_forename THEN 1 ELSE 0 END AS full_name_match,
    CASE
      WHEN tu.age_years IS NOT NULL THEN TRY_CAST(SUBSTR(md.year, 1, 4) AS INT) - tu.age_years
      WHEN tu.dob_year IS NOT NULL THEN tu.dob_year
    END AS implied_birth_year
  FROM tier2_unresolved tu
  JOIN matched_docs md ON md.file_id = tu.file_id
  JOIN genealogy.gold_person_life p
    ON UPPER(TRIM(REGEXP_EXTRACT(p.given_name, '^(\\S+)', 1))) = tu.forename_first
   AND UPPER(TRIM(p.surname)) = tu.surname_last
  WHERE p.person_gedcom_id != md.primary_person_id
    AND p.birth_year <= TRY_CAST(SUBSTR(md.year, 1, 4) AS INT)
    AND (p.death_year IS NULL OR p.death_year >= TRY_CAST(SUBSTR(md.year, 1, 4) AS INT))

  UNION ALL

  SELECT tu.file_id, tu.person_index, tu.name_raw, tu.role_in_record,
    a.person_gedcom_id, pl.given_name, pl.surname, pl.birth_year, pl.death_year,
    CASE WHEN UPPER(TRIM(a.alias_given_name)) = tu.full_forename THEN 1 ELSE 0 END AS full_name_match,
    CASE
      WHEN tu.age_years IS NOT NULL THEN TRY_CAST(SUBSTR(md.year, 1, 4) AS INT) - tu.age_years
      WHEN tu.dob_year IS NOT NULL THEN tu.dob_year
    END AS implied_birth_year
  FROM tier2_unresolved tu
  JOIN matched_docs md ON md.file_id = tu.file_id
  JOIN genealogy.silver_person_alias a
    ON UPPER(TRIM(REGEXP_EXTRACT(a.alias_given_name, '^(\\S+)', 1))) = tu.forename_first
   AND UPPER(TRIM(a.alias_surname)) = tu.surname_last
  JOIN genealogy.gold_person_life pl ON pl.person_gedcom_id = a.person_gedcom_id
  WHERE a.person_gedcom_id != md.primary_person_id
    AND pl.birth_year <= TRY_CAST(SUBSTR(md.year, 1, 4) AS INT)
    AND (pl.death_year IS NULL OR pl.death_year >= TRY_CAST(SUBSTR(md.year, 1, 4) AS INT))
),

-- Prefer full-given-name matches over first-token-only matches: if any
-- candidate for a mention matches the full forename, first-token-only
-- candidates are dropped entirely rather than counted as competing ties.
best_tier AS (
  SELECT file_id, person_index, MAX(full_name_match) AS best_full_match
  FROM whole_tree_candidates
  GROUP BY file_id, person_index
),

whole_tree_filtered AS (
  SELECT wtc.*
  FROM whole_tree_candidates wtc
  JOIN best_tier bt ON bt.file_id = wtc.file_id AND bt.person_index = wtc.person_index
  WHERE wtc.full_name_match = bt.best_full_match
),

whole_tree_counts AS (
  SELECT file_id, person_index, COUNT(DISTINCT person_gedcom_id) AS n_candidates
  FROM whole_tree_filtered GROUP BY file_id, person_index
),

-- Distance from implied_birth_year (age/DOB on the mention, if any) breaks a
-- genuine tie when possible; person_gedcom_id ASC is the last-resort,
-- arbitrary tie-break otherwise -- flagged LOW confidence below, same
-- convention as Cell 5's own TIE handling, not asserted as a real match.
whole_tree_ranked AS (
  SELECT wtc.*, cnt.n_candidates,
    ROW_NUMBER() OVER (
      PARTITION BY wtc.file_id, wtc.person_index
      ORDER BY ABS(COALESCE(wtc.implied_birth_year, wtc.birth_year) - wtc.birth_year) ASC, wtc.person_gedcom_id ASC
    ) AS rk
  FROM whole_tree_filtered wtc
  JOIN whole_tree_counts cnt ON cnt.file_id = wtc.file_id AND cnt.person_index = wtc.person_index
)

SELECT
  f.file_id,
  md.file_name,
  f.person_gedcom_id,
  f.given_name || ' ' || f.surname AS display_name,
  'WHOLE_TREE_NAME_MATCH' AS match_method,
  CASE WHEN f.n_candidates = 1 THEN 'MEDIUM' ELSE 'LOW' END AS match_confidence,
  f.n_candidates AS candidate_count,
  CONCAT(f.role_in_record, ' matched via whole-tree name search',
    CASE WHEN f.n_candidates > 1
      THEN CONCAT(' | TIE: ', f.n_candidates, ' candidates equally plausible, needs manual review')
      ELSE '' END
  ) AS notes,
  CURRENT_TIMESTAMP()
FROM whole_tree_ranked f
JOIN matched_docs md ON md.file_id = f.file_id
WHERE f.rk = 1
  AND NOT EXISTS (
    SELECT 1 FROM genealogy.silver_document_person sdp
    WHERE sdp.file_id = f.file_id AND sdp.person_gedcom_id = f.person_gedcom_id
  );

-- %%
-- %sql
-- Verification: role-expansion (Cell 5f/5g/5h) rows, by match_method + relation.
-- SPOUSE/CHILD were already live from Cell 5e (Session 71) -- everything else
-- (PARENT/GRANDPARENT/SIBLING/GRANDCHILD, plus the Tier 2 relation-in-notes
-- rows and WHOLE_TREE_NAME_MATCH) is new this session.
SELECT match_method,
  -- REGEXP_EXTRACT returns '' (not NULL) on no match in Spark SQL, so a bare
  -- COALESCE never falls through to the next pattern -- NULLIF converts the
  -- empty-string non-match back to NULL first.
  COALESCE(NULLIF(REGEXP_EXTRACT(notes, '^Household member \\(([A-Z]+)\\)', 1), ''),
           NULLIF(REGEXP_EXTRACT(notes, ' matched via ([A-Z]+) relation', 1), ''),
           'whole-tree') AS relation,
  COUNT(*) AS rows_total, COUNT(DISTINCT file_id) AS files_affected
FROM genealogy.silver_document_person
WHERE match_method IN ('HOUSEHOLD_INFERENCE_V2', 'WHOLE_TREE_NAME_MATCH')
GROUP BY match_method, relation
ORDER BY match_method, rows_total DESC;

-- Sanity check, expect 2: Charles Edward Ball's two distinct wills-related
-- appearances must resolve to two DIFFERENT person_gedcom_id values (the
-- 1934 testator/father vs. the 1971 executor/son) -- the actual test of
-- whether the collision is resolved, not just avoided.
SELECT COUNT(DISTINCT person_gedcom_id) AS distinct_charles_edward_ball_ids
FROM genealogy.silver_document_person
WHERE file_id IN ('0B00VuRbH2UFNaWtKWXpxdGdXZlU', '11cDZ6oFAHIBD8IGH1VWj8RQIC4FKzPVK')
  AND display_name LIKE 'Charles Edward%';

-- Sanity check, expect 0: Harry Harriss, Edith Harriss and Fred Anderson
-- (all confirmed absent from the tree) should never get a row -- confirms
-- the matcher doesn't force a pick just because a name was checked.
SELECT COUNT(*) AS wrongly_matched_absent_people
FROM genealogy.silver_document_person
WHERE (file_id = '11cDZ6oFAHIBD8IGH1VWj8RQIC4FKzPVK' AND display_name IN ('Harry Harriss', 'Edith Harriss'))
   OR (file_id = '0B00VuRbH2UFNaWtKWXpxdGdXZlU' AND display_name = 'Fred Anderson');

-- Sanity check, expect 0: a household-inference/whole-tree row should never
-- be the only row on a file (it always accompanies the Cell 5 primary match).
SELECT COUNT(*) AS orphaned_inference_only_files
FROM (
  SELECT file_id, COUNT(*) AS n,
    SUM(CASE WHEN match_method IN ('HOUSEHOLD_INFERENCE_V2','WHOLE_TREE_NAME_MATCH') THEN 1 ELSE 0 END) AS n_inferred
  FROM genealogy.silver_document_person
  GROUP BY file_id
) x
WHERE n_inferred = n;

-- %% [markdown]
-- ## Cell 5i — Dedup: remove exact-duplicate silver_document_person rows
--
-- **Defensive safety net, not a logic fix.** Ed's full-notebook re-run on 19
-- Sep 2026 produced 11 exact-duplicate row pairs, all on MarriageCertificate
-- documents, all sharing an identical `matched_at` down to the millisecond
-- within each pair. Investigated thoroughly before adding this: the
-- `relatives`/`candidate_names`/`candidate_matches` pipeline in Cells 5f/5g/5h
-- was re-validated end-to-end at full corpus scale (not a smaller test
-- subset) and produces exactly one candidate row for every duplicated case —
-- the SQL logic itself is not the cause. The notebook actually running in
-- Databricks was also diff'd cell-by-cell against the validated GitHub
-- version — byte-for-byte identical, ruling out a merge/sync issue too.
--
-- The identical-to-the-millisecond `matched_at` pairs point instead to the
-- serverless SQL warehouse's own execution layer occasionally committing one
-- INSERT's effects twice (most consistent with a transient-failure retry that
-- reuses an already-resolved query plan, including its `CURRENT_TIMESTAMP()`
-- constant) — outside what SQL text can prevent. Rather than chase an
-- infrastructure-level retry, this cell cleans up its effect: `file_id` +
-- `person_gedcom_id` is meant to be unique across the whole table (every
-- matching cell in this notebook guards its own INSERT with `NOT EXISTS` on
-- exactly that pair), so any duplicate found here is always a bug regardless
-- of cause.
--
-- Uses `SELECT DISTINCT *` deliberately, not an arbitrary per-column pick
-- (e.g. `ANY_VALUE`) — a true retry-duplicate has every column identical, so
-- `DISTINCT` collapses it safely. If a `(file_id, person_gedcom_id)` pair ever
-- has genuinely *different* row content across its copies, that's a real
-- conflict, not a retry artifact, and `DISTINCT` correctly leaves both rows in
-- place for the verify cell below to flag rather than silently picking one.

-- %%
-- %sql
-- Cell 5i — Dedup: remove exact-duplicate silver_document_person rows
CREATE OR REPLACE TABLE genealogy.silver_document_person_dedup_tmp AS
SELECT DISTINCT * FROM genealogy.silver_document_person;

TRUNCATE TABLE genealogy.silver_document_person;

INSERT INTO genealogy.silver_document_person
SELECT * FROM genealogy.silver_document_person_dedup_tmp;

DROP TABLE genealogy.silver_document_person_dedup_tmp;

-- %%
-- %sql
-- Verification: dedup results
SELECT COUNT(*) AS total_rows, COUNT(DISTINCT file_id || '|' || person_gedcom_id) AS distinct_file_person_pairs
FROM genealogy.silver_document_person;

-- Sanity check, expect 0: every (file_id, person_gedcom_id) pair should be
-- unique after dedup. Nonzero here means a genuine content conflict (not a
-- retry artifact) survived DISTINCT -- e.g. two different match_methods
-- both claiming the same file+person -- and needs manual investigation,
-- not another automatic dedup pass.
SELECT file_id, person_gedcom_id, COUNT(*) AS n, COLLECT_SET(match_method) AS methods, COLLECT_SET(notes) AS distinct_notes
FROM genealogy.silver_document_person
GROUP BY file_id, person_gedcom_id
HAVING COUNT(*) > 1;

-- %% [markdown]
-- ## Cell 6 — Diagnostic: why did files not match?
--
-- Also persists the YEAR_FILTER_ELIMINATED(+ALIAS) rows below to
-- silver_document_match_exception (BUG-002 fix, Asana 1218506594311016) — files
-- that had a name/alias-matching candidate but none survived Cell 5's
-- year-plausibility filter no longer get force-matched by the old NOT EXISTS
-- fallback, so this is now where they get logged for manual review instead.

-- %%
-- %sql
WITH cleaned_transcripts AS (
  SELECT
    file_id, file_name, year, surname,
    -- Same trailing-annotation strip as Cell 5 (BUG-005, 2026-09-16).
    TRIM(REGEXP_REPLACE(
      TRIM(REGEXP_REPLACE(forename, '\\s*\\(?(Jr|Sr|Jnr|Snr|Uncle)\\.?\\)?\\s*$', '')),
      '\\s*\\([^)]*\\)\\s*$', ''
    )) AS forename_clean,
    doc_type_detected
  FROM genealogy.ocr_transcriptions
),
unmatched AS (
  SELECT t.* FROM cleaned_transcripts t
  WHERE NOT EXISTS (
    SELECT 1 FROM genealogy.silver_document_person sdp WHERE sdp.file_id = t.file_id
  )
),
surname_check AS (
  SELECT
    u.file_id, u.file_name, u.surname, u.forename_clean,
    COUNT(DISTINCT p.person_gedcom_id) AS surname_matches
  FROM unmatched u
  LEFT JOIN genealogy.gold_person_life p
    ON UPPER(TRIM(u.surname)) = UPPER(TRIM(p.surname))
  GROUP BY u.file_id, u.file_name, u.surname, u.forename_clean
),
name_check AS (
  -- Mirrors Cell 5's candidate-matching logic (BUG-001 fix C): any token in
  -- given_name, not just the first, so a middle-name match isn't miscounted
  -- as a forename failure here.
  SELECT u.file_id, COUNT(DISTINCT p.person_gedcom_id) AS name_matches
  FROM unmatched u
  LEFT JOIN genealogy.gold_person_life p
    ON UPPER(TRIM(u.surname)) = UPPER(TRIM(p.surname))
   AND (
     UPPER(TRIM(u.forename_clean)) = UPPER(TRIM(p.given_name))
     OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(p.given_name)), ' '), UPPER(TRIM(u.forename_clean)))
   )
  GROUP BY u.file_id
),
alias_check AS (
  SELECT u.file_id, COUNT(DISTINCT a.person_gedcom_id) AS alias_matches
  FROM unmatched u
  LEFT JOIN genealogy.silver_person_alias a
    ON UPPER(TRIM(u.surname)) = UPPER(TRIM(a.alias_surname))
   AND (
     UPPER(TRIM(u.forename_clean)) = UPPER(TRIM(a.alias_given_name))
     OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(a.alias_given_name)), ' '), UPPER(TRIM(u.forename_clean)))
   )
  GROUP BY u.file_id
)
SELECT
  s.file_name,
  s.surname,
  s.forename_clean,
  s.surname_matches,
  n.name_matches,
  a.alias_matches,
  CASE
    WHEN s.surname_matches = 0                      THEN 'SURNAME_NOT_IN_TREE'
    WHEN n.name_matches = 0 AND a.alias_matches = 0 THEN 'FORENAME_NOT_MATCHED'
    WHEN n.name_matches > 0                         THEN 'YEAR_FILTER_ELIMINATED'
    WHEN a.alias_matches > 0                        THEN 'YEAR_FILTER_ELIMINATED_ALIAS'
    ELSE                                                 'UNKNOWN'
  END AS failure_reason
FROM surname_check s
JOIN name_check n ON s.file_id = n.file_id
JOIN alias_check a ON s.file_id = a.file_id
ORDER BY failure_reason, s.surname, s.forename_clean;

-- BUG-002 fix (2026-09-15): persist the YEAR_FILTER_ELIMINATED(+ALIAS) rows
-- above -- files that had at least one name/alias-matching candidate but none
-- survived Cell 5's year-plausibility filter (the removed NOT EXISTS fallback
-- would previously have force-matched one of these anyway) -- to
-- silver_document_match_exception for manual review. Asana 1218506594311016.
--
-- BUG-004 fix (2026-09-15, caught in production alongside Cell 5c's MERGE
-- failure): ocr_transcriptions has one row per page, not per file (see Cell
-- 5's "Multi-page fix" note) -- deduped to one row per file_id here so a
-- multi-page unresolved document doesn't get logged multiple times.
WITH cleaned_transcripts AS (
  SELECT
    file_id, MIN(file_name) AS file_name, MIN(year) AS year, MIN(surname) AS surname,
    -- Same trailing-annotation strip as Cell 5 (BUG-005, 2026-09-16).
    MIN(TRIM(REGEXP_REPLACE(
      TRIM(REGEXP_REPLACE(forename, '\\s*\\(?(Jr|Sr|Jnr|Snr|Uncle)\\.?\\)?\\s*$', '')),
      '\\s*\\([^)]*\\)\\s*$', ''
    ))) AS forename_clean,
    MIN(doc_type_detected) AS doc_type_detected
  FROM genealogy.ocr_transcriptions
  GROUP BY file_id
),
unmatched AS (
  SELECT t.* FROM cleaned_transcripts t
  WHERE NOT EXISTS (
    SELECT 1 FROM genealogy.silver_document_person sdp WHERE sdp.file_id = t.file_id
  )
),
surname_check AS (
  SELECT
    u.file_id, u.file_name, u.surname, u.forename_clean,
    COUNT(DISTINCT p.person_gedcom_id) AS surname_matches
  FROM unmatched u
  LEFT JOIN genealogy.gold_person_life p
    ON UPPER(TRIM(u.surname)) = UPPER(TRIM(p.surname))
  GROUP BY u.file_id, u.file_name, u.surname, u.forename_clean
),
name_check AS (
  SELECT u.file_id, COUNT(DISTINCT p.person_gedcom_id) AS name_matches
  FROM unmatched u
  LEFT JOIN genealogy.gold_person_life p
    ON UPPER(TRIM(u.surname)) = UPPER(TRIM(p.surname))
   AND (
     UPPER(TRIM(u.forename_clean)) = UPPER(TRIM(p.given_name))
     OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(p.given_name)), ' '), UPPER(TRIM(u.forename_clean)))
   )
  GROUP BY u.file_id
),
alias_check AS (
  SELECT u.file_id, COUNT(DISTINCT a.person_gedcom_id) AS alias_matches
  FROM unmatched u
  LEFT JOIN genealogy.silver_person_alias a
    ON UPPER(TRIM(u.surname)) = UPPER(TRIM(a.alias_surname))
   AND (
     UPPER(TRIM(u.forename_clean)) = UPPER(TRIM(a.alias_given_name))
     OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(a.alias_given_name)), ' '), UPPER(TRIM(u.forename_clean)))
   )
  GROUP BY u.file_id
),
candidates_desc AS (
  -- Combined primary + alias candidate pool per file, for a human-readable
  -- audit trail -- not re-scored (that's what silver_person_alias/
  -- silver_document_person_override are for), just descriptive.
  SELECT file_id, CONCAT_WS('; ', COLLECT_LIST(cand)) AS candidates_considered
  FROM (
    SELECT DISTINCT u.file_id AS file_id,
      CONCAT(p.person_gedcom_id, ' (', p.given_name, ' ', p.surname,
        ', b.', COALESCE(CAST(YEAR(p.birth_date) AS STRING), '?'),
        ', d.', COALESCE(CAST(YEAR(p.death_date) AS STRING), '?'), ')') AS cand
    FROM unmatched u
    JOIN genealogy.gold_person_life p
      ON UPPER(TRIM(u.surname)) = UPPER(TRIM(p.surname))
     AND (
       UPPER(TRIM(u.forename_clean)) = UPPER(TRIM(p.given_name))
       OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(p.given_name)), ' '), UPPER(TRIM(u.forename_clean)))
     )
    UNION
    SELECT DISTINCT u.file_id AS file_id,
      CONCAT(a.person_gedcom_id, ' (', pl.given_name, ' ', pl.surname, ' via ', a.alias_type,
        ', b.', COALESCE(CAST(YEAR(pl.birth_date) AS STRING), '?'),
        ', d.', COALESCE(CAST(YEAR(pl.death_date) AS STRING), '?'), ')') AS cand
    FROM unmatched u
    JOIN genealogy.silver_person_alias a
      ON UPPER(TRIM(u.surname)) = UPPER(TRIM(a.alias_surname))
     AND (
       UPPER(TRIM(u.forename_clean)) = UPPER(TRIM(a.alias_given_name))
       OR ARRAY_CONTAINS(SPLIT(UPPER(TRIM(a.alias_given_name)), ' '), UPPER(TRIM(u.forename_clean)))
     )
    JOIN genealogy.gold_person_life pl ON a.person_gedcom_id = pl.person_gedcom_id
  ) x
  GROUP BY file_id
)
INSERT INTO genealogy.silver_document_match_exception
  (file_id, file_name, doc_type_detected, year, surname, forename,
   candidate_count, reason, candidates_considered, logged_at)
SELECT
  u.file_id, u.file_name, u.doc_type_detected, u.year, s.surname, s.forename_clean,
  n.name_matches + a.alias_matches,
  'NO_PLAUSIBLE_CANDIDATE',
  cd.candidates_considered,
  CURRENT_TIMESTAMP()
FROM surname_check s
JOIN name_check n ON s.file_id = n.file_id
JOIN alias_check a ON s.file_id = a.file_id
JOIN unmatched u ON u.file_id = s.file_id
LEFT JOIN candidates_desc cd ON cd.file_id = s.file_id
WHERE n.name_matches > 0 OR a.alias_matches > 0;

-- %% [markdown]
-- ## Cell 7 — Source/doc_type mapping view
--
-- Maps silver_source title patterns to doc_type_detected vocabulary.
-- Extend the values list as new source_title values appear when processing additional surname branches.

-- %%
-- %sql
CREATE OR REPLACE VIEW genealogy.v_source_doctype_map AS
SELECT source_title, doc_type_category FROM (VALUES
  -- England & Wales certificates
  ('Certified Copy of an Entry at Birth',              'BirthCertificate'),
  ('Certified Copy of an Entry of Marriage',           'MarriageCertificate'),
  ('Certified Copy of an Entry of Death',              'DeathCertificate'),
  ('Certified Copy of an entry at Death',              'DeathCertificate'),
  -- England census
  ('1841 England Census',                              'Census'),
  ('1851 England Census',                              'Census'),
  ('1861 England Census',                              'Census'),
  ('1871 England Census',                              'Census'),
  ('1881 England Census',                              'Census'),
  ('1891 England Census',                              'Census'),
  ('1901 England Census',                              'Census'),
  ('1911 England Census',                              'Census'),
  ('1921 England Census',                              'Census'),
  ('1939 England and Wales Register',                  'Census'),
  -- Scotland census
  ('1841 Scotland Census',                             'Census'),
  ('1851 Scotland Census',                             'Census'),
  ('1861 Scotland Census',                             'Census'),
  ('1871 Scotland Census',                             'Census'),
  ('1881 Scotland Census',                             'Census'),
  ('1891 Scotland Census',                             'Census'),
  ('1901 Scotland Census',                             'Census'),
  ('1911 Scotland Census',                             'Census'),
  ('1921 Scotland Census',                             'Census'),
  -- US census
  ('1850 United States Federal Census',                'Census'),
  ('1860 United States Federal Census',                'Census'),
  ('1870 United States Federal Census',                'Census'),
  ('1880 United States Federal Census',                'Census'),
  ('1890 United States Federal Census',                'Census'),
  ('1900 United States Federal Census',                'Census'),
  ('1910 United States Federal Census',                'Census'),
  ('1920 United States Federal Census',                'Census'),
  ('1930 United States Federal Census',                'Census'),
  ('1940 United States Federal Census',                'Census'),
  ('1950 United States Federal Census',                'Census'),
  -- Canada census
  ('1881 Census of Canada',                            'Census'),
  ('1891 Census of Canada',                            'Census'),
  ('1901 Census of Canada',                            'Census'),
  ('1911 Census of Canada',                            'Census'),
  ('1921 Census of Canada',                            'Census'),
  ('1931 Census of Canada',                            'Census'),
  -- Baptism / christening registers
  ('England, Select Births and Christenings, 1538-1975',                          'BaptismRegister'),
  ('Scotland, Select Births and Baptisms, 1564-1950',                             'BaptismRegister'),
  ('England & Wales Christening Records, 1530-1906',                              'BaptismRegister'),
  ('Nottinghamshire, England, Church of England Baptisms, 1813-1919',             'BaptismRegister'),
  ('Nottinghamshire, England, Church of England Baptisms, 1813-1922',             'BaptismRegister'),
  ('Cambridgeshire and Huntingdonshire, England, Church of England Births and Baptisms, 1813-1924', 'BaptismRegister'),
  ('Norfolk, England, Church of England Births and Baptisms, 1813-1919',          'BaptismRegister'),
  ('London, England, Births and Baptisms, 1813-1906',                             'BaptismRegister'),
  -- Marriage registers & OPR
  ('Nottinghamshire, England, Church of England Marriages and Banns, 1754-1937',  'MarriageCertificate'),
  ('Scotland OPR Banns & Marriages, 1553-1854',                                   'MarriageCertificate'),
  ('Cambridgeshire and Huntingdonshire, England, Church of England Marriages and Banns, 1754-1950', 'MarriageCertificate'),
  ('Norfolk, England, Church of England Marriages and Banns, 1754-1936',          'MarriageCertificate'),
  ('Derbyshire, England, Church of England Marriages and Banns, 1754-1932',       'MarriageCertificate'),
  ('London, England, Marriages and Banns, 1754-1921',                             'MarriageCertificate'),
  ('Sheffield and Rotherham, Yorkshire, England, Church of England Marriages and Banns, 1754-1948', 'MarriageCertificate'),
  ('Gretna Green, Scotland, Marriage Registers, 1794-1895', 'MarriageCertificate'),
  -- Death / burial registers
  ('Nottinghamshire, England, Church of England Burials, 1813-1994',               'BurialRegister'),
  ('Cambridgeshire and Huntingdonshire, England, Church of England Deaths and Burials, 1813-1997', 'BurialRegister'),
  ('Norfolk, England, Church of England Deaths and Burials, 1813-1995',            'BurialRegister'),
  ('Web: UK, Burial and Cremation Index, 1576-2014',                               'BurialRegister'),
  ('Scotland Statutory Death Register',                                            'DeathCertificate'),
  -- Birth indexes (replaces BMDIndex for birth-specific sources)
  ('England & Wales, Birth Index: 1984-2005',                                     'BirthIndex'),
  ('England & Wales, FreeBMD Birth Index, 1837-1915',                             'BirthIndex'),
  ('Scotland Statutory Register Births Index, 1855-',                             'BirthIndex'),
  -- Marriage indexes (replaces BMDIndex for marriage-specific sources)
  ('England & Wales, Marriage Index: 1916-2005',                                  'MarriageIndex'),
  ('England & Wales, Civil Registration Marriage Index, 1916-2005',               'MarriageIndex'),
  ('England & Wales, Civil Registration Marriage Index, 1837-1915',               'MarriageIndex'),
  ('England & Wales, FreeBMD Marriage Index: 1837-1915',                          'MarriageIndex'),
  ('Scotland Statutory Register Marriages Index, 1855-1930',                      'MarriageIndex'),
  ('England, Select Marriages, 1538-1973',                                        'MarriageIndex'),
  ('England, Select Marriages, 1538\u20131973',                                  'MarriageIndex'),
  ('Scotland, Select Marriages, 1561-1910',                                       'MarriageIndex'),
  -- Death indexes (replaces BMDIndex for death-specific sources)
  ('England & Wales, Death Index: 1984-2005',                                     'DeathIndex'),
  ('England and Wales, Death Index, 1989-2019',                                   'DeathIndex'),
  ('England & Wales, Civil Registration Death Index, 1916-2007',                  'DeathIndex'),
  ('England & Wales, FreeBMD Death Index: 1837-1915',                             'DeathIndex'),
  ('England, Select Deaths and Burials, 1538-1991',                               'DeathIndex'),
  -- Mixed BMD transcript (covers births, marriages AND burials in one source title —
  -- cannot be disambiguated by title alone, so mapped to OTHER)
  ('Norfolk, England, Transcripts of Church of England Baptism, Marriage and Burial Registers, 1600-1935', 'OTHER'),
  -- Military records
  ('UK, World War I Service Records, 1914-1920',                                  'MilitaryRecord'),
  ('UK, British Army World War I Service Records, 1914-1920',                     'MilitaryRecord'),
  ('British Army WWI Service Records, 1914-1920',                                 'MilitaryRecord'),
  ('UK, World War II Service Records',                                            'MilitaryRecord'),
  ('UK, Soldiers Died in the Great War, 1914-1919',                               'MilitaryRecord'),
  ('UK,  British Army World War I Pension Records 1914-1920',                     'MilitaryRecord'),
  ('UK, Army Registers of Soldiers\' Effects, 1901-1929',                        'MilitaryRecord'),
  ('Australia, World War II Military Service Records, 1939-1945',                 'MilitaryRecord'),
  ('UK, Navy Lists, 1888-1970',                                                   'MilitaryRecord'),
  ('UK, Royal Air Force Airmen Records, 1918-1940',                               'MilitaryRecord'),
  -- Newspapers
  ('UK and Ireland, Newspapers.com\u2122 Marriage Index, 1800s-current',         'NewspaperClipping'),
  ('U.S., Newspapers.com Obituary Index, 1800s-current',                          'NewspaperClipping'),
  ('Canada, Newspapers.com Obituary Index, 1800s-current',                        'NewspaperClipping'),
  ('UK and Ireland, Newspapers.com\u2122 Obituary Index, 1800s-current',         'NewspaperClipping'),
  -- Electoral
  ('UK, Electoral Registers, 2003-2010',                                          'ElectoralRegister'),
  ('UK, Electoral Registers, 2011-2018',                                          'ElectoralRegister'),
  ('Australia, Electoral Rolls, 1903-1980',                                       'ElectoralRegister'),
  ('New Zealand, Electoral Rolls, 1853-2010',                                     'ElectoralRegister'),
  ('London, England, Electoral Registers, 1832-1965',                             'ElectoralRegister'),
  -- Passenger lists
  ('UK, Outward Passenger Lists, 1890-1960',                                      'PassengerList'),
  ('UK Incoming Passenger Lists, 1878-1960',                                      'PassengerList'),
  ('New York Passenger Lists, 1820-1957',                                         'PassengerList'),
  ('Pennsylvania, U.S., Arriving Passenger and Crew Lists, 1800-1962',            'PassengerList'),
  -- Other
  ('England & Wales, National Probate Calendar (Index of Wills and Administrations),1861-1941', 'Probate'),
  ('Scotland, Burial Monument Inscriptions, 1507-2019',                           'MonumentalInscription'),
  ('North Lanarkshire, Scotland, Poor Law Applications and Registers, 1849-1917', 'PoorLawRecord'),
  ('UK, City and County Directories, 1766 - 1946',                                'Directory'),
  ('England & Wales, Criminal Registers, 1791-1892',                              'CriminalRecord'),
  ('Web: Scotland, Prison Records Index, 1828-1878',                              'CriminalRecord'),
  ('UK, Calendar of Prisoners, 1868-1929',                                        'CriminalRecord')
) AS t(source_title, doc_type_category);

-- %% [markdown]
-- ## Cell 8 — Populate gold_source_coverage
--
-- Run after silver_document_person is fully populated and v_source_doctype_map is created.

-- %%
-- %sql
TRUNCATE TABLE genealogy.gold_source_coverage;

INSERT INTO genealogy.gold_source_coverage (
  person_gedcom_id, source_title, source_category,
  ancestry_record_id, citation_date, citation_text, citation_url,
  has_document, has_transcript, matched_file_ids, coverage_status, refreshed_at
)
WITH

event_person AS (
  SELECT DISTINCT ep.event_id, ep.person_id AS person_gedcom_id
  FROM genealogy.silver_event_participant ep
  WHERE ep.data_source = 'recorded' --exclude derived parentage events
),

citations AS (
  -- One row per (person, source_xref, citation_date, ancestry_record_id).
  -- ancestry_record_id = _APID from Ancestry, identifying a specific record
  -- within a collection. For family records (marriages), husband_id or wife_id
  -- is used instead of person_id. For non-Ancestry sources, ancestry_record_id
  -- is NULL and all citations for the same source_title should group by citation_date to allow for a person with multiple certificate citations (e.g. themselves and their child).
  --
  -- citation_year fallback chain:
  -- 1. 4-digit year extracted from citation_date (free text e.g. "21 Jan 1857", "Dec 1856")
  -- 2. 4-digit year extracted from citation_text (often contains event year)
  --    NOTE: citation_text may be truncated due to line breaks in source data —
  --    this is a known data pipeline issue to fix upstream in the GEDCOM ingestion.
  --    When truncated, this fallback returns NULL and the chain continues.
  --    Exclude Census as the text can contain estimate birth date of the person and not the census year
  -- 3. Title regex — Census only. For all other source types the title gives the
  --    collection date range (e.g. 1530 from "1530-1906") not the event year,
  --    so is deliberately excluded for non-Census categories.
  -- 4. birth_year / death_year from gold_person_life — last resort for parish
  --    registers where citation_date and citation_text contain no year.
  SELECT
    ep.person_gedcom_id,
    ss.source_title,
    COALESCE(dm.doc_type_category, 'OTHER')                              AS source_category,
    COALESCE(
      TRY_CAST(REGEXP_EXTRACT(MAX(es.citation_date), '(\\d{4})') AS INT),
      -- Text regex for non-Census
      CASE WHEN COALESCE(dm.doc_type_category, 'OTHER') <> 'Census'
        THEN TRY_CAST(REGEXP_EXTRACT(MAX(es.citation_text), '(\\d{4})') AS INT)
      END,
      -- Title regex only for Census — gives collection range for all other types
      CASE WHEN COALESCE(dm.doc_type_category, 'OTHER') = 'Census'
        THEN TRY_CAST(REGEXP_EXTRACT(ss.source_title, '(\\d{4})') AS INT)
      END,
      CASE
        WHEN COALESCE(dm.doc_type_category, 'OTHER')
             IN ('BirthCertificate', 'BaptismRegister', 'BirthIndex')
        THEN pl.birth_year
        WHEN COALESCE(dm.doc_type_category, 'OTHER')
             IN ('DeathCertificate', 'BurialRegister', 'DeathIndex')
        THEN pl.death_year
      END
    )                                                                    AS citation_year,
    COALESCE(es.citation_ancestry_person_id,
             es.citation_ancestry_husband_id,
             es.citation_ancestry_wife_id)                               AS ancestry_record_id,
    MAX(es.citation_date)                                                AS citation_date,
    MAX(es.citation_text)                                                AS citation_text,
    MAX(es.citation_url)                                                 AS citation_url
  FROM genealogy.silver_event_source es
  JOIN event_person ep ON es.event_id = ep.event_id
  LEFT JOIN genealogy.silver_source ss ON es.source_xref = ss.record_xref
  LEFT JOIN genealogy.v_source_doctype_map dm ON ss.source_title = dm.source_title
  LEFT JOIN genealogy.gold_person_life pl ON ep.person_gedcom_id = pl.person_gedcom_id
  GROUP BY
    ep.person_gedcom_id,
    ss.source_title,
    COALESCE(dm.doc_type_category, 'OTHER'),
    TRY_CAST(REGEXP_EXTRACT(ss.source_title, '(\\d{4})') AS INT),
    es.citation_date,
    COALESCE(es.citation_ancestry_person_id,
             es.citation_ancestry_husband_id,
             es.citation_ancestry_wife_id),
    pl.birth_year,
    pl.death_year
),

doc_matches AS (
  SELECT
    sdp.person_gedcom_id,
    ot.doc_type_detected,
    YEAR(TRY_CAST(ot.year AS DATE))    AS doc_year,
    sdp.file_id,
    ot.transcribed_text IS NOT NULL    AS has_transcript
  FROM genealogy.silver_document_person sdp
  JOIN genealogy.ocr_transcriptions ot ON sdp.file_id = ot.file_id
),

marriage_years AS (
  SELECT person_gedcom_id, event_year_parsed AS marriage_year
  FROM genealogy.gold_person_event_timeline
  WHERE event_type = 'MARR'
    AND event_year_parsed IS NOT NULL
),

doc_coverage AS (
  -- Match citations to held documents on person + doc type + year proximity.
  -- citation_year is derived from the fallback chain above so is the actual
  -- event year for most source types.
  -- Census uses the title-regex fallback year and requires exact match.
  -- Military, probate, electoral etc have no year guard.
  SELECT
    c.person_gedcom_id,
    c.source_category,
    c.citation_year,
    COUNT(DISTINCT dm.file_id) > 0                                      AS has_document,
    COUNT(DISTINCT CASE WHEN dm.has_transcript THEN dm.file_id END) > 0 AS has_transcript,
    CONCAT_WS(',', COLLECT_LIST(DISTINCT dm.file_id))                   AS matched_file_ids
  FROM citations c
  JOIN doc_matches dm
    ON  c.person_gedcom_id = dm.person_gedcom_id
    AND c.source_category  = dm.doc_type_detected
    AND (
      (c.source_category = 'Census'
          AND dm.doc_year = c.citation_year)
      OR (c.source_category IN ('BirthCertificate', 'BaptismRegister', 'BirthIndex')
          AND ABS(dm.doc_year - c.citation_year) <= 2)
      OR (c.source_category IN ('DeathCertificate', 'BurialRegister', 'DeathIndex')
          AND ABS(dm.doc_year - c.citation_year) <= 2)
      OR c.source_category NOT IN (
          'Census', 'BirthCertificate', 'BaptismRegister', 'BirthIndex',
          'MarriageCertificate', 'MarriageIndex',
          'DeathCertificate', 'BurialRegister', 'DeathIndex'
         )
    )
    GROUP BY c.person_gedcom_id, c.source_category, c.citation_year
  -- Marriage: join to all marriage years and match if doc within ±2 of any
  -- Having added extra filter to match doc year to citation year (to avoid false matches like father cited on child's marriage certificate), this union may be redundant. Unless it was added due to missing citation dates on some marriage sources - in which case these dates need to be added
  UNION ALL
  SELECT
    c.person_gedcom_id,
    c.source_category,
    c.citation_year,
    COUNT(DISTINCT dm.file_id) > 0                                      AS has_document,
    COUNT(DISTINCT CASE WHEN dm.has_transcript THEN dm.file_id END) > 0 AS has_transcript,
    CONCAT_WS(',', COLLECT_LIST(DISTINCT dm.file_id))                   AS matched_file_ids
  FROM citations c
  JOIN doc_matches dm
    ON  c.person_gedcom_id = dm.person_gedcom_id
    AND c.source_category  = dm.doc_type_detected
  JOIN marriage_years my
    ON  my.person_gedcom_id = c.person_gedcom_id
    AND ABS(dm.doc_year - my.marriage_year) <= 2 -- doc matches event
    AND dm.doc_year = c.citation_year -- doc matches citation
  WHERE c.source_category IN ('MarriageCertificate', 'MarriageIndex')
  GROUP BY c.person_gedcom_id, c.source_category, c.citation_year
)

SELECT
  c.person_gedcom_id, c.source_title, c.source_category,
  c.ancestry_record_id, c.citation_date, c.citation_text, c.citation_url,
  COALESCE(dc.has_document, FALSE)    AS has_document,
  COALESCE(dc.has_transcript, FALSE)  AS has_transcript,
  dc.matched_file_ids,
  CASE
    -- Index-only sources: no physical document to download
    WHEN c.source_category IN ('BirthIndex', 'MarriageIndex', 'DeathIndex') THEN 'INDEX_ONLY'
    WHEN c.source_category = 'OTHER_NO_FILE'                                THEN 'NOT_APPLICABLE'
    -- Non-Ancestry citations (no _APID) imply document held outside system
    WHEN c.ancestry_record_id IS NULL
         AND c.source_category = 'OTHER'                                    THEN 'NOT_APPLICABLE'
    WHEN dc.has_transcript = TRUE                                           THEN 'COVERED'
    WHEN dc.has_document   = TRUE                                           THEN 'DOCUMENT_NO_TRANSCRIPT'
    ELSE                                                                         'UNCOVERED'
  END AS coverage_status,
  CURRENT_TIMESTAMP()
FROM citations c
LEFT JOIN doc_coverage dc
  ON  c.person_gedcom_id = dc.person_gedcom_id
  AND c.source_category  = dc.source_category
  AND (
    -- Mirror the same year guard logic used in doc_coverage above
    (c.source_category = 'Census'
        AND c.citation_year = dc.citation_year)
    OR (c.source_category IN ('BirthCertificate', 'BaptismRegister', 'BirthIndex')
        AND ABS(dc.citation_year - c.citation_year) <= 2)
    OR c.source_category IN ('MarriageCertificate', 'MarriageIndex')
    OR (c.source_category IN ('DeathCertificate', 'BurialRegister', 'DeathIndex')
        AND ABS(dc.citation_year - c.citation_year) <= 2)
    OR c.source_category NOT IN (
        'Census', 'BirthCertificate', 'BaptismRegister', 'BirthIndex',
        'MarriageCertificate', 'MarriageIndex',
        'DeathCertificate', 'BurialRegister', 'DeathIndex'
       )
  );

-- %% [markdown]
-- ## Cell 9 — Coverage summary dashboard

-- %%
-- %sql
SELECT coverage_status, COUNT(*) AS n
FROM genealogy.gold_source_coverage sc
--LEFT JOIN genealogy.gold_ancestral_proximity ap ON sc.person_gedcom_id = ap.person_id
--WHERE ap.ancestral_proximity = 0
GROUP BY coverage_status
ORDER BY n DESC;

-- %% [markdown]
-- ## Cell 10 — People with most uncovered citations

-- %%
-- %sql
SELECT
  p.given_name || ' ' || p.surname as display_name,
  year(p.birth_date) as birth_year,
  year(p.death_date) as death_year,
  b.branch,
  COUNT(*) AS uncovered_citations,
  COLLECT_LIST(DISTINCT sc.source_title) AS missing_source_types
FROM genealogy.gold_source_coverage sc
JOIN genealogy.gold_person_life p ON sc.person_gedcom_id = p.person_gedcom_id
JOIN genealogy.gold_person_branch b ON sc.person_gedcom_id = b.person_gedcom_id
WHERE sc.coverage_status = 'UNCOVERED'
GROUP BY 1,2,3,4
ORDER BY uncovered_citations DESC
LIMIT 50;

-- %% [markdown]
-- ## Cell 11 — Verify a specific person
--
-- Substitute a real person_gedcom_id from your tree.

-- %%
-- %sql
SELECT
  sc.source_title,
  sc.source_category,
  sc.citation_date,
  sc.coverage_status,
  sc.matched_file_ids
FROM genealogy.gold_source_coverage sc
WHERE sc.person_gedcom_id = (select person_gedcom_id from genealogy.gold_person_life where given_name = 'Robert' and surname = 'Ambrose' and death_year = 1865)
ORDER BY sc.source_category, sc.citation_date;
