# %%
# %sql
-- ============================================================
-- NOTEBOOK A: Research Actions (v3)
-- Run BEFORE Notebook B (signal detection)
--
-- v3 changes vs v2.1:
--   ref_signal_weights:
--     REMOVED:  SIGNAL_POSSIBLE_WWI, SIGNAL_POSSIBLE_WWII,
--               SIGNAL_POSSIBLE_OCCUPATION, SIGNAL_TRANSCRIPT_AVAILABLE
--     ADDED (completeness): SIGNAL_MISSING_OCCUPATION, SIGNAL_MISSING_BURIAL,
--                           SIGNAL_NO_RESIDENCE, SIGNAL_UNCONFIRMED_MILITARY
--     ADDED (evidence):     SIGNAL_NO_DOCUMENTS_AT_ALL, SIGNAL_UNRESOLVED_CONFLICT,
--                           SIGNAL_TRANSCRIPT_ONLY_FACTS
--     WIDENED:  SIGNAL_UNCOVERED_SOURCES — proximity <= 2 restriction removed
--     ADDED (narrative):    SIGNAL_CONFIRMED_MILITARY, SIGNAL_LARGE_FAMILY,
--                           SIGNAL_TRANSCRIPT_RICH, SIGNAL_NEWSPAPER_MENTION,
--                           SIGNAL_WILL_OR_PROBATE
--   gold_research_action:
--     ADDED: SEARCH_BURIAL_RECORDS, SEARCH_MILITARY_RECORDS
--   gold_research_signal_action:
--     New action mappings for all new signals
--     Removed mappings for retired signals
-- ============================================================

CREATE OR REPLACE TABLE genealogy.gold_research_action (
  action_code     STRING,
  action_label    STRING,
  action_category STRING,
  default_effort  INT
);

INSERT INTO genealogy.gold_research_action VALUES
-- Evidence & identity
('CLUSTER_SOURCES',         'Find corroborating sources',                         'evidence',  2),
('REVIEW_EXISTING_SOURCES', 'Review existing sources closely',                     'evidence',  1),
('RESOLVE_NAME_VARIANTS',   'Resolve name variants / aliases',                     'identity',  2),
('RESOLVE_CONFLICTS',       'Investigate and resolve transcript vs tree conflicts', 'evidence',  2),

-- Lifecycle
('SEARCH_BIRTH_RECORDS',    'Search for birth/baptism records',                    'lifecycle', 1),
('SEARCH_DEATH_RECORDS',    'Search for death/burial records',                     'lifecycle', 1),
('SEARCH_BURIAL_RECORDS',   'Search for burial/cremation records',                 'lifecycle', 1),
('SEARCH_MARRIAGE_RECORDS', 'Search for marriage records',                         'lifecycle', 1),
('SEARCH_CENSUS',           'Search census / population records',                  'lifecycle', 1),

-- Document pipeline
('DOWNLOAD_DOCUMENTS',      'Download cited documents from Ancestry/archive',      'evidence',  2),
('TRANSCRIBE_DOCUMENTS',    'Run OCR transcription pipeline on downloaded docs',   'evidence',  1),

-- Family structure
('TRACE_PARENTS',           'Identify or verify parents',                          'family',    2),
('TRACE_CHILDREN_FORWARD',  'Trace children forward',                              'family',    2),
('VERIFY_FAMILY_EVENTS',    'Source family events (marriage, children)',            'family',    1),

-- Contextual / narrative
('INVESTIGATE_MIGRATION',   'Investigate migration and movement',                  'narrative', 2),
('SEARCH_MILITARY_RECORDS', 'Search military service records',                     'narrative', 2),
('INVESTIGATE_MILITARY',    'Investigate and record confirmed military service',   'narrative', 3),
('INVESTIGATE_OCCUPATION',  'Research occupational history and records',           'narrative', 2),
('INVESTIGATE_LATER_LIFE',  'Search for late-life events and records',             'narrative', 2);

# %%
# %sql
-- ============================================================
-- CELL 2: ref_intent_category_weights
-- Unchanged from v2.1 — weights sum to 1.0 per intent
-- ============================================================

CREATE OR REPLACE TABLE genealogy.ref_intent_category_weights (
  intent   STRING,
  category STRING,
  weight   DOUBLE
);

INSERT OVERWRITE genealogy.ref_intent_category_weights VALUES
  ('integrity', 'evidence',     0.60),
  ('integrity', 'completeness', 0.40),
  ('narrative', 'texture',      0.45),
  ('narrative', 'family',       0.30),
  ('narrative', 'context',      0.25);

# %%
# %sql
-- ============================================================
-- CELL 3: ref_signal_weights (v3)
--
-- v3 changes vs v2.1:
--   REMOVED from narrative/texture:
--     SIGNAL_POSSIBLE_WWI  — replaced by SIGNAL_UNCONFIRMED_MILITARY (completeness)
--     SIGNAL_POSSIBLE_WWII — replaced by SIGNAL_UNCONFIRMED_MILITARY (completeness)
--   REMOVED from narrative/context:
--     SIGNAL_POSSIBLE_OCCUPATION  — superseded by SIGNAL_MISSING_OCCUPATION
--     SIGNAL_TRANSCRIPT_AVAILABLE — superseded by SIGNAL_TRANSCRIPT_RICH
--   ADDED to completeness:
--     SIGNAL_UNCONFIRMED_MILITARY — born 1880-1928, no _MILT or MilitaryRecord doc
--     SIGNAL_MISSING_OCCUPATION   — male, working-age lifespan, num_occupations = 0
--     SIGNAL_MISSING_BURIAL       — post-1837 death, no burial/cremation event
--     SIGNAL_NO_RESIDENCE         — lifespan >= 20 years, zero residence events
--   ADDED to evidence:
--     SIGNAL_NO_DOCUMENTS_AT_ALL  — zero matched files in silver_document_person
--     SIGNAL_UNRESOLVED_CONFLICT  — CONFLICT rows in gold_fact_comparison with no override
--     SIGNAL_TRANSCRIPT_ONLY_FACTS — TRANSCRIPT_ONLY rows in gold_fact_comparison
--   WIDENED:
--     SIGNAL_UNCOVERED_SOURCES — base_score raised 15->20; proximity restriction removed
--   ADDED to narrative/texture:
--     SIGNAL_CONFIRMED_MILITARY — has _MILT event or MilitaryRecord doc
--     SIGNAL_LARGE_FAMILY       — >= 6 children recorded
--     SIGNAL_NEWSPAPER_MENTION  — NewspaperClipping doc filed for person
--     SIGNAL_WILL_OR_PROBATE    — Will or Probate doc filed for person
--   ADDED to narrative/context:
--     SIGNAL_TRANSCRIPT_RICH    — >= 2 non-BMDIndex transcribed docs
--
-- NOTE: Base scores are provisional pending calibration run.
-- Run Notebook B v3 then the calibration notebook to tune empirically.
-- ============================================================

CREATE OR REPLACE TABLE genealogy.ref_signal_weights (
  signal_code  STRING,
  category     STRING,
  intent       STRING,
  base_score   INT,
  reason_label STRING,
  rationale    STRING
);

INSERT OVERWRITE genealogy.ref_signal_weights VALUES

  -- ===========================================================
  -- INTEGRITY — Evidence fragility
  -- ===========================================================
  ('SIGNAL_NO_DOCUMENTS_AT_ALL',       'evidence', 'integrity', 40, 'no documents filed',                'zero matched files — profile entirely uncorroborated by downloaded evidence'),
  ('SIGNAL_FACT_CONFLICT',              'evidence', 'integrity', 30, 'transcript conflicts tree',         'highest integrity risk — document contradicts recorded fact'),
  ('SIGNAL_UNRESOLVED_CONFLICT',        'evidence', 'integrity', 25, 'unresolved transcript conflict',    'active conflict in gold_fact_comparison with no override recorded'),
  ('SIGNAL_TRANSCRIPT_ONLY_FACTS',      'evidence', 'integrity', 20, 'transcript facts not in tree',      'document contains facts not yet reflected in tree — tree is provably incomplete'),
  ('SIGNAL_VERY_LOW_EVIDENCE_DENSITY',  'evidence', 'integrity', 30, 'very low source density (mostly unsourced)', 'avg sources per fact < 0.3 — profile is largely unsourced'),
  ('SIGNAL_SINGLE_SOURCE_DEPENDENCE',   'evidence', 'integrity', 25, 'single-source reliance',            'catches illusion-of-certainty problem'),
  ('SIGNAL_UNSOURCED_FAMILY_EVENTS',    'evidence', 'integrity', 25, 'unsourced family events',           'marriages and child births without sources are research traps'),
  ('SIGNAL_LOW_EVIDENCE_DENSITY',       'evidence', 'integrity', 15, 'low source density (some unsourced facts)', 'avg sources per fact < 1.0 — at least one fact has no source citation'),
  ('SIGNAL_DOCS_NOT_TRANSCRIBED',       'evidence', 'integrity', 15, 'documents not transcribed',         'evidence downloaded but not yet verified via OCR'),
  ('SIGNAL_IMPRECISE_DATES',            'evidence', 'integrity', 10, 'imprecise dates',                   'post-1837 civil registration events where a certificate should exist'),
  ('SIGNAL_INCOMPLETE_NAME',            'evidence', 'integrity', 10, 'incomplete name',                   'suggests exhaustive searches not done'),
  ('SIGNAL_IMPRECISE_PLACES',           'evidence', 'integrity', 10, 'imprecise places',                  'post-1837 records should resolve to town/parish level'),

  -- ===========================================================
  -- INTEGRITY — Structural completeness
  -- ===========================================================
  ('SIGNAL_NO_BIRTH_RECORDED',        'completeness', 'integrity', 30, 'birth not recorded',            NULL),
  ('SIGNAL_MISSING_PARENT',           'completeness', 'integrity', 25, 'missing parent',                NULL),
  ('SIGNAL_NO_DEATH_RECORDED',        'completeness', 'integrity', 20, 'death not recorded',            NULL),
  ('SIGNAL_MISSING_CENSUS_COVERAGE',  'completeness', 'integrity', 20, 'missing expected census',       'person was alive during census year but no RESI event present'),
  -- v3: proximity restriction removed — fires for all with > 1 uncovered source
  ('SIGNAL_UNCOVERED_SOURCES',        'completeness', 'integrity', 20, 'uncovered cited sources',       'cited sources with no downloaded document'),
  ('SIGNAL_NO_MARRIAGES',             'completeness', 'integrity', 15, 'no marriage recorded',          'age-guarded: suppressed for young deaths'),
  ('SIGNAL_LATE_LIFE_GAP',            'completeness', 'integrity', 15, 'late-life records gap',         'no events recorded after age 40 despite expected survival'),
  -- NEW v3
  ('SIGNAL_UNCONFIRMED_MILITARY',     'completeness', 'integrity', 15, 'military service unconfirmed',  'born 1880-1928 — WWI/WWII service neither confirmed nor denied'),
  ('SIGNAL_MISSING_OCCUPATION',       'completeness', 'integrity', 10, 'no occupation recorded',        'male with working-age lifespan and zero occupation events recorded'),
  ('SIGNAL_NO_RESIDENCE',             'completeness', 'integrity', 10, 'no residence events',           'lifespan >= 20 years with zero residence/census events'),
  ('SIGNAL_NO_CHILDREN',              'completeness', 'integrity', 10, 'no children recorded',          'proximity guard: proximity <= 1 only'),
  ('SIGNAL_EARLY_LIFE_ONLY',          'completeness', 'integrity', 10, 'early-life records only',       'classic birth+parents-only profile, no adult records'),
  ('SIGNAL_CHILD_GAPS',               'completeness', 'integrity', 10, 'gaps between child births',     'unusually long inter-birth gap or marriage with no children'),
  ('SIGNAL_MISSING_BURIAL',           'completeness', 'integrity',  8, 'burial not recorded',           'post-1837 death with no burial or cremation event'),

  -- ===========================================================
  -- NARRATIVE — Life texture
  -- ===========================================================
  ('SIGNAL_MIGRANT',             'texture', 'narrative', 30, 'evidence of migration',          NULL),
  ('SIGNAL_CONFIRMED_MILITARY',  'texture', 'narrative', 25, 'confirmed military service',     'has _MILT event or MilitaryRecord document — strong story angle'),
  ('SIGNAL_YOUNG_DEATH',         'texture', 'narrative', 20, 'young death',                    NULL),
  ('SIGNAL_NEWSPAPER_MENTION',   'texture', 'narrative', 25, 'newspaper mention',              'rare: newspaper clipping filed — high story value'),
  ('SIGNAL_WILL_OR_PROBATE',     'texture', 'narrative', 20, 'will or probate record',         'wealth/family dynamics and final wishes — strong narrative anchor'),
  ('SIGNAL_LARGE_FAMILY',        'texture', 'narrative', 15, 'large family (>= 6 children)',   'social history angle; child mortality likely'),
  ('SIGNAL_STORY_WRITTEN',       'texture', 'narrative', -50,'story already written',          'suppresses narrative priority once story is complete'),

  -- ===========================================================
  -- NARRATIVE — Family
  -- ===========================================================
  ('SIGNAL_MULTIPLE_SPOUSES', 'family', 'narrative', 40, 'multiple spouses', NULL),

  -- ===========================================================
  -- NARRATIVE — Context
  -- ===========================================================
  ('SIGNAL_TRANSCRIPT_RICH',     'context', 'narrative', 25, 'rich primary source material',   '>= 2 non-BMDIndex transcribed docs — enough to write a real narrative'),
  ('SIGNAL_HIGH_FAMILY_PAYOFF',  'context', 'narrative', 25, 'high-leverage under-researched family', 'many family events, low source density'),
  ('SIGNAL_VARIED_OCCUPATIONS',  'context', 'narrative', 20, 'varied occupational history',    'multiple distinct occupations — richer life story'),
  ('SIGNAL_POSSIBLE_MARRIAGE',   'context', 'narrative', 15, 'possible unrecorded marriage',   'female in 1939 register with no marriage recorded'),
  ('SIGNAL_POSSIBLE_CHILDREN',   'context', 'narrative', 15, 'possible unrecorded children',   'female in 1911 census born <=1895'),
  ('SIGNAL_POSSIBLE_RESIDENCE',  'context', 'narrative', 15, 'residence records likely findable', 'family events present but census coverage incomplete');

# %%
# %sql
-- ============================================================
-- CELL 4: gold_research_signal_action (v3)
--
-- v3 changes vs v2.1:
--   REMOVED mappings for retired signals:
--     SIGNAL_POSSIBLE_WWI, SIGNAL_POSSIBLE_WWII,
--     SIGNAL_POSSIBLE_OCCUPATION, SIGNAL_TRANSCRIPT_AVAILABLE
--   ADDED mappings for new signals:
--     SIGNAL_UNCONFIRMED_MILITARY, SIGNAL_CONFIRMED_MILITARY,
--     SIGNAL_MISSING_OCCUPATION, SIGNAL_MISSING_BURIAL,
--     SIGNAL_NO_RESIDENCE, SIGNAL_NO_DOCUMENTS_AT_ALL,
--     SIGNAL_UNRESOLVED_CONFLICT, SIGNAL_TRANSCRIPT_ONLY_FACTS,
--     SIGNAL_LARGE_FAMILY, SIGNAL_TRANSCRIPT_RICH,
--     SIGNAL_NEWSPAPER_MENTION, SIGNAL_WILL_OR_PROBATE
-- ============================================================

CREATE OR REPLACE TABLE genealogy.gold_research_signal_action (
  signal_code   STRING,
  action_code   STRING,
  action_weight INT
);

INSERT INTO genealogy.gold_research_signal_action VALUES

  -- Evidence quality
  ('SIGNAL_NO_DOCUMENTS_AT_ALL',       'DOWNLOAD_DOCUMENTS',      3),
  ('SIGNAL_NO_DOCUMENTS_AT_ALL',       'CLUSTER_SOURCES',         2),
  ('SIGNAL_UNRESOLVED_CONFLICT',       'RESOLVE_CONFLICTS',       3),
  ('SIGNAL_TRANSCRIPT_ONLY_FACTS',     'REVIEW_EXISTING_SOURCES', 3),
  ('SIGNAL_TRANSCRIPT_ONLY_FACTS',     'RESOLVE_CONFLICTS',       2),
  ('SIGNAL_FACT_CONFLICT',             'RESOLVE_CONFLICTS',       3),
  ('SIGNAL_DOCS_NOT_TRANSCRIBED',      'TRANSCRIBE_DOCUMENTS',    3),
  ('SIGNAL_UNCOVERED_SOURCES',         'DOWNLOAD_DOCUMENTS',      3),
  ('SIGNAL_LOW_EVIDENCE_DENSITY',      'CLUSTER_SOURCES',         3),
  ('SIGNAL_LOW_EVIDENCE_DENSITY',      'SEARCH_CENSUS',           2),
  ('SIGNAL_LOW_EVIDENCE_DENSITY',      'REVIEW_EXISTING_SOURCES', 2),
  ('SIGNAL_VERY_LOW_EVIDENCE_DENSITY', 'CLUSTER_SOURCES',         3),
  ('SIGNAL_VERY_LOW_EVIDENCE_DENSITY', 'SEARCH_CENSUS',           2),
  ('SIGNAL_VERY_LOW_EVIDENCE_DENSITY', 'REVIEW_EXISTING_SOURCES', 2),
  ('SIGNAL_SINGLE_SOURCE_DEPENDENCE',  'REVIEW_EXISTING_SOURCES', 3),
  ('SIGNAL_SINGLE_SOURCE_DEPENDENCE',  'CLUSTER_SOURCES',         2),
  ('SIGNAL_UNSOURCED_FAMILY_EVENTS',   'VERIFY_FAMILY_EVENTS',    3),

  -- Identity quality
  ('SIGNAL_INCOMPLETE_NAME',   'SEARCH_MARRIAGE_RECORDS', 3),
  ('SIGNAL_INCOMPLETE_NAME',   'SEARCH_BIRTH_RECORDS',    2),
  ('SIGNAL_IMPRECISE_DATES',   'REVIEW_EXISTING_SOURCES', 3),
  ('SIGNAL_IMPRECISE_DATES',   'SEARCH_BIRTH_RECORDS',    2),
  ('SIGNAL_IMPRECISE_DATES',   'SEARCH_DEATH_RECORDS',    2),
  ('SIGNAL_IMPRECISE_PLACES',  'REVIEW_EXISTING_SOURCES', 3),
  ('SIGNAL_IMPRECISE_PLACES',  'CLUSTER_SOURCES',         2),

  -- Lifecycle gaps
  ('SIGNAL_NO_BIRTH_RECORDED',       'SEARCH_BIRTH_RECORDS',    3),
  ('SIGNAL_NO_DEATH_RECORDED',       'SEARCH_DEATH_RECORDS',    3),
  ('SIGNAL_NO_MARRIAGES',            'SEARCH_MARRIAGE_RECORDS', 3),
  ('SIGNAL_NO_CHILDREN',             'SEARCH_CENSUS',           3),
  ('SIGNAL_NO_CHILDREN',             'SEARCH_BIRTH_RECORDS',    2),
  ('SIGNAL_MISSING_CENSUS_COVERAGE', 'SEARCH_CENSUS',           3),
  ('SIGNAL_LATE_LIFE_GAP',           'INVESTIGATE_LATER_LIFE',  3),
  ('SIGNAL_LATE_LIFE_GAP',           'SEARCH_DEATH_RECORDS',    2),
  ('SIGNAL_EARLY_LIFE_ONLY',         'SEARCH_CENSUS',           3),
  ('SIGNAL_EARLY_LIFE_ONLY',         'CLUSTER_SOURCES',         2),
  ('SIGNAL_CHILD_GAPS',              'SEARCH_BIRTH_RECORDS',    3),
  ('SIGNAL_CHILD_GAPS',              'SEARCH_CENSUS',           2),
  ('SIGNAL_MISSING_BURIAL',          'SEARCH_BURIAL_RECORDS',   3),
  ('SIGNAL_MISSING_BURIAL',          'SEARCH_DEATH_RECORDS',    2),
  ('SIGNAL_NO_RESIDENCE',            'SEARCH_CENSUS',           3),

  -- Family structure
  ('SIGNAL_MISSING_PARENT',    'TRACE_PARENTS',           3),
  ('SIGNAL_MULTIPLE_SPOUSES',  'VERIFY_FAMILY_EVENTS',    3),
  ('SIGNAL_LARGE_FAMILY',      'TRACE_CHILDREN_FORWARD',  3),
  ('SIGNAL_LARGE_FAMILY',      'SEARCH_BIRTH_RECORDS',    2),

  -- Military
  -- UNCONFIRMED -> search; CONFIRMED -> deeper investigation
  ('SIGNAL_UNCONFIRMED_MILITARY', 'SEARCH_MILITARY_RECORDS', 3),
  ('SIGNAL_CONFIRMED_MILITARY',   'INVESTIGATE_MILITARY',    3),

  -- Occupations
  ('SIGNAL_MISSING_OCCUPATION', 'SEARCH_CENSUS',           3),
  ('SIGNAL_MISSING_OCCUPATION', 'INVESTIGATE_OCCUPATION',  2),
  ('SIGNAL_VARIED_OCCUPATIONS', 'INVESTIGATE_OCCUPATION',  3),

  -- Narrative context
  ('SIGNAL_MIGRANT',           'INVESTIGATE_MIGRATION',   3),
  ('SIGNAL_YOUNG_DEATH',       'REVIEW_EXISTING_SOURCES', 3),
  ('SIGNAL_YOUNG_DEATH',       'SEARCH_DEATH_RECORDS',    2),
  ('SIGNAL_TRANSCRIPT_RICH',   'REVIEW_EXISTING_SOURCES', 2),
  ('SIGNAL_HIGH_FAMILY_PAYOFF','VERIFY_FAMILY_EVENTS',    3),
  ('SIGNAL_HIGH_FAMILY_PAYOFF','CLUSTER_SOURCES',         2),
  ('SIGNAL_NEWSPAPER_MENTION', 'REVIEW_EXISTING_SOURCES', 3),
  ('SIGNAL_WILL_OR_PROBATE',   'REVIEW_EXISTING_SOURCES', 3),
  ('SIGNAL_POSSIBLE_MARRIAGE', 'SEARCH_MARRIAGE_RECORDS', 3),
  ('SIGNAL_POSSIBLE_MARRIAGE', 'SEARCH_CENSUS',           2),
  ('SIGNAL_POSSIBLE_CHILDREN', 'SEARCH_BIRTH_RECORDS',    3),
  ('SIGNAL_POSSIBLE_CHILDREN', 'SEARCH_CENSUS',           2),
  ('SIGNAL_POSSIBLE_RESIDENCE','SEARCH_CENSUS',           3),
  ('SIGNAL_POSSIBLE_RESIDENCE','CLUSTER_SOURCES',         2);
  -- Note: SIGNAL_STORY_WRITTEN is a suppression signal — no research actions triggered

# %%
# %sql
-- ============================================================
-- CELL 5: Verification queries
-- ============================================================

-- 1. Signals with weights but no action mapping
-- Expected exemptions: SIGNAL_STORY_WRITTEN (suppression only)
-- SIGNAL_TRANSCRIPT_RICH has no action — it is a positive confirmatory signal
SELECT
  w.signal_code, w.intent, w.category, w.base_score
FROM genealogy.ref_signal_weights w
LEFT JOIN genealogy.gold_research_signal_action a ON a.signal_code = w.signal_code
WHERE a.signal_code IS NULL
  AND w.signal_code NOT IN ('SIGNAL_STORY_WRITTEN', 'SIGNAL_TRANSCRIPT_RICH',
                             'SIGNAL_NEWSPAPER_MENTION', 'SIGNAL_WILL_OR_PROBATE')
ORDER BY w.intent, w.category;

# %%
# %sql
-- 2. Action mappings pointing to non-existent action codes (should return 0 rows)
SELECT sa.signal_code, sa.action_code
FROM genealogy.gold_research_signal_action sa
LEFT JOIN genealogy.gold_research_action a ON a.action_code = sa.action_code
WHERE a.action_code IS NULL;

-- 3. Category weights — confirm each intent sums to 1.0
SELECT
  intent,
  ROUND(SUM(weight), 2) AS total_weight,
  COLLECT_LIST(CONCAT(category, '=', CAST(weight AS STRING))) AS breakdown
FROM genealogy.ref_intent_category_weights
GROUP BY intent ORDER BY intent;
