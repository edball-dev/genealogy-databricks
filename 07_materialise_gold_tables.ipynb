# %% [markdown]
# # Notebook 07: Gold-layer views + gold_person_event_timeline
#
# Materialises/source-controls the core gold-layer person/event views, and builds
# the gold_person_event_timeline table that depends on them.
#
# ## Run order
# Run after Notebook 05a (silver_event_date) and Notebook 04 (silver_person,
# silver_event, silver_event_participant). Cells must run in order -- gold_event
# must exist before gold_person_life, which must exist before
# gold_person_event_timeline.
#
# ## What's here
# - **gold_event** (view) -- one row per parsed life event, resolving
#   silver_event_date's start/end range to a single representative date per event.
# - **gold_person_life** (view) -- one row per person, birth/death dates and
#   years derived from gold_event.
# - **gold_person_event_timeline** (table) -- full event timeline per person,
#   with age-at-event and inter-event gap calculations.
#
# Both views previously existed only as ad hoc Databricks objects, not checked
# into this repo (flagged in Asana 1218420159653198 -- "cannot revert if view
# changed or deleted"). gold_person_branch, the third view named in that task,
# is unrelated to this notebook's tables and is still not source-controlled.
#
# ## Latest changes (2026-09-15)
# Fixed gold_event.event_date_parsed / event_year_parsed: previously took
# silver_event_date.date_start unconditionally, which is correct for
# EXACT/ABT/AFT/RANGE dates but wrong for BEF dates -- silver_event_date
# encodes "BEF <year>" as an open range (date_start = year 1, the unbounded
# lower end; date_end = <year>, the actual known bound), so a BEF event
# resolved to year 1 instead of its real approximate year. This was the root
# cause of the death_year=1 / birth_year=1 corruption tracked at Asana
# 1218448497347847 and guarded against by DQ-001 and DQ-009. Now takes
# date_end for BEF rows. gold_person_life inherits the fix automatically
# (no changes to its own logic) since birth_date/death_date come straight
# from gold_event.

# %%
# %sql
-- Source-controls genealogy.gold_event (previously defined only in Databricks,
-- flagged in Asana 1218420159653198 as "cannot revert if view changed").
-- Fix (2026-09-15): event_date_parsed/event_year_parsed used to take
-- d.date_start unconditionally. That's correct for EXACT/ABT/AFT/RANGE dates
-- (date_start holds the real parsed value there) but wrong for BEF dates --
-- silver_event_date deliberately encodes "BEF <year>" as an open range
-- (date_start = year 1, the unbounded lower end; date_end = <year>, the known
-- upper bound), so taking date_start on a BEF row produced year 1 instead of
-- the real year. Traced from DQ-001/DQ-009 violations (death_year=1) via
-- Asana 1218448497347847 -- David Edmiston, Jonathan Croxon and others
-- workspace-wide. Now takes date_end for BEF rows, date_start for everything
-- else (unchanged behaviour for EXACT/ABT/AFT/RANGE, verified in Cell 3).
CREATE OR REPLACE VIEW genealogy.gold_event (
  record_xref,
  record_type,
  event_line_no,
  event_value,
  event_id,
  event_type,
  event_subtype,
  event_date_raw,
  event_date_parsed,
  event_year_parsed,
  event_date_type,
  event_place,
  event_country_inferred,
  event_ordinal_within_type,
  event_sequence_by_date,
  event_sequence_in_record)
WITH SCHEMA COMPENSATION
AS SELECT
  e.record_xref,
  CASE WHEN e.record_xref LIKE '%F%' THEN 'F' ELSE 'P' END AS record_type,
  e.event_line_no,
  e.event_value,
  e.event_id,
  e.event_type,
  e.event_subtype,
  e.event_date AS event_date_raw,
  -- BEF fix: date_end holds the meaningful bound for a BEF-type range.
  CASE WHEN d.date_type = 'BEF' THEN d.date_end ELSE d.date_start END AS event_date_parsed,
  year(CASE WHEN d.date_type = 'BEF' THEN d.date_end ELSE d.date_start END) AS event_year_parsed,
  d.date_type AS event_date_type,
  pc.preferred_name AS event_place,
  pc.inferred_country AS event_country_inferred,
  e.event_ordinal_within_type,
  -- NOTE: still ordered on d.date_start, unchanged from the pre-fix view --
  -- a BEF event's date_start is still the year-1 sentinel, so event
  -- sequencing for BEF-dated events is not corrected by this change. Out of
  -- scope for the DQ-001 date-plausibility bug this fix addresses; flag
  -- separately if BEF event ordering needs the same treatment.
  row_number() OVER (
      PARTITION BY e.record_xref
      ORDER BY d.date_start, e.event_type
    ) AS event_sequence_by_date,
  event_sequence_in_record
FROM
    genealogy.silver_event e
    LEFT JOIN genealogy.silver_event_date d
      ON e.event_id = d.event_id
    LEFT JOIN genealogy.silver_place_variant pv
      ON e.event_place_variant_id = pv.place_variant_id
    LEFT JOIN genealogy.silver_v_active_place_canonical pc
      ON pc.canonical_place_id = pv.canonical_place_id
WHERE event_type NOT IN ('NAME', 'SEX', 'FACT')

# %%
# %sql
-- Spot-check: David Edmiston / Jonathan Croxon, both previously corrupted to
-- death_year = 1 via a "Bef. YYYY" death date (see Asana 1218448497347847).
-- event_date_parsed/event_year_parsed should now reflect the "Bef." year,
-- not year 1.
SELECT record_xref, event_type, event_date_raw, event_date_type,
       event_date_parsed, event_year_parsed
FROM genealogy.gold_event
WHERE record_xref IN ('@I999886834@', '@I332676429761@')
  AND event_type = 'DEAT'
ORDER BY record_xref;

# %%
# %sql
-- ============================================================
-- ANOMALY CHECKS -- all should return 0 violations
-- ============================================================

-- 1. A BEF-typed event should never resolve to year 1 (the old bug)
SELECT
  'BEF event resolved to year 1' AS check_name,
  COUNT(*) AS violations
FROM genealogy.gold_event
WHERE event_date_type = 'BEF' AND year(event_date_parsed) = 1

UNION ALL

-- 2. A non-BEF event's parsed date should be unchanged by this fix (still
--    equal to silver_event_date.date_start) -- confirms no behaviour change
--    for EXACT/ABT/AFT/RANGE dates
SELECT
  'non-BEF event_date_parsed diverged from date_start' AS check_name,
  COUNT(*) AS violations
FROM genealogy.gold_event ge
JOIN genealogy.silver_event_date d ON d.event_id = ge.event_id
WHERE ge.event_date_type != 'BEF'
  AND ge.event_date_parsed != d.date_start

ORDER BY violations DESC;

# %%
# %sql
-- Source-controls genealogy.gold_person_life (previously defined only in
-- Databricks, flagged in Asana 1218420159653198). Logic unchanged from the
-- prior production definition -- captured as-is. Inherits the Cell 1 BEF fix
-- automatically since birth_date/death_date come straight from gold_event.
CREATE OR REPLACE VIEW genealogy.gold_person_life (
  person_gedcom_id,
  given_name,
  first_name,
  surname,
  display_name,
  sex,
  birth_date,
  birth_year,
  birth_date_raw,
  birth_date_type,
  birth_place,
  death_date,
  death_year,
  death_date_raw,
  death_place,
  age_at_death,
  has_birth_event,
  has_death_event,
  is_living)
WITH SCHEMA COMPENSATION
AS WITH ranked_events AS (
  SELECT
    ge.record_xref as person_id,
    ge.event_id,
    ge.event_type,
    ge.event_date_raw,
    ge.event_date_parsed,
    ge.event_date_type,
    ge.event_place as place
  FROM
    genealogy.gold_event ge
  WHERE
    event_type IN ('BIRT', 'DEAT')
    AND event_ordinal_within_type = 1
),
life_events AS (
  SELECT
    person_id,
    MAX(
      CASE
        WHEN event_type = 'BIRT' THEN event_id
      END
    ) AS birth_event_id,
    MAX(
      CASE
        WHEN event_type = 'BIRT' THEN event_date_parsed
      END
    ) AS birth_date,
    MAX(
      CASE
        WHEN event_type = 'BIRT' THEN event_date_raw
      END
    ) AS birth_date_raw,
    MAX(
      CASE
        WHEN event_type = 'BIRT' THEN event_date_type
      END
    ) AS birth_date_type,
    MAX(
      CASE
        WHEN event_type = 'BIRT' THEN place
      END
    ) AS birth_place,
    MAX(
      CASE
        WHEN event_type = 'DEAT' THEN event_id
      END
    ) AS death_event_id,
    MAX(
      CASE
        WHEN event_type = 'DEAT' THEN event_date_parsed
      END
    ) AS death_date,
    MAX(
      CASE
        WHEN event_type = 'DEAT' THEN event_date_raw
      END
    ) AS death_date_raw,
    MAX(
      CASE
        WHEN event_type = 'DEAT' THEN place
      END
    ) AS death_place
  FROM
    ranked_events
  GROUP BY
    person_id
)
SELECT
  p.person_gedcom_id,
  n.given_name,
  split_part(n.given_name, ' ', 1) as first_name,
  n.surname,
  TRIM(CONCAT(COALESCE(n.given_name, ''), ' ', COALESCE(n.surname, ''))) AS display_name,
  p.sex,
  le.birth_date,
  year(birth_date) as birth_year,
  le.birth_date_raw,
  le.birth_date_type,
  le.birth_place,
  le.death_date,
  year(death_date) as death_year,
  le.death_date_raw,
  le.death_place,
  CASE
    WHEN
      le.birth_date IS NOT NULL
      AND le.death_date IS NOT NULL
    THEN
      floor(months_between(le.death_date, le.birth_date) / 12)
  END AS age_at_death,
  le.birth_event_id IS NOT NULL AS has_birth_event,
  le.death_event_id IS NOT NULL AS has_death_event,
  case
    when
      year(current_date) - year(birth_date) <= 100
      AND le.death_date IS NULL
    then
      1
    else 0
  end as is_living
FROM
  genealogy.silver_person p
    LEFT JOIN genealogy.silver_person_name n
      ON p.person_gedcom_id = n.person_gedcom_id
    LEFT JOIN life_events le
      ON p.person_gedcom_id = le.person_id

# %%
# %sql
-- ============================================================
-- ANOMALY CHECKS -- all should return 0 violations
-- ============================================================

-- 1. A "Bef."/"BEF" qualified death should never leave death_year = 1 --
--    regression guard for the Cell 1 gold_event fix (DQ-009 also guards
--    this independently at genealogy.gold_person_life)
SELECT
  'BEF death resolved to year 1' AS check_name,
  COUNT(*) AS violations
FROM genealogy.gold_person_life
WHERE UPPER(REPLACE(death_date_raw, '.', '')) LIKE 'BEF%' AND death_year = 1

UNION ALL

-- 2. Same check on the birth side (DQ-009 also found this pattern on
--    birth_year, e.g. Whyte @I_967017974@ from a "BEF 1631" birth date)
SELECT
  'BEF birth resolved to year 1' AS check_name,
  COUNT(*) AS violations
FROM genealogy.gold_person_life
WHERE UPPER(REPLACE(birth_date_raw, '.', '')) LIKE 'BEF%' AND birth_year = 1

UNION ALL

-- 3. Row count should match silver_person -- the view is a straight 1:1
--    LEFT JOIN from silver_person, so no join should fan out or drop rows
SELECT
  'gold_person_life row count != silver_person row count' AS check_name,
  ABS(
    (SELECT COUNT(*) FROM genealogy.gold_person_life)
    - (SELECT COUNT(*) FROM genealogy.silver_person)
  ) AS violations

ORDER BY violations DESC;

# %%
# %sql
CREATE OR REPLACE TABLE genealogy.gold_person_event_timeline AS
SELECT p.person_gedcom_id
	,pn.given_name
	,pn.surname
	,e.event_id
	,e.event_type
	,e.event_subtype
	,e.event_value
	,ep.role AS event_role
	,ep.data_source AS event_participant_source
	,e.event_date_raw
	,e.event_date_type
	,e.event_date_parsed
	,e.event_year_parsed
	,e.event_place
	,e.event_country_inferred
	,CASE 
		WHEN birth_date IS NULL
			OR e.event_date_parsed IS NULL
			THEN NULL
				-- exclude BEFORE / AFTER
		WHEN birth_date_type IN (
				'BEF'
				,'AFT'
				)
			OR event_date_type IN (
				'BEF'
				,'AFT'
				)
			THEN NULL
		ELSE year(event_date_parsed) - year(birth_date) - CASE 
				WHEN date_format(event_date_parsed, 'MM-dd') < date_format(birth_date, 'MM-dd')
					THEN 1
				ELSE 0
				END
		END AS age_years
	,CASE 
		WHEN age_years IS NULL
			THEN NULL
		WHEN birth_date_type = 'EXACT'
			AND event_date_type = 'EXACT'
			THEN true
		ELSE false
		END AS age_years_exact_flag
	,CASE 
		WHEN age_years IS NULL
			THEN NULL
		WHEN age_years_exact_flag = true
			THEN NULL
		ELSE CONCAT (
				'Age estimated from '
				,birth_date_type
				,' birth date and '
				,event_date_type
				,' event date'
				)
		END AS age_note
	,row_number() OVER (
		PARTITION BY p.person_gedcom_id
		,e.event_type
		,ep.role ORDER BY e.event_date_parsed
		) AS event_ordinal_within_type_and_role
	,row_number() OVER (
		PARTITION BY p.person_gedcom_id ORDER BY e.event_date_parsed
			,e.event_type
		) AS event_sequence_by_date
	,
	--Calculate days since previous event of same type/role, ignore NULLs and BEF/AFT dates
	CASE 
		WHEN e.event_date_parsed IS NULL
			THEN NULL
		WHEN event_date_type IN (
				'BEF'
				,'AFT'
				)
			THEN NULL
		WHEN lag(e.event_date_parsed) OVER (
				PARTITION BY p.person_gedcom_id
				,e.event_type
				,ep.role ORDER BY e.event_date_parsed
				) IS NULL
			THEN NULL
		WHEN lag(event_date_type) OVER (
				PARTITION BY p.person_gedcom_id
				,e.event_type
				,ep.role ORDER BY e.event_date_parsed
				) IN (
				'BEF'
				,'AFT'
				)
			THEN NULL
		ELSE datediff(e.event_date_parsed, lag(e.event_date_parsed) OVER (
					PARTITION BY p.person_gedcom_id
					,e.event_type
					,ep.role ORDER BY e.event_date_parsed
					))
		END AS days_since_previous_same_event
	,CASE 
		WHEN days_since_previous_same_event IS NULL
			THEN 'UNKNOWN'
		WHEN days_since_previous_same_event = 0
			THEN 'SAME_DAY'
		WHEN days_since_previous_same_event <= 7
			THEN 'DAYS'
		WHEN days_since_previous_same_event <= 30
			THEN 'WEEKS'
		WHEN days_since_previous_same_event <= 365
			THEN 'MONTHS'
		WHEN days_since_previous_same_event <= 3650
			THEN 'YEARS'
		ELSE 'DECADE_PLUS'
		END AS same_event_gap_bucket
	,
	-- Same calcs for any event
	CASE 
		WHEN e.event_date_parsed IS NULL
			THEN NULL
		WHEN event_date_type IN (
				'BEF'
				,'AFT'
				)
			THEN NULL
		WHEN lag(e.event_date_parsed) OVER (
				PARTITION BY p.person_gedcom_id ORDER BY e.event_date_parsed
				) IS NULL
			THEN NULL
		WHEN lag(event_date_type) OVER (
				PARTITION BY p.person_gedcom_id ORDER BY e.event_date_parsed
				) IN (
				'BEF'
				,'AFT'
				)
			THEN NULL
		ELSE datediff(e.event_date_parsed, lag(e.event_date_parsed) OVER (
					PARTITION BY p.person_gedcom_id ORDER BY e.event_date_parsed
					))
		END AS days_since_previous_any_event
	,CASE 
		WHEN days_since_previous_any_event IS NULL
			THEN 'UNKNOWN'
		WHEN days_since_previous_any_event = 0
			THEN 'SAME_DAY'
		WHEN days_since_previous_any_event <= 7
			THEN 'DAYS'
		WHEN days_since_previous_any_event <= 30
			THEN 'WEEKS'
		WHEN days_since_previous_any_event <= 365
			THEN 'MONTHS'
		WHEN days_since_previous_any_event <= 3650
			THEN 'YEARS'
		ELSE 'DECADE_PLUS'
		END AS any_event_gap_bucket
FROM genealogy.gold_person_life p
JOIN genealogy.silver_person_name pn ON pn.person_gedcom_id = p.person_gedcom_id
JOIN genealogy.silver_event_participant ep ON p.person_gedcom_id = ep.person_id
JOIN genealogy.gold_event e ON ep.event_id = e.event_id
