# %% [markdown]
# # Notebook 08: gold_generation_depth + gold_ancestral_proximity
#
# Builds two tables that define how every person in the tree relates to the researcher.
#
# ## gold_generation_depth
# Direct ancestors only. Recurses upward through parent relationships from the researcher.
# - `person_id` — GEDCOM ID
# - `generation_depth` — 0 = researcher, 1 = parents, 2 = grandparents, etc.
# - `path` — array from researcher to this ancestor (shortest path)
#
# ## gold_ancestral_proximity
# Everyone in the tree reachable from a direct ancestor via parent-child or spouse relationships.
# - `person_id` — GEDCOM ID
# - `ancestral_proximity` — 0 = direct ancestor, 1 = child of ancestor or spouse of ancestor, etc.
# - `path_to_ancestor` — array from nearest direct ancestor to this person
# - `nearest_direct_ancestor_id` — the direct ancestor this person is closest to
# - `is_blood_relative` — **TRUE** if reached via parent-child recursion (blood descent from a direct ancestor); **FALSE** if reached via spouse expansion (in-law / spouse, non-blood)
#
# ## is_blood_relative logic
# The recursive CTE (`prox_all_steps`) follows only `parent` relationships, so every person it
# produces is definitionally a blood relative of the researcher (direct ancestor or descendant
# of a direct ancestor = sibling, cousin, etc.). The two spouse INSERT statements afterwards
# add only people not already in the table (`NOT EXISTS` guard), so they can only ever be
# non-blood relatives. This means `is_blood_relative` can be set as a literal constant in each
# code path rather than derived from any join.
#
# ## Run order
# Run all cells in order. The spouse INSERTs in Cell 5 depend on the table created in Cell 3.
# Re-running Cell 3 alone will truncate the spouse rows — always re-run Cell 5 afterwards.

# %%
# %sql
CREATE OR REPLACE TEMP VIEW gen_seed AS
SELECT
  '@I_967018310@' AS person_id, -- researcher (Ed)
  0 AS generation_depth;

# %%
# %sql
-- parent-child edges used by both generation_depth and proximity recursions
CREATE OR REPLACE TEMP VIEW person_parent_child AS
SELECT
  person_id_1 AS parent_id,
  person_id_2 AS child_id
FROM genealogy.silver_relationship
WHERE relationship_type = 'parent';

# %%
# %sql
-- Recurses UPWARD through parent relationships from the researcher.
-- Only direct ancestors are produced — no collaterals, no spouses.
-- Path direction: researcher at position 0, ancestor at position N.
CREATE OR REPLACE TABLE genealogy.gold_generation_depth AS
WITH RECURSIVE gen_all_steps(person_id, generation_depth, path) MAX RECURSION LEVEL 200 AS (
  -- Base case: researcher
  SELECT
    person_id,
    generation_depth,
    array(person_id) AS path
  FROM gen_seed

  UNION ALL

  -- Recursive step: walk upward to parents
  SELECT
    pc.parent_id         AS person_id,
    g.generation_depth + 1 AS generation_depth,
    array_append(g.path, pc.parent_id)
  FROM gen_all_steps g
  JOIN person_parent_child pc ON g.person_id = pc.child_id
  WHERE pc.parent_id IS NOT NULL
)
SELECT
  person_id,
  MIN(generation_depth)          AS generation_depth,
  MIN_BY(path, size(path))       AS path
FROM gen_all_steps
GROUP BY person_id;

# %%
# %sql
-- Seed for proximity recursion: every direct ancestor is at proximity 0.
-- The recursion then fans outward through parent-child edges to find
-- collateral relatives, before the spouse INSERTs add in-laws.
CREATE OR REPLACE TEMP VIEW prox_seed AS
SELECT
  person_id,
  0 AS ancestral_proximity
FROM genealogy.gold_generation_depth;

# %%
# %sql
-- ============================================================
-- BUILD PHASE 1: blood relatives only
--
-- Recurses DOWNWARD through parent-child relationships from
-- every direct ancestor. Produces all blood relatives:
--   proximity 0 = direct ancestors (seeded from gold_generation_depth)
--   proximity 1 = children of direct ancestors (siblings, aunts/uncles)
--   proximity 2 = grandchildren of ancestors (1st cousins, etc.)
--   ... and so on for all collateral lines
--
-- is_blood_relative = TRUE for every row produced here.
-- The spouse INSERTs in Cell 6 add non-blood relatives afterwards.
-- ============================================================
CREATE OR REPLACE TABLE genealogy.gold_ancestral_proximity AS
WITH RECURSIVE prox_all_steps (
    person_id,
    ancestral_proximity,
    path,
    direct_ancestor_id,
    is_blood_relative
) AS (

  -- Base case: direct ancestors — always blood relatives
  SELECT
    person_id,
    0                  AS ancestral_proximity,
    array(person_id)   AS path,
    person_id          AS direct_ancestor_id,
    TRUE               AS is_blood_relative
  FROM prox_seed

  UNION ALL

  -- Recursive step: follow parent -> child edges only.
  -- Spouse edges deliberately excluded here — spouses are added
  -- separately in Cell 6 with is_blood_relative = FALSE.
  SELECT
    r.next_person_id       AS person_id,
    p.ancestral_proximity + 1,
    array_append(p.path, r.next_person_id),
    p.direct_ancestor_id,
    TRUE                   AS is_blood_relative  -- children of blood relatives are blood
  FROM prox_all_steps p
  JOIN (
    SELECT
      person_id_1 AS from_person_id,
      person_id_2 AS next_person_id
    FROM genealogy.silver_relationship
    WHERE relationship_type = 'parent'
  ) r ON p.person_id = r.from_person_id
  -- Cycle guard: prevents infinite loops in trees with data errors
  WHERE NOT array_contains(p.path, r.next_person_id)
)
SELECT
  person_id,
  MIN(ancestral_proximity)               AS ancestral_proximity,
  MIN_BY(path, size(path))               AS path_to_ancestor,
  MIN_BY(direct_ancestor_id, size(path)) AS nearest_direct_ancestor_id,
  TRUE                                   AS is_blood_relative
FROM prox_all_steps
GROUP BY person_id;

# %%
# %sql
-- ============================================================
-- BUILD PHASE 2: non-blood relatives (spouses and in-laws)
--
-- Adds spouses of anyone already in gold_ancestral_proximity.
-- The NOT EXISTS guard ensures only people not already in the
-- table are inserted — so these rows are definitionally non-blood
-- (a blood relative already present would have been excluded).
--
-- is_blood_relative = FALSE for all rows inserted here.
--
-- Two INSERTs handle both directions of the spouse relationship:
--   person_id_1 = husband, person_id_2 = wife in silver_relationship
-- ============================================================

-- Wives of blood/proximity relatives
INSERT INTO genealogy.gold_ancestral_proximity
SELECT
  s.person_id_2                                                            AS person_id,
  p.ancestral_proximity + 1                                                AS ancestral_proximity,
  MIN_BY(array_append(p.path_to_ancestor, s.person_id_2), size(p.path_to_ancestor)) AS path_to_ancestor,
  MIN_BY(p.nearest_direct_ancestor_id, size(p.path_to_ancestor))          AS nearest_direct_ancestor_id,
  FALSE                                                                    AS is_blood_relative
FROM genealogy.gold_ancestral_proximity p
JOIN genealogy.silver_relationship s
  ON p.person_id = s.person_id_1
WHERE s.relationship_type = 'spouse'
  -- Only add people not already present (they would be blood relatives if already here)
  AND NOT EXISTS (
    SELECT 1
    FROM genealogy.gold_ancestral_proximity p2
    WHERE p2.person_id = s.person_id_2
  )
GROUP BY s.person_id_2, p.ancestral_proximity; -- deduplicate: one person married to two tree members

-- Husbands of blood/proximity relatives
INSERT INTO genealogy.gold_ancestral_proximity
SELECT
  s.person_id_1                                                            AS person_id,
  p.ancestral_proximity + 1                                                AS ancestral_proximity,
  MIN_BY(array_append(p.path_to_ancestor, s.person_id_1), size(p.path_to_ancestor)) AS path_to_ancestor,
  MIN_BY(p.nearest_direct_ancestor_id, size(p.path_to_ancestor))          AS nearest_direct_ancestor_id,
  FALSE                                                                    AS is_blood_relative
FROM genealogy.gold_ancestral_proximity p
JOIN genealogy.silver_relationship s
  ON p.person_id = s.person_id_2
WHERE s.relationship_type = 'spouse'
  -- Only add people not already present (they would be blood relatives if already here)
  AND NOT EXISTS (
    SELECT 1
    FROM genealogy.gold_ancestral_proximity p2
    WHERE p2.person_id = s.person_id_1
  )
GROUP BY s.person_id_1, p.ancestral_proximity; -- deduplicate: one person married to two tree members

# %%
# %sql
-- ============================================================
-- VERIFICATION
-- Expected approximate results (based on tree as of May 2026):
--   is_blood_relative = TRUE:  ~5,000-5,500 (direct ancestors + all collateral lines)
--   is_blood_relative = FALSE: ~800-1,500 (spouses and in-laws)
--   proximity = 0, blood = TRUE: exactly 385 (direct ancestors)
--   proximity = 0, blood = FALSE: 0 (direct ancestors can never be non-blood)
--   proximity = 1, blood = FALSE: ~37 (spouses of direct ancestors)
-- ============================================================

-- Summary by proximity and blood status
SELECT
  ancestral_proximity,
  is_blood_relative,
  COUNT(*) AS people
FROM genealogy.gold_ancestral_proximity
WHERE ancestral_proximity <= 4
GROUP BY ancestral_proximity, is_blood_relative
ORDER BY ancestral_proximity, is_blood_relative DESC;

# %%
# %sql
-- ============================================================
-- ANOMALY CHECKS — all should return 0 violations
-- ============================================================

-- 1. Direct ancestors must all be blood relatives
SELECT
  'Direct ancestor flagged non-blood' AS check_name,
  COUNT(*) AS violations
FROM genealogy.gold_ancestral_proximity ap
JOIN genealogy.gold_generation_depth gd ON gd.person_id = ap.person_id
WHERE ap.is_blood_relative = FALSE

UNION ALL

-- 2. No person should appear more than once
SELECT
  'Duplicate person_id' AS check_name,
  COUNT(*) AS violations
FROM (
  SELECT person_id, COUNT(*) AS cnt
  FROM genealogy.gold_ancestral_proximity
  GROUP BY person_id
  HAVING cnt > 1
)

UNION ALL

-- 3. is_blood_relative should never be NULL
SELECT
  'NULL is_blood_relative' AS check_name,
  COUNT(*) AS violations
FROM genealogy.gold_ancestral_proximity
WHERE is_blood_relative IS NULL

ORDER BY violations DESC;
